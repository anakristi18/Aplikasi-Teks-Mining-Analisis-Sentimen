# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dd6406ad-2873-4f70-8e00-e68ed5c35918" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd6406ad-2873-4f70-8e00-e68ed5c35918">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving exo(pakai).xlsx to exo(pakai).xlsx

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4cf41faa-fcd1-4b0e-925c-9899e5535c80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4cf41faa-fcd1-4b0e-925c-9899e5535c80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving exo_sentimen_positif.xlsx to exo_sentimen_positif.xlsx

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3ac53786-e0be-4fba-96c1-9d53c050eee8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ac53786-e0be-4fba-96c1-9d53c050eee8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving exo_sentimen_negatif.xlsx to exo_sentimen_negatif.xlsx

# %%
import pandas as pd

df = pd.read_excel("exo(pakai).xlsx", index_col = None)
df_positif = pd.read_excel("exo_sentimen_positif.xlsx", index_col = None)
df_negatif = pd.read_excel("exo_sentimen_negatif.xlsx", index_col = None)

# %% [markdown]
# ##Praproses Teks

# %%
#menghilangkan url
df["tweet"] = df["tweet"].str.replace(r'\s*https?://\S+(\s+|$)', ' ').str.strip()
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#                                                  tweet  sentimen
# 0                        Dilakukan untuk Baekhyun #EXO         1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...         1
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...         1
# 3              dilakukan untuk baekhyun #EXO #BAEKHYUN         1
# 4    Saya pikir kami memiliki waktu yg sangat baik....         1
# ..                                                 ...       ...
# 495  asli deh padahal udah gua nyala semua notif ny...         0
# 496  Tolong EXO segera kembali, sebelum aku terjatu...         0
# 497  Baru sadar, selama stan exo, aku ga punya mome...         0
# 498  padahal dulu suka banget nonton video konser s...         0
# 499  Harapan gua terlalu muluk kayak nya kalo liat ...         0
#
# [500 rows x 2 columns]

# %%
#menghilangkan url
df_positif["tweet"] = df_positif["tweet"].str.replace(r'\s*https?://\S+(\s+|$)', ' ').str.strip()
df_positif
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#                                                  tweet  sentimen
# 0                        Dilakukan untuk Baekhyun #EXO         1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...         1
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...         1
# 3              dilakukan untuk baekhyun #EXO #BAEKHYUN         1
# 4    Saya pikir kami memiliki waktu yg sangat baik....         1
# ..                                                 ...       ...
# 425  @chikatiejk Tapi jujur bridges nya exo tuh bag...         1
# 426  lagi bayangin kalau exo, nct, svt sama treasur...         1
# 427  tetap setia sama EXO di era gempuran idol lain...         1
# 428  Gue suka KPop gara gara  BTS and EXO  sejak  2014         1
# 429  @starfess Luhan, Suho, Lay, Chanyeol, Baekhyun...         1
#
# [430 rows x 2 columns]

# %%
#menghilangkan url
df_negatif["tweet"] = df_negatif["tweet"].str.replace(r'\s*https?://\S+(\s+|$)', ' ').str.strip()
df_negatif
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#                                                 tweet  sentimen
# 0   lucu banget liat Kai marah gegara eribong di s...         0
# 1   Tidak sabar menanti Kji3 ðŸ™ƒ Tapi tunggu!! It...         0
# 2   Beri suara Baekhyun di TTA yuk Eri,, ayo kelua...         0
# 3   Pesan suara dari #CHEN untuk 5 th hari jadi De...         0
# 4   Biasa mendapat tinjauan harian Chanyeol tiap h...         0
# ..                                                ...       ...
# 65  asli deh padahal udah gua nyala semua notif ny...         0
# 66  Tolong EXO segera kembali, sebelum aku terjatu...         0
# 67  Baru sadar, selama stan exo, aku ga punya mome...         0
# 68  padahal dulu suka banget nonton video konser s...         0
# 69  Harapan gua terlalu muluk kayak nya kalo liat ...         0
#
# [70 rows x 2 columns]

# %%
#remove mention
import re
def remove_mention(text):
    for i in text:
        result = re.sub("@[A-Za-z0-9_]+","",text)
    return result

df["tweet"] = df["tweet"].apply(remove_mention)
df
# Out:
#                                                  tweet  sentimen
# 0                        Dilakukan untuk Baekhyun #EXO         1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...         1
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...         1
# 3              dilakukan untuk baekhyun #EXO #BAEKHYUN         1
# 4    Saya pikir kami memiliki waktu yg sangat baik....         1
# ..                                                 ...       ...
# 495  asli deh padahal udah gua nyala semua notif ny...         0
# 496  Tolong EXO segera kembali, sebelum aku terjatu...         0
# 497  Baru sadar, selama stan exo, aku ga punya mome...         0
# 498  padahal dulu suka banget nonton video konser s...         0
# 499  Harapan gua terlalu muluk kayak nya kalo liat ...         0
#
# [500 rows x 2 columns]

# %%
#remove mention
import re
def remove_mention(text):
    for i in text:
        result = re.sub("@[A-Za-z0-9_]+","",text)
    return result

df_positif["tweet"] = df_positif["tweet"].apply(remove_mention)
df_positif
# Out:
#                                                  tweet  sentimen
# 0                        Dilakukan untuk Baekhyun #EXO         1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...         1
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...         1
# 3              dilakukan untuk baekhyun #EXO #BAEKHYUN         1
# 4    Saya pikir kami memiliki waktu yg sangat baik....         1
# ..                                                 ...       ...
# 425   Tapi jujur bridges nya exo tuh bagus bagus, k...         1
# 426  lagi bayangin kalau exo, nct, svt sama treasur...         1
# 427  tetap setia sama EXO di era gempuran idol lain...         1
# 428  Gue suka KPop gara gara  BTS and EXO  sejak  2014         1
# 429   Luhan, Suho, Lay, Chanyeol, Baekhyun, Kyungso...         1
#
# [430 rows x 2 columns]

# %%
#remove mention
import re
def remove_mention(text):
    for i in text:
        result = re.sub("@[A-Za-z0-9_]+","",text)
    return result

df_negatif["tweet"] = df_negatif["tweet"].apply(remove_mention)
df_negatif
# Out:
#                                                 tweet  sentimen
# 0   lucu banget liat Kai marah gegara eribong di s...         0
# 1   Tidak sabar menanti Kji3 ðŸ™ƒ Tapi tunggu!! It...         0
# 2   Beri suara Baekhyun di TTA yuk Eri,, ayo kelua...         0
# 3   Pesan suara dari #CHEN untuk 5 th hari jadi De...         0
# 4   Biasa mendapat tinjauan harian Chanyeol tiap h...         0
# ..                                                ...       ...
# 65  asli deh padahal udah gua nyala semua notif ny...         0
# 66  Tolong EXO segera kembali, sebelum aku terjatu...         0
# 67  Baru sadar, selama stan exo, aku ga punya mome...         0
# 68  padahal dulu suka banget nonton video konser s...         0
# 69  Harapan gua terlalu muluk kayak nya kalo liat ...         0
#
# [70 rows x 2 columns]

# %%
#remove hashtags
def remove_hash(text):
    for i in text:
        result = re.sub("#[A-Za-z0-9_]+","",text)
    return result

df["tweet"] = df["tweet"].apply(remove_hash)
df
# Out:
#                                                  tweet  sentimen
# 0                            Dilakukan untuk Baekhyun          1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...         1
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...         1
# 3                           dilakukan untuk baekhyun           1
# 4    Saya pikir kami memiliki waktu yg sangat baik....         1
# ..                                                 ...       ...
# 495  asli deh padahal udah gua nyala semua notif ny...         0
# 496  Tolong EXO segera kembali, sebelum aku terjatu...         0
# 497  Baru sadar, selama stan exo, aku ga punya mome...         0
# 498  padahal dulu suka banget nonton video konser s...         0
# 499  Harapan gua terlalu muluk kayak nya kalo liat ...         0
#
# [500 rows x 2 columns]

# %%
#remove hashtags
def remove_hash(text):
    for i in text:
        result = re.sub("#[A-Za-z0-9_]+","",text)
    return result

df_positif["tweet"] = df_positif["tweet"].apply(remove_hash)
df_positif
# Out:
#                                                  tweet  sentimen
# 0                            Dilakukan untuk Baekhyun          1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...         1
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...         1
# 3                           dilakukan untuk baekhyun           1
# 4    Saya pikir kami memiliki waktu yg sangat baik....         1
# ..                                                 ...       ...
# 425   Tapi jujur bridges nya exo tuh bagus bagus, k...         1
# 426  lagi bayangin kalau exo, nct, svt sama treasur...         1
# 427  tetap setia sama EXO di era gempuran idol lain...         1
# 428  Gue suka KPop gara gara  BTS and EXO  sejak  2014         1
# 429   Luhan, Suho, Lay, Chanyeol, Baekhyun, Kyungso...         1
#
# [430 rows x 2 columns]

# %%
#remove hashtags
def remove_hash(text):
    for i in text:
        result = re.sub("#[A-Za-z0-9_]+","",text)
    return result

df_negatif["tweet"] = df_negatif["tweet"].apply(remove_hash)
df_negatif
# Out:
#                                                 tweet  sentimen
# 0   lucu banget liat Kai marah gegara eribong di s...         0
# 1   Tidak sabar menanti Kji3 ðŸ™ƒ Tapi tunggu!! It...         0
# 2   Beri suara Baekhyun di TTA yuk Eri,, ayo kelua...         0
# 3   Pesan suara dari  untuk 5 th hari jadi Debut E...         0
# 4   Biasa mendapat tinjauan harian Chanyeol tiap h...         0
# ..                                                ...       ...
# 65  asli deh padahal udah gua nyala semua notif ny...         0
# 66  Tolong EXO segera kembali, sebelum aku terjatu...         0
# 67  Baru sadar, selama stan exo, aku ga punya mome...         0
# 68  padahal dulu suka banget nonton video konser s...         0
# 69  Harapan gua terlalu muluk kayak nya kalo liat ...         0
#
# [70 rows x 2 columns]

# %%
#menghilangkan punctuation
df["tweet"] = df["tweet"].str.replace(r'[^\w\s]+', '')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#                                                  tweet  sentimen
# 0                            Dilakukan untuk Baekhyun          1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...         1
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...         1
# 3                           dilakukan untuk baekhyun           1
# 4    Saya pikir kami memiliki waktu yg sangat baik ...         1
# ..                                                 ...       ...
# 495  asli deh padahal udah gua nyala semua notif ny...         0
# 496  Tolong EXO segera kembali sebelum aku terjatuh...         0
# 497  Baru sadar selama stan exo aku ga punya momen ...         0
# 498  padahal dulu suka banget nonton video konser s...         0
# 499  Harapan gua terlalu muluk kayak nya kalo liat ...         0
#
# [500 rows x 2 columns]

# %%
#menghilangkan punctuation
df_positif["tweet"] = df_positif["tweet"].str.replace(r'[^\w\s]+', '')
df_positif
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#                                                  tweet  sentimen
# 0                            Dilakukan untuk Baekhyun          1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...         1
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...         1
# 3                           dilakukan untuk baekhyun           1
# 4    Saya pikir kami memiliki waktu yg sangat baik ...         1
# ..                                                 ...       ...
# 425   Tapi jujur bridges nya exo tuh bagus bagus ka...         1
# 426  lagi bayangin kalau exo nct svt sama treasure ...         1
# 427  tetap setia sama EXO di era gempuran idol lain...         1
# 428  Gue suka KPop gara gara  BTS and EXO  sejak  2014         1
# 429   Luhan Suho Lay Chanyeol Baekhyun Kyungsoo Seh...         1
#
# [430 rows x 2 columns]

# %%
#menghilangkan punctuation
df_negatif["tweet"] = df_negatif["tweet"].str.replace(r'[^\w\s]+', '')
df_negatif
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#                                                 tweet  sentimen
# 0   lucu banget liat Kai marah gegara eribong di s...         0
# 1   Tidak sabar menanti Kji3 ðŸƒ Tapi tunggu Itu b...         0
# 2   Beri suara Baekhyun di TTA yuk Eri ayo keluari...         0
# 3   Pesan suara dari  untuk 5 th hari jadi Debut E...         0
# 4   Biasa mendapat tinjauan harian Chanyeol tiap h...         0
# ..                                                ...       ...
# 65  asli deh padahal udah gua nyala semua notif ny...         0
# 66  Tolong EXO segera kembali sebelum aku terjatuh...         0
# 67  Baru sadar selama stan exo aku ga punya momen ...         0
# 68  padahal dulu suka banget nonton video konser s...         0
# 69  Harapan gua terlalu muluk kayak nya kalo liat ...         0
#
# [70 rows x 2 columns]

# %%
#remove emoji
df["tweet"] = df["tweet"].apply(lambda x: x.encode('ascii', 'ignore').decode('ascii'))
df
# Out:
#                                                  tweet  sentimen
# 0                            Dilakukan untuk Baekhyun          1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...         1
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...         1
# 3                           dilakukan untuk baekhyun           1
# 4    Saya pikir kami memiliki waktu yg sangat baik ...         1
# ..                                                 ...       ...
# 495  asli deh padahal udah gua nyala semua notif ny...         0
# 496  Tolong EXO segera kembali sebelum aku terjatuh...         0
# 497  Baru sadar selama stan exo aku ga punya momen ...         0
# 498  padahal dulu suka banget nonton video konser s...         0
# 499  Harapan gua terlalu muluk kayak nya kalo liat ...         0
#
# [500 rows x 2 columns]

# %%
#remove emoji
df_positif["tweet"] = df_positif["tweet"].apply(lambda x: x.encode('ascii', 'ignore').decode('ascii'))
df_positif
# Out:
#                                                  tweet  sentimen
# 0                            Dilakukan untuk Baekhyun          1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...         1
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...         1
# 3                           dilakukan untuk baekhyun           1
# 4    Saya pikir kami memiliki waktu yg sangat baik ...         1
# ..                                                 ...       ...
# 425   Tapi jujur bridges nya exo tuh bagus bagus ka...         1
# 426  lagi bayangin kalau exo nct svt sama treasure ...         1
# 427  tetap setia sama EXO di era gempuran idol lain...         1
# 428  Gue suka KPop gara gara  BTS and EXO  sejak  2014         1
# 429   Luhan Suho Lay Chanyeol Baekhyun Kyungsoo Seh...         1
#
# [430 rows x 2 columns]

# %%
#remove emoji
df_negatif["tweet"] = df_negatif["tweet"].apply(lambda x: x.encode('ascii', 'ignore').decode('ascii'))
df_negatif
# Out:
#                                                 tweet  sentimen
# 0   lucu banget liat Kai marah gegara eribong di s...         0
# 1   Tidak sabar menanti Kji3  Tapi tunggu Itu bera...         0
# 2   Beri suara Baekhyun di TTA yuk Eri ayo keluari...         0
# 3   Pesan suara dari  untuk 5 th hari jadi Debut E...         0
# 4   Biasa mendapat tinjauan harian Chanyeol tiap h...         0
# ..                                                ...       ...
# 65  asli deh padahal udah gua nyala semua notif ny...         0
# 66  Tolong EXO segera kembali sebelum aku terjatuh...         0
# 67  Baru sadar selama stan exo aku ga punya momen ...         0
# 68  padahal dulu suka banget nonton video konser s...         0
# 69  Harapan gua terlalu muluk kayak nya kalo liat ...         0
#
# [70 rows x 2 columns]

# %%
#case folding
data_lower = []
for line in df["tweet"]:
  a = line.lower()
  data_lower.append(a) 

data_lower
# Out:
# ['dilakukan untuk baekhyun ',
#  'peristiwa selanjutnya kita berkumpul lagi ya guys              ',
#  'semua nya tertawa lihat tingkah nya sehun tim produksi nya juga  kyungsoo aja sampai sesak nafas benar kata kai kalo sehun selalu jadi diri nya sendiri alias selalu jadi raja di antara kakak nya  nya       ',
#  'dilakukan untuk baekhyun  ',
#  'saya pikir kami memiliki waktu yg sangat baik menunggu itu sulit tapi sambil mengenang masamasa kita bahagia  mari bersiapsiap untuk bertemu lagi kalau begitu ayo bertemu secepatnya meski hanya sehari aku mencintaimu exol    ',
#  ' pilih untuk baekhyun   ',
#  'dari pameran debut hingga konser saya merasa bahagia saya juga menantikan smtown dimana saya bisa bertemu semua orang semoga tetap sehat sampai hari kita bertemu ini adalah sebuah janji selamat tinggal    ',
#  ' pilih untuk baekhyun   ',
#  'selamat hari jadi exo cbx kesayangan aku   ',
#  'exo tiap debut kembali nya beda beda ga heran sih kalo exol tahan banting semua  ',
#  'kamu ganteng bgt mas   ',
#  'exocbx jepang debut 5 th hari jadi  semoga kalian cepat kembali setelah baekhyun selesai wajib militer ya        ',
#  '220524  update   pesan dari xiumin  exocbx 5 th selamat hari jadi debut di japan  ',
#  '   baekhyun  amp',
#  'dilakukan untuk exo baekhyun    ',
#  'senang banget kebetulan nya benar benar gila aku kirim pesan sekitar 4 menit sebelum di unggah sama suho gatau dia benar benar perhatiin aku atau ngga tapi kaya aneh aja gitu pas banget minta foto selfie kalo ini benaran tolong suho baik banget',
#  'sesuatu yg kalo diceritakan dg lagu sedih bikin nangis kalo dinikmati dg musiknya  permission to dance atau  dont fight the feeling jadinya hangat dan menyenangkan beberapa orang bilang apa untungnya jadi pecandu drama korea and pecinta musik korea bagi aku adalah caraku penyembuhan',
#  'sehun x diorerl    ',
#  'loh  balik ke incheon dulu toh aku kira langsung dubai   ',
#  'suho telah terbang  dubai  japan usa ke seoul   ',
#  'aku terpikat pada tuturmu aku tersihir jiwamu terkagum pada pandangmu  caramu melihat dunia  ',
#  '170527 kai  the exordium di seoul iconic    ',
#  'lihat kalian kumpul gini kok senang banget yaa sehatsehat terus kalian     ',
#  'ini aura aktornya sehun jadinya mirip bgt sama yoo yeonseok     ',
#  '220523 china mencapai puncak baru menempati peringkat 6 dalam daftar top 10 pasar musik di dunia  pada pembaruan 2021 menurut ifpi exo adalah puncak 1 dalam daftar yg membantu pasar cina           ',
#  ' telah terbang ke seoul  dubai    seoul  dm ',
#  'berhubung tim keuangan ace akan jeda sementara di bawah adalah detail hasil donasi  kjm2    terimakasih semua untuk semua donatur dan juga tim streaming  sampai jumpai di projek selanjutnya ',
#  '220522 ig musik kok unggah perbaruan dengan     kita pakai baju yang sama tanpa disengaja  sebelum kita kelelahan terima kasih untuk pelatih yang mengajarkan kita',
#  'paling suka sama lagu ini  membayangkan exo nyanyi ini secara langsung  seperti biasa  ',
#  'bentar lagi juni bulannya dont fight for then feeling   no matter by  ',
#  'jaehyuk of   baekhyun of  renjun yangyang and jisung of ',
#  'udah mau setahun aja  runaway by  ',
#  'exol ayok mutualan kuy kuy kuy mari kita saling berkawan besti   ',
#  'diperbarui juga maknae palsu xiumin dan exo  ',
#  'eri ayo semangat dukung baekhyun jarak nya tipis',
#  'vitamin xiu ini bakalan bertahan berapa lama ya  vitamin xiu ini buat berapa minggu berapa bulan  kapan xiumin perbarui lagi',
#  'masternim kai yg masih aktif siapa aja ya selain aumicky   ',
#  'member exo lagi pada kangen kah ',
#  'ternyata foto ini yg perbarui sehun aku kira dari smc amp',
#  'masih banyak bermunculan di sosial media intip perjalanan cinta jennie blackpink pernah dekat sama kai exo hingga v bts',
#  'nego aja guys masih mulus isi lengkap  ',
#  'memilih untuk baekhyun  ',
#  'memilih untuk baekhyun   ',
#  'suho terbang ke  dubai  jepang   usa ke seoul   ',
#  '220523 ooh sehun instragram   sehun memperbarui foto bersama suho dan member exo',
#  'nih orang fotonya tuh simpel dan biasa tapi selalu kelihatan bagus feed instagram nya pun rapi dan estetik  ',
#  'sehun instagram  imut imut imut   sayang banget sama kalian',
#  'suho dan sehun    ',
#  'ooh sehun lagi   ',
#  'katanya doa gaboleh ragu dan setengah setengah   ya tuhan jadikan salah seorang yang ada difoto ini jodoh saya terserah yang mana tuhan mau yang paling kanan atau paling kiri atau disamping yg paling kanan atau yg di samping paling kiri apalagi yg tengah  ',
#  '220523   suho instagram  sampai jumpa lagi    ',
#  ' memilih untuk baekhyun   ',
#  '141018 smtown di  shanghai             x0',
#  'exo adalah sembilan  kita satu exo saranghaja              ',
#  'ooh sehun      ',
#  '__        selamat ulang tahun semoga di tahun ini di beri kesehatan supaya bisa nyapa exol setiap hari  kita mencintaimu oppa selamat',
#  'ooh berusaha menstabilkan pikiran ini    ',
#  'selamat ulang tahun suho terimakasih sudah menjadi ayah buat exo sehat ya dan sukses di karir solo maupun di grup      ',
#  'tahu aja kalo exol habis kena drama makasih sehun   ',
#  'ooh sehun   ',
#  'selamat ulang tahun suho        ',
#  'selamat ulang tahun suho        ',
#  ' selamat ulang tahun ketua kita    terimakasih sudah bekerja keras selama ini sehat selalu ya dan mari kita bertemu di masa depan  terimakasih amp',
#  'aku dengar dari nadanya kayak lagu exo judulnya playboy ya gak sih     ',
#  'hemm iya tahu ganteng kok  ',
#  'nah kalo ini kumpulan barang siap sedia alias tersedia   alias ls list officialunoff           oriofficial     unoff   ada yang oriofficial ada yg ngga',
#  'tiap pencarian deg deg an terus takut kurang  pas tau senang poll   ',
#  'oh iya ya bisa jadi sih karena mau ganti bagian agensi lagian sm hiburan senang banget bikin acara tibatiba begitu wkwk ',
#  'exol memilih untuk baekhyun      ',
#  'exo jeda sepi konten  exo jeda bikin exol mabok perbaruan dan visual tiap saat          ',
#  'mau ikutan trend tapi pocky kemahalan    ',
#  'junmyeon kayak anak yg terpaksa ikut ayahnya untuk ketemu klien    ',
#  'kenapa kalo lagu exo di cover ga dapet rasa nya ya kek lewat lewat aja gitu',
#  'tao adalah member yang paling sering menangis fakta exo',
#  'kangen masa dulu semangat buat promosi exo ada kabar langsung senang banget sekarang mau semangat buat promosi exo semangat hidup aja nggak ada',
#  'kayak nya makin banyak yg ninggal exo ya di linimasa udah dikit bgt yg promosi exo pada pindah kemana nih',
#  'asli deh padahal udah gua nyala semua notif nya instagram semua member exo tapi pas sehun sama jongin kemaren perbarui cerita instagram kenapa gaada pemberitahuan nya sih',
#  'tolong exo segera kembali sebelum aku terjatuh lebih jauh ke brondong dream ',
#  'baru sadar selama stan exo aku ga punya momen utama yang bikin aku suka banget ke sehun tentu saja aku promosi dan mendukung dia terus exo stan era  sedangkan aku punya momen itu ke member lain',
#  'padahal dulu suka banget nonton video konser suju shinee exo karena terasa nggak lipsync sekarang coba tonton konser idol sm rasa nya kurang greget aja gitu',
#  'harapan gua terlalu muluk kayak nya kalo liat exo kembali tahun ini apapun itu yang jelas gua kangen banget sama mereka']

# %%
#case folding
data_lower_pos = []
for line in df_positif["tweet"]:
  a = line.lower()
  data_lower_pos.append(a) 

data_lower_pos
# Out:
# ['dilakukan untuk baekhyun ',
#  'peristiwa selanjutnya kita berkumpul lagi ya guys              ',
#  'semua nya tertawa lihat tingkah nya sehun tim produksi nya juga  kyungsoo aja sampai sesak nafas benar kata kai kalo sehun selalu jadi diri nya sendiri alias selalu jadi raja di antara kakaknya  nya       ',
#  'dilakukan untuk baekhyun  ',
#  'saya pikir kami memiliki waktu yg sangat baik menunggu itu sulit tapi sambil mengenang masamasa kita bahagia  mari bersiapsiap untuk bertemu lagi kalau begitu ayo bertemu secepatnya meski hanya sehari aku mencintaimu exol    ',
#  ' pilih untuk baekhyun   ',
#  'dari pameran debut hingga konser saya merasa bahagia saya juga menantikan smtown dimana saya bisa bertemu semua orang semoga tetap sehat sampai hari kita bertemu ini adalah sebuah janji selamat tinggal    ',
#  ' pilih untuk baekhyun   ',
#  'selamat hari jadi exo cbx kesayangan aku   ',
#  'exo tiap debut kembali nya beda beda ga heran sih kalo exol tahan banting semua  ',
#  'kamu ganteng bgt mas   ',
#  'exocbx jepang debut 5 th hari jadi  semoga kalian cepat kembali setelah baekhyun selesai wajib militer ya        ',
#  '220524  update   pesan dari xiumin  exocbx 5 th selamat hari jadi debut di japan  ',
#  '   baekhyun  amp',
#  'dilakukan untuk exo baekhyun    ',
#  'senang banget kebetulan nya benar benar gila aku kirim pesan sekitar 4 menit sebelum di unggah sama suho gatau dia benar benar perhatiin aku atau ngga tapi kaya aneh aja gitu pas banget minta foto selfie kalo ini benaran tolong suho baik banget',
#  'sesuatu yg kalo diceritakan dg lagu sedih bikin nangis kalo dinikmati dg musiknya  permission to dance atau  dont fight the feeling jadinya hangat dan menyenangkan beberapa orang bilang apa untungnya jadi pecandu drama korea and pecinta musik korea bagi aku adalah caraku penyembuhan',
#  'sehun x diorerl    ',
#  'loh  balik ke incheon dulu toh aku kira langsung dubai   ',
#  'suho telah terbang  dubai  japan usa ke seoul   ',
#  'aku terpikat pada tuturmu aku tersihir jiwamu terkagum pada pandangmu  caramu melihat dunia  ',
#  '170527 kai  the exordium di seoul iconic    ',
#  'lihat kalian kumpul gini kok senang banget yaa sehatsehat terus kalian     ',
#  'ini aura aktornya sehun jadinya mirip bgt sama yoo yeonseok     ',
#  '220523 china mencapai puncak baru menempati peringkat 6 dalam daftar top 10 pasar musik di dunia  pada pembaruan 2021 menurut ifpi exo adalah puncak 1 dalam daftar yg membantu pasar cina           ',
#  ' telah terbang ke seoul  dubai    seoul  dm ',
#  'berhubung tim keuangan ace akan jeda sementara di bawah adalah detail hasil donasi  kjm2    terimakasih semua untuk semua donatur dan juga tim streaming  sampai jumpai di projek selanjutnya ',
#  '220522 ig musik kok unggah perbaruan dengan     kita pakai baju yang sama tanpa disengaja  sebelum kita kelelahan terima kasih untuk pelatih yang mengajarkan kita',
#  'paling suka sama lagu ini  membayangkan exo nyanyi ini secara langsung  seperti biasa  ',
#  'bentar lagi juni bulannya dont fight for then feeling   no matter by  ',
#  'jaehyuk of   baekhyun of  renjun yangyang and jisung of ',
#  'udah mau setahun aja  runaway by  ',
#  'exol ayok mutualan kuy kuy kuy mari kita saling berkawan besti   ',
#  'diperbarui juga maknae palsu xiumin dan exo  ',
#  'eri ayo semangat dukung baekhyun jarak nya tipis',
#  'vitamin xiu ini bakalan bertahan berapa lama ya  vitamin xiu ini buat berapa minggu berapa bulan  kapan xiumin perbarui lagi',
#  'masternim kai yg masih aktif siapa aja ya selain aumicky   ',
#  'member exo lagi pada kangen kah ',
#  'ternyata foto ini yg perbarui sehun aku kira dari smc amp',
#  'masih banyak bermunculan di sosial media intip perjalanan cinta jennie blackpink pernah dekat sama kai exo hingga v bts',
#  'nego aja guys masih mulus isi lengkap  ',
#  'memilih untuk baekhyun  ',
#  'memilih untuk baekhyun   ',
#  'suho terbang ke  dubai  jepang   usa ke seoul   ',
#  '220523 ooh sehun instragram   sehun memperbarui foto bersama suho dan member exo',
#  'nih orang fotonya tuh simpel dan biasa tapi selalu kelihatan bagus feed instagram nya pun rapi dan estetik  ',
#  'sehun instagram  imut imut imut   sayang banget sama kalian',
#  'suho dan sehun    ',
#  'ooh sehun lagi   ',
#  'katanya doa gaboleh ragu dan setengah setengah   ya tuhan jadikan salah seorang yang ada difoto ini jodoh saya terserah yang mana tuhan mau yang paling kanan atau paling kiri atau disamping yg paling kanan atau yg di samping paling kiri apalagi yg tengah  ',
#  '220523   suho instagram  sampai jumpa lagi    ',
#  ' memilih untuk baekhyun   ',
#  '141018 smtown di  shanghai             x0',
#  'exo adalah sembilan  kita satu exo saranghaja              ',
#  'ooh sehun      ',
#  '__        selamat ulang tahun semoga di tahun ini di beri kesehatan supaya bisa nyapa exol setiap hari  kita mencintaimu oppa selamat',
#  'ayok yg only aja mutualan tidak hijau ungu pink mejikuhibiniu khusus exol bukan multi atau solo stan grup lain  bantu rt bestie ',
#  'curiga aku pak jangan mau buat pabrik anggur juga   bangga kepadamu kimjunmyeon         ',
#  'jam jam kangen   semua akun yg dulu udah aku retweet atau suka harus diulang karena ini akun kedua yg kuingat sebelum pas akun pertama aku lupa  semoga ini bertahan lama  tapi kalo buat beri suara masih ada akun juga sih  disini lebih nyaman dari sosial media lainnya apalagi segi perbaruan',
#  'ini ketua pamer makanan mulu kan jadi pengen makan bareng    ',
#  'belum lihat episode ini tapi kayak do  xiumin yang udah gasabar ingin terjun disisi lain suho  kai yg belum siap terjun   ',
#  ' kai tolong jangan bikin aku cemburu   ',
#  'exo ladder musim ketiga besok episode terakhir          ',
#  'gak bisa nih gw seperti ini suho tanggung jawab lo tiap hari bikin anak orang gak waras         ',
#  'konser nya berpencar ya ini para peterpan ku      ',
#  'contoh makhluk tidak berotak yang dianugrahi bisa mengetik laporkan dan blokir jangan terlibat    ',
#  'ini benaran konser yg di dubai gratis ya allah kenapa ga indonesia aja sih          ',
#  'mau hidup waras kok susah banget ya   ',
#  'exo jeda sepi konten  exo jeda bikin exol mabok perbaruan dan visual tiap saat          ',
#  'mau ikutan trend tapi pocky kemahalan    ',
#  'junmyeon kayak anak yg terpaksa ikut ayahnya untuk ketemu klien    ',
#  'kenapa kalo lagu exo di cover ga dapet rasa nya ya kek lewat lewat aja gitu',
#  'tao adalah member yang paling sering menangis fakta exo',
#  'kangen masa dulu semangat buat promosi exo ada kabar langsung senang banget sekarang mau semangat buat promosi exo semangat hidup aja nggak ada',
#  'kayak nya makin banyak yg ninggal exo ya di linimasa udah dikit bgt yg promosi exo pada pindah kemana nih',
#  'asli deh padahal udah gua nyala semua notif nya instagram semua member exo tapi pas sehun sama jongin kemaren perbarui cerita instagram kenapa gaada pemberitahuan nya sih',
#  'tolong exo segera kembali sebelum aku terjatuh lebih jauh ke brondong dream ',
#  'baru sadar selama stan exo aku ga punya momen utama yang bikin aku suka banget ke sehun tentu saja aku promosi dan mendukung dia terus exo stan era  sedangkan aku punya momen itu ke member lain',
#  'padahal dulu suka banget nonton video konser suju shinee exo karena terasa nggak lipsync sekarang coba tonton konser idol sm rasa nya kurang greget aja gitu',
#  'harapan gua terlalu muluk kayak nya kalo liat exo kembali tahun ini apapun itu yang jelas gua kangen banget sama mereka']

# %%
#remove number
import re
data_no_number = []
for line in data_lower:
  result = re.sub(r'\d', '', line)
  data_no_number.append(result)

data_no_number
# Out:
# ['dilakukan untuk baekhyun ',
#  'peristiwa selanjutnya kita berkumpul lagi ya guys              ',
#  'semua nya tertawa lihat tingkah nya sehun tim produksi nya juga  kyungsoo aja sampai sesak nafas benar kata kai kalo sehun selalu jadi diri nya sendiri alias selalu jadi raja di antara kakak nya  nya       ',
#  'dilakukan untuk baekhyun  ',
#  'saya pikir kami memiliki waktu yg sangat baik menunggu itu sulit tapi sambil mengenang masamasa kita bahagia  mari bersiapsiap untuk bertemu lagi kalau begitu ayo bertemu secepatnya meski hanya sehari aku mencintaimu exol    ',
#  'sm entertainment kembali tambahkan nama lay ke profil resmi exo',
#  'exo berhasil menorehkan prestasi membanggakan salah satu nya yaitu mendapat sebutan nations pick dari warga korsel kesuksesan exo bukan semata berasal dari agensi besar namun juga karena bakat para member yang luar biasa selengkapnya klik link ini ya',
#  'kangen sehun banget kangen exo juga kangen kyungsoo',
#  'lagi kangen banget sama exo gatau kenapa mengulang semua drama yang ada exo nya  terus pas nonton do kyungsoo lucu banget',
#  'mau heran tapi ini exo diam aja tapi sering banget ada di puncak   jadi kapan nih kembali ',
#  'exo nih stabil banget loh peringkat  yg dimana kembali aja jarang  bangga',
#  'tujuan baekhyun di masa depan  aku ingin exo menjadi sejarah musik korea sehingga  tahun dari sekarang kami di ingat sebagai grup besar jika aku bisa aku ingin mencoba mendirikan program hiburan atau akting',
#  'exo bakal selalu jadi nomor  mereka punya tempat sendiri di hati dan gak mungkin terganti',
#  ' tapi jujur bridges nya exo tuh bagus bagus kayak nya hampir semua lagu bridges nya bikin merinding aku gak dengarin lagu yg batu tapi dari era tempo ke sebelumnya tuh mantap banget',
#  'lagi bayangin kalau exo nct svt sama treasure kumpul satu tempat rame nya macem mana ya ',
#  'tetap setia sama exo di era gempuran idol lain pada kembali',
#  'gue suka kpop gara gara  bts and exo  sejak  ',
#  ' luhan suho lay chanyeol baekhyun kyungsoo sehun kai  kebanyakan member exo udah terkenal dari sebelum debut',
#  'contoh makhluk tidak berotak yang dianugrahi bisa mengetik laporkan dan blokir jangan terlibat    ',
#  'ini benaran konser yg di dubai gratis ya allah kenapa ga indonesia aja sih          ',
#  'mau hidup waras kok susah banget ya   ',
#  'exo jeda sepi konten  exo jeda bikin exol mabok perbaruan dan visual tiap saat          ',
#  'mau ikutan trend tapi pocky kemahalan    ',
#  'junmyeon kayak anak yg terpaksa ikut ayahnya untuk ketemu klien    ',
#  'kenapa kalo lagu exo di cover ga dapet rasa nya ya kek lewat lewat aja gitu',
#  'tao adalah member yang paling sering menangis fakta exo',
#  'kangen masa dulu semangat buat promosi exo ada kabar langsung senang banget sekarang mau semangat buat promosi exo semangat hidup aja nggak ada',
#  'kayak nya makin banyak yg ninggal exo ya di linimasa udah dikit bgt yg promosi exo pada pindah kemana nih',
#  'asli deh padahal udah gua nyala semua notif nya instagram semua member exo tapi pas sehun sama jongin kemaren perbarui cerita instagram kenapa gaada pemberitahuan nya sih',
#  'tolong exo segera kembali sebelum aku terjatuh lebih jauh ke brondong dream ',
#  'baru sadar selama stan exo aku ga punya momen utama yang bikin aku suka banget ke sehun tentu saja aku promosi dan mendukung dia terus exo stan era  sedangkan aku punya momen itu ke member lain',
#  'padahal dulu suka banget nonton video konser suju shinee exo karena terasa nggak lipsync sekarang coba tonton konser idol sm rasa nya kurang greget aja gitu',
#  'harapan gua terlalu muluk kayak nya kalo liat exo kembali tahun ini apapun itu yang jelas gua kangen banget sama mereka']

# %%
#remove number
import re
data_no_number_pos = []
for line in data_lower_pos:
  result = re.sub(r'\d', '', line)
  data_no_number_pos.append(result)

#  'sm entertainment kembali tambahkan nama lay ke profil resmi exo',
#  'exo berhasil menorehkan prestasi membanggakan salah satu nya yaitu mendapat sebutan nations pick dari warga korsel kesuksesan exo bukan semata berasal dari agensi besar namun juga karena bakat para member yang luar biasa selengkapnya klik link ini ya',
#  'kangen sehun banget kangen exo juga kangen kyungsoo',
#  'lagi kangen banget sama exo gatau kenapa mengulang semua drama yang ada exo nya  terus pas nonton do kyungsoo lucu banget',
#  'mau heran tapi ini exo diam aja tapi sering banget ada di puncak   jadi kapan nih kembali ',
#  'exo nih stabil banget loh peringkat  yg dimana kembali aja jarang  bangga',
#  'tujuan baekhyun di masa depan  aku ingin exo menjadi sejarah musik korea sehingga  tahun dari sekarang kami di ingat sebagai grup besar jika aku bisa aku ingin mencoba mendirikan program hiburan atau akting',
#  'exo bakal selalu jadi nomor  mereka punya tempat sendiri di hati dan gak mungkin terganti',
#  ' tapi jujur bridges nya exo tuh bagus bagus kayak nya hampir semua lagu bridges nya bikin merinding aku gak dengarin lagu yg batu tapi dari era tempo ke sebelumnya tuh mantap banget',
#  'lagi bayangin kalau exo nct svt sama treasure kumpul satu tempat rame nya macem mana ya ',
#  'tetap setia sama exo di era gempuran idol lain pada kembali',
#  'gue suka kpop gara gara  bts and exo  sejak  ',
#  ' luhan suho lay chanyeol baekhyun kyungsoo sehun kai  kebanyakan member exo udah terkenal dari sebelum debut']

# %%
#remove number
import re
data_no_number_neg = []
for line in data_lower_neg:
  result = re.sub(r'\d', '', line)
  data_no_number_neg.append(result)

data_no_number_neg
# Out:
# ['lucu banget liat kai marah gegara eribong di sembunyi kyungsoo  kyungsoo juga berperilaku polos  sehun sampai memperhatikan hyung nya marah     ',
#  'tidak sabar menanti kji  tapi tunggu itu berarti enlist semakin dekat   ',
#  'beri suara baekhyun di tta yuk eri ayo keluarin lagi mode beri suara monsternya     ',
#  'pesan suara dari  untuk  th hari jadi debut exo cbx di jepang cr chenniepii       miss you chen ',
#  'biasa mendapat tinjauan harian chanyeol tiap hari padahal baru beberapa hari gak muncul udah berasa setahun gak muncul  chanyeol jam segini lagi ngapain ya masih libur atau udah balik ke barak     ',
#  'kimjunmyeon sudah sampai di korea  gak lama di korea bakal pergi ke dubai lagi   istirahat yg cukup ya myeonnie    ',
#  ' hari sampai baekhyun s dipulangkan     ',
#  ' karena anginrambutku menjadi seperti ini photo slide   aku akan mengirimi kalian video begitu aku sampai di dubai   selamat tinggal       ',
#  'kabarin dong kalo lagi kenapa tuh jangan menghilang terus     ',
#  'tutup aurora nya bang   ',
#  'ada badut apaan sih lay suho   ',
#  'ketika lay merindukan peristiwa itu aku dan exol lainnya pun sangat  merindukan peristiwa itu juga ',
#  'exol bangun yuk fokus idol kita jangan ikut campur urusan idol lain  bantu rnb guys  ',
#  'exol mutual yuk bantu retweet juga selektif   ',
#  'exol ingatkah istilah bukan idol kamu bukan urusan kamu yuk fokus exo jangan ikut campur atas masalah idol lain ingat jangan sampai jadi berbalik ke kita abaikan kasus garam atau kencan itu ya kembali ke idol kalo masih mau ikutan ganti foto pribadi aja dulu ',
#  'asli deh padahal udah gua nyala semua notif nya instagram semua member exo tapi pas sehun sama jongin kemaren perbarui cerita instagram kenapa gaada pemberitahuan nya sih',
#  'tolong exo segera kembali sebelum aku terjatuh lebih jauh ke brondong dream ',
#  'baru sadar selama stan exo aku ga punya momen utama yang bikin aku suka banget ke sehun tentu saja aku promosi dan mendukung dia terus exo stan era  sedangkan aku punya momen itu ke member lain',
#  'padahal dulu suka banget nonton video konser suju shinee exo karena terasa nggak lipsync sekarang coba tonton konser idol sm rasa nya kurang greget aja gitu',
#  'harapan gua terlalu muluk kayak nya kalo liat exo kembali tahun ini apapun itu yang jelas gua kangen banget sama mereka']

# %%
#remove whitespace
data_no_whitespace = []
for line in data_no_number:
  if len(line.split()) > 1:
    result = ' '.join(line.split())
    data_no_whitespace.append(result)

data_no_whitespace
# Out:
# ['dilakukan untuk baekhyun',
#  'peristiwa selanjutnya kita berkumpul lagi ya guys',
#  'semua nya tertawa lihat tingkah nya sehun tim produksi nya juga kyungsoo aja sampai sesak nafas benar kata kai kalo sehun selalu jadi diri nya sendiri alias selalu jadi raja di antara kakak nya nya',
#  'dilakukan untuk baekhyun',
#  'saya pikir kami memiliki waktu yg sangat baik menunggu itu sulit tapi sambil mengenang masamasa kita bahagia mari bersiapsiap untuk bertemu lagi kalau begitu ayo bertemu secepatnya meski hanya sehari aku mencintaimu exol',
#  'pilih untuk baekhyun',
#  'dari pameran debut hingga konser saya merasa bahagia saya juga menantikan smtown dimana saya bisa bertemu semua orang semoga tetap sehat sampai hari kita bertemu ini adalah sebuah janji selamat tinggal',
#  'pilih untuk baekhyun',
#  'selamat hari jadi exo cbx kesayangan aku',
#  'exo tiap debut kembali nya beda beda ga heran sih kalo exol tahan banting semua',
#  'kamu ganteng bgt mas',
#  'exocbx jepang debut th hari jadi semoga kalian cepat kembali setelah baekhyun selesai wajib militer ya',
#  'update pesan dari xiumin exocbx th selamat hari jadi debut di japan',
#  'baekhyun amp',
#  'dilakukan untuk exo baekhyun',
#  'senang banget kebetulan nya benar benar gila aku kirim pesan sekitar menit sebelum di unggah sama suho gatau dia benar benar perhatiin aku atau ngga tapi kaya aneh aja gitu pas banget minta foto selfie kalo ini benaran tolong suho baik banget',
#  'sesuatu yg kalo diceritakan dg lagu sedih bikin nangis kalo dinikmati dg musiknya permission to dance atau dont fight the feeling jadinya hangat dan menyenangkan beberapa orang bilang apa untungnya jadi pecandu drama korea and pecinta musik korea bagi aku adalah caraku penyembuhan',
#  'sehun x diorerl',
#  'loh balik ke incheon dulu toh aku kira langsung dubai',
#  'suho telah terbang dubai japan usa ke seoul',
#  'aku terpikat pada tuturmu aku tersihir jiwamu terkagum pada pandangmu caramu melihat dunia',
#  'kai the exordium di seoul iconic',
#  'lihat kalian kumpul gini kok senang banget yaa sehatsehat terus kalian',
#  'ini aura aktornya sehun jadinya mirip bgt sama yoo yeonseok',
#  'china mencapai puncak baru menempati peringkat dalam daftar top pasar musik di dunia pada pembaruan menurut ifpi exo adalah puncak dalam daftar yg membantu pasar cina',
#  'telah terbang ke seoul dubai seoul dm',
#  'berhubung tim keuangan ace akan jeda sementara di bawah adalah detail hasil donasi kjm terimakasih semua untuk semua donatur dan juga tim streaming sampai jumpai di projek selanjutnya',
#  'ig musik kok unggah perbaruan dengan kita pakai baju yang sama tanpa disengaja sebelum kita kelelahan terima kasih untuk pelatih yang mengajarkan kita',
#  'paling suka sama lagu ini membayangkan exo nyanyi ini secara langsung seperti biasa',
#  'bentar lagi juni bulannya dont fight for then feeling no matter by',
#  'jaehyuk of baekhyun of renjun yangyang and jisung of',
#  'udah mau setahun aja runaway by',
#  'exol ayok mutualan kuy kuy kuy mari kita saling berkawan besti',
#  'diperbarui juga maknae palsu xiumin dan exo',
#  'eri ayo semangat dukung baekhyun jarak nya tipis',
#  'vitamin xiu ini bakalan bertahan berapa lama ya vitamin xiu ini buat berapa minggu berapa bulan kapan xiumin perbarui lagi',
#  'masternim kai yg masih aktif siapa aja ya selain aumicky',
#  'member exo lagi pada kangen kah',
#  'ternyata foto ini yg perbarui sehun aku kira dari smc amp',
#  'masih banyak bermunculan di sosial media intip perjalanan cinta jennie blackpink pernah dekat sama kai exo hingga v bts',
#  'nego aja guys masih mulus isi lengkap',
#  'memilih untuk baekhyun',
#  'memilih untuk baekhyun',
#  'suho terbang ke dubai jepang usa ke seoul',
#  'ooh sehun instragram sehun memperbarui foto bersama suho dan member exo',
#  'nih orang fotonya tuh simpel dan biasa tapi selalu kelihatan bagus feed instagram nya pun rapi dan estetik',
#  'sehun instagram imut imut imut sayang banget sama kalian',
#  'suho dan sehun',
#  'ooh sehun lagi',
#  'katanya doa gaboleh ragu dan setengah setengah ya tuhan jadikan salah seorang yang ada difoto ini jodoh saya terserah yang mana tuhan mau yang paling kanan atau paling kiri atau disamping yg paling kanan atau yg di samping paling kiri apalagi yg tengah',
#  'suho instagram sampai jumpa lagi',
#  'memilih untuk baekhyun',
#  'smtown di shanghai x',
#  'exo adalah sembilan kita satu exo saranghaja',
#  'ooh sehun',
#  '__ selamat ulang tahun semoga di tahun ini di beri kesehatan supaya bisa nyapa exol setiap hari kita mencintaimu oppa selamat',
#  'ooh berusaha menstabilkan pikiran ini',
#  'selamat ulang tahun suho terimakasih sudah menjadi ayah buat exo sehat ya dan sukses di karir solo maupun di grup',
#  'tahu aja kalo exol habis kena drama makasih sehun',
#  'ooh sehun',
#  'selamat ulang tahun suho',
#  'selamat ulang tahun suho',
#  'selamat ulang tahun ketua kita terimakasih sudah bekerja keras selama ini sehat selalu ya dan mari kita bertemu di masa depan terimakasih amp',
#  'aku dengar dari nadanya kayak lagu exo judulnya playboy ya gak sih',
#  'hemm iya tahu ganteng kok',
#  'nah kalo ini kumpulan barang siap sedia alias tersedia alias ls list officialunoff oriofficial unoff ada yang oriofficial ada yg ngga',
#  'tiap pencarian deg deg an terus takut kurang pas tau senang poll',
#  'oh iya ya bisa jadi sih karena mau ganti bagian agensi lagian sm hiburan senang banget bikin acara tibatiba begitu wkwk',
#  'exol memilih untuk baekhyun',
#  'hampir lupa ini bukti tangkapan layar hari ini suho grey suit dday _greysuit_pm',
#  'ya allah hun kamu ganteng banget sih coba sini kasih tau siapa yang bisa kalahin kegantengan tuan muda oh sehun',
#  'aktivitas baru kris wu jadi sedang trend apakah kris wu sudah bebas',
#  'selamat ulang tahun kepada suho ketua super kita',
#  'menurut akun twitter hallyu pop fest london mereka menginfokan bahwa video pesan artis untuk chen akan segera hadir',
#  'tapi lay bertanya apakah kamu mau dan mencoba membagikan popcorn kepada orangorang di sekitarnya',
#  'happy birthday mas junmyeon terima kasih telah menjadi salah warna di kehidupanku aku berharap mas junmyeon selalu bahagia apapun hal yang dilakukan menikmati hari bersama orang tersayang kimjunmyeon',
#  'selamat ulang tahun suho mumpung ulang tahunnya barengan jadi beli satu kue aja wkwkwk __',
#  'jangan lupa memilih baekhyun di tta',
#  'suho terbang ke dubai jepang c usa to seoul',
#  'maudy aja bisa nikah sama marga choi kayak nya aku juga bisa nikah sama marga kim deh',
#  'memilih untuk baekhyun',
#  'jangan lupa milih baekhyun exol memilih baekhyun di tta exol pilihlah baekhyun di tta exol memilih baekhyun di tta',
#  'udah yuk balik fokus sama idol kita tercinta promosi exomember aja lebih utama',
#  'udah ah daripada mengurus perang saja kembali ke exo lagi exo lebih dari segalanya exol terbaik',
#  'karena kebanyakan yg no aku pilih dvd kive japan aja deh selamat ulang tahun suho __',
#  'meninjau drama korea days my prince do exo dan namjihyun jadi tokoh utama',
#  'terima kasih sudah menjadi ketua exo terima kasih sudah menjaga member exo __',
#  'papi suho terima kasih sudah lahir terima kasih telah menjadi bagian exo dan smtown terima kasih sudah membuat lagu yang bagus __',
#  'selamat ulang tahun ketua kami kimjunmyeon terima kasih untuk perjuangan kamu selama ini dan terima kasih selalu mengingat kami exol dimana pun kamu berada __',
#  'selamat ulang tahun leader terhebat sehat dan kuat selalu aku masih sama dan akan tetap sama yang akan selalu mendukung mu menunggumu dengan semua yang akan kau lakukan',
#  'selamat ulang tahun ketua kesayangan aeri',
#  'selain kencang kencangan perang jangan lupa pilih yg kencang juga baekhyun ya bestie',
#  'selesai semua aturan mau album greysuit min bapak suho itu selalu tampak keren di semua foto cuman kalo ditambah dengan kacamata hitam makin nambah ganteng nya',
#  'maaf ya aku tim exol only bukan aku juga exol',
#  'selamat hari suho sehat sehat selalu __',
#  'selamat ulang tahun buat kamu suho tersayang aku selalu mengharapkan yang terbaik untukmu',
#  'selamar hari suho terimakasih sudah menjadi ketua yang baikpendengar yang baikorang yang amat sangat baik semoga kamu selalu mendapatkan semua hal hal baik dalam hidupaku mencintaimu',
#  'selamat ulang tahun bapak ketua ganteng estetik sekali',
#  'exo itu walaupun anggota exo mulai sibuk dengan kegiatan mereka tapi buat kita exol exo tetap sembilan tetap dukung member kesayangan kita',
#  'selamat ulang tahun kimjunmyeon sehat selalu makan yang banyak karena kamu kelihatan kurus selama promosi grey suit terima kasih sudah menjadi bagian dari kebahagiaan exol dan selalu menjadi kebanggaan kami love you',
#  'my trinity bias kemarin ditinggal wajib militer barengan tahun ini mereka pulang barengan juga',
#  'sehun di la',
#  'sehun ada di la sekarang',
#  'pilih baekhyun',
#  'iya siapa lagi kai exo',
#  'wts kartu foto baekhyun exo expan baekhyun hanya tempat perhiasa jaemin hanya dom bandung bisa menjaga acara condi bisa dm bisa satuan pilihan bijak',
#  'selamat ulang tahun peterpanku aku harap kebaikan selalu bersamamu tetap menetap hingga aku menemukan peterpan di dunia nyataku mari mencintai untuk waktu yg lebih lama',
#  'mau cari mutual exol dan sijeuni yuk yuk mutualan',
#  'suho exo bahas peran di grup tak anggap diri sendiri sosok penting meski ketua',
#  'drama korea yang dibintangi oleh do exo dan pratinjau decolsin obat batuk dan flu',
#  'ini namanya perasaan nya dapet mereka karena sudah menjiwai tapi kalo ingat pertunjukan overdose tuh pas hyung loey lupa koreografi dg percaya diri nya ke depan hingga meninggalkan do di belakang koreografi sendirian',
#  'saya menjual miraclesindecember the winter special album seharga rp ayo beli di shopee',
#  'senang banget lihat begini semoga bahagia terus di sana bang suho cinta kamu',
#  'kita satu exo versi ketengan dulu bunda versi lengkap harap bersabar',
#  'bapak ketua aktif banget gue jadi pengen liburan jg ajak aku liburan bang jumyeon',
#  'si paling estetik',
#  'lucu banget liat kai marah gegara eribong di sembunyi kyungsoo kyungsoo juga berperilaku polos sehun sampai memperhatikan hyung nya marah',
#  'tidak sabar menanti kji tapi tunggu itu berarti enlist semakin dekat',
#  'beri suara baekhyun di tta yuk eri ayo keluarin lagi mode beri suara monsternya',
#  'pesan suara dari untuk th hari jadi debut exo cbx di jepang cr chenniepii miss you chen',
#  'biasa mendapat tinjauan harian chanyeol tiap hari padahal baru beberapa hari gak muncul udah berasa setahun gak muncul chanyeol jam segini lagi ngapain ya masih libur atau udah balik ke barak',
#  'kimjunmyeon sudah sampai di korea gak lama di korea bakal pergi ke dubai lagi istirahat yg cukup ya myeonnie',
#  'hari sampai baekhyun s dipulangkan',
#  'karena anginrambutku menjadi seperti ini photo slide aku akan mengirimi kalian video begitu aku sampai di dubai selamat tinggal',
#  'kabarin dong kalo lagi kenapa tuh jangan menghilang terus',
#  'tutup aurora nya bang',
#  'ada badut apaan sih lay suho',
#  'ketika lay merindukan peristiwa itu aku dan exol lainnya pun sangat merindukan peristiwa itu juga',
#  'exol bangun yuk fokus idol kita jangan ikut campur urusan idol lain bantu rnb guys',
#  'exol mutual yuk bantu retweet juga selektif',
#  'exol ingatkah istilah bukan idol kamu bukan urusan kamu yuk fokus exo jangan ikut campur atas masalah idol lain ingat jangan sampai jadi berbalik ke kita abaikan kasus garam atau kencan itu ya kembali ke idol kalo masih mau ikutan ganti foto pribadi aja dulu',
#  'yuk fokus eri idol kita exo loh jangan ikut campur',
#  'yuk yg merasa exol fokus sama exo aja jangan ikut campur amp',
#  'belum lama ini diketahui nama lay telah dihapus dari profil exo oleh sm entertainment hal ini menyebabkan banyaknya protes yang datang dari penggemar pasal nya walaupun sudah bukan bagian dari sm entertainment lay sendiri menyatakan bahwa dirinya masih bagian dari exo',
#  'exo bakal selalu jadi nomor mereka punya tempat sendiri di hati dan gak mungkin terganti',
#  'tapi jujur bridges nya exo tuh bagus bagus kayak nya hampir semua lagu bridges nya bikin merinding aku gak dengarin lagu yg batu tapi dari era tempo ke sebelumnya tuh mantap banget',
#  'lagi bayangin kalau exo nct svt sama treasure kumpul satu tempat rame nya macem mana ya',
#  'tetap setia sama exo di era gempuran idol lain pada kembali',
#  'gue suka kpop gara gara bts and exo sejak',
#  'luhan suho lay chanyeol baekhyun kyungsoo sehun kai kebanyakan member exo udah terkenal dari sebelum debut',
#  'contoh makhluk tidak berotak yang dianugrahi bisa mengetik laporkan dan blokir jangan terlibat',
#  'ini benaran konser yg di dubai gratis ya allah kenapa ga indonesia aja sih',
#  'mau hidup waras kok susah banget ya',
#  'exo jeda sepi konten exo jeda bikin exol mabok perbaruan dan visual tiap saat',
#  'mau ikutan trend tapi pocky kemahalan',
#  'junmyeon kayak anak yg terpaksa ikut ayahnya untuk ketemu klien',
#  'kenapa kalo lagu exo di cover ga dapet rasa nya ya kek lewat lewat aja gitu',
#  'tao adalah member yang paling sering menangis fakta exo',
#  'kangen masa dulu semangat buat promosi exo ada kabar langsung senang banget sekarang mau semangat buat promosi exo semangat hidup aja nggak ada',
#  'kayak nya makin banyak yg ninggal exo ya di linimasa udah dikit bgt yg promosi exo pada pindah kemana nih',
#  'asli deh padahal udah gua nyala semua notif nya instagram semua member exo tapi pas sehun sama jongin kemaren perbarui cerita instagram kenapa gaada pemberitahuan nya sih',
#  'tolong exo segera kembali sebelum aku terjatuh lebih jauh ke brondong dream',
#  'baru sadar selama stan exo aku ga punya momen utama yang bikin aku suka banget ke sehun tentu saja aku promosi dan mendukung dia terus exo stan era sedangkan aku punya momen itu ke member lain',
#  'padahal dulu suka banget nonton video konser suju shinee exo karena terasa nggak lipsync sekarang coba tonton konser idol sm rasa nya kurang greget aja gitu',
#  'harapan gua terlalu muluk kayak nya kalo liat exo kembali tahun ini apapun itu yang jelas gua kangen banget sama mereka']

# %%
#remove whitespace
data_no_whitespace_pos = []
for line in data_no_number_pos:
  if len(line.split()) > 1:
    result = ' '.join(line.split())
    data_no_whitespace_pos.append(result)

data_no_whitespace_pos
# Out:
# ['dilakukan untuk baekhyun',
#  'peristiwa selanjutnya kita berkumpul lagi ya guys',
#  'semua nya tertawa lihat tingkah nya sehun tim produksi nya juga kyungsoo aja sampai sesak nafas benar kata kai kalo sehun selalu jadi diri nya sendiri alias selalu jadi raja di antara kakaknya nya',
#  'dilakukan untuk baekhyun',
#  'saya pikir kami memiliki waktu yg sangat baik menunggu itu sulit tapi sambil mengenang masamasa kita bahagia mari bersiapsiap untuk bertemu lagi kalau begitu ayo bertemu secepatnya meski hanya sehari aku mencintaimu exol',
#  'pilih untuk baekhyun',
#  'dari pameran debut hingga konser saya merasa bahagia saya juga menantikan smtown dimana saya bisa bertemu semua orang semoga tetap sehat sampai hari kita bertemu ini adalah sebuah janji selamat tinggal',
#  'pilih untuk baekhyun',
#  'selamat hari jadi exo cbx kesayangan aku',
#  'exo tiap debut kembali nya beda beda ga heran sih kalo exol tahan banting semua',
#  'kamu ganteng bgt mas',
#  'exocbx jepang debut th hari jadi semoga kalian cepat kembali setelah baekhyun selesai wajib militer ya',
#  'update pesan dari xiumin exocbx th selamat hari jadi debut di japan',
#  'baekhyun amp',
#  'dilakukan untuk exo baekhyun',
#  'senang banget kebetulan nya benar benar gila aku kirim pesan sekitar menit sebelum di unggah sama suho gatau dia benar benar perhatiin aku atau ngga tapi kaya aneh aja gitu pas banget minta foto selfie kalo ini benaran tolong suho baik banget',
#  'sesuatu yg kalo diceritakan dg lagu sedih bikin nangis kalo dinikmati dg musiknya permission to dance atau dont fight the feeling jadinya hangat dan menyenangkan beberapa orang bilang apa untungnya jadi pecandu drama korea and pecinta musik korea bagi aku adalah caraku penyembuhan',
#  'sehun x diorerl',
#  'loh balik ke incheon dulu toh aku kira langsung dubai',
#  'suho telah terbang dubai japan usa ke seoul',
#  'aku terpikat pada tuturmu aku tersihir jiwamu terkagum pada pandangmu caramu melihat dunia',
#  'kai the exordium di seoul iconic',
#  'lihat kalian kumpul gini kok senang banget yaa sehatsehat terus kalian',
#  'ini aura aktornya sehun jadinya mirip bgt sama yoo yeonseok',
#  'china mencapai puncak baru menempati peringkat dalam daftar top pasar musik di dunia pada pembaruan menurut ifpi exo adalah puncak dalam daftar yg membantu pasar cina',
#  'telah terbang ke seoul dubai seoul dm',
#  'berhubung tim keuangan ace akan jeda sementara di bawah adalah detail hasil donasi kjm terimakasih semua untuk semua donatur dan juga tim streaming sampai jumpai di projek selanjutnya',
#  'ig musik kok unggah perbaruan dengan kita pakai baju yang sama tanpa disengaja sebelum kita kelelahan terima kasih untuk pelatih yang mengajarkan kita',
#  'paling suka sama lagu ini membayangkan exo nyanyi ini secara langsung seperti biasa',
#  'bentar lagi juni bulannya dont fight for then feeling no matter by',
#  'jaehyuk of baekhyun of renjun yangyang and jisung of',
#  'udah mau setahun aja runaway by',
#  'exol ayok mutualan kuy kuy kuy mari kita saling berkawan besti',
#  'diperbarui juga maknae palsu xiumin dan exo',
#  'eri ayo semangat dukung baekhyun jarak nya tipis',
#  'vitamin xiu ini bakalan bertahan berapa lama ya vitamin xiu ini buat berapa minggu berapa bulan kapan xiumin perbarui lagi',
#  'masternim kai yg masih aktif siapa aja ya selain aumicky',
#  'member exo lagi pada kangen kah',
#  'ternyata foto ini yg perbarui sehun aku kira dari smc amp',
#  'masih banyak bermunculan di sosial media intip perjalanan cinta jennie blackpink pernah dekat sama kai exo hingga v bts',
#  'nego aja guys masih mulus isi lengkap',
#  'memilih untuk baekhyun',
#  'memilih untuk baekhyun',
#  'suho terbang ke dubai jepang usa ke seoul',
#  'ooh sehun instragram sehun memperbarui foto bersama suho dan member exo',
#  'nih orang fotonya tuh simpel dan biasa tapi selalu kelihatan bagus feed instagram nya pun rapi dan estetik',
#  'sehun instagram imut imut imut sayang banget sama kalian',
#  'suho dan sehun',
#  'ooh sehun lagi',
#  'katanya doa gaboleh ragu dan setengah setengah ya tuhan jadikan salah seorang yang ada difoto ini jodoh saya terserah yang mana tuhan mau yang paling kanan atau paling kiri atau disamping yg paling kanan atau yg di samping paling kiri apalagi yg tengah',
#  'suho instagram sampai jumpa lagi',
#  'memilih untuk baekhyun',
#  'smtown di shanghai x',
#  'exo adalah sembilan kita satu exo saranghaja',
#  'ooh sehun',
#  '__ selamat ulang tahun semoga di tahun ini di beri kesehatan supaya bisa nyapa exol setiap hari kita mencintaimu oppa selamat',
#  'ooh berusaha menstabilkan pikiran ini',
#  'selamat ulang tahun suho terimakasih sudah menjadi ayah buat exo sehat ya dan sukses di karir solo maupun di grup',
#  'tahu aja kalo exol habis kena drama makasih sehun',
#  'ooh sehun',
#  'selamat ulang tahun suho',
#  'selamat ulang tahun suho',
#  'selamat ulang tahun ketua kita terimakasih sudah bekerja keras selama ini sehat selalu ya dan mari kita bertemu di masa depan terimakasih amp',
#  'aku dengar dari nadanya kayak lagu exo judulnya playboy ya gak sih',
#  'hemm iya tahu ganteng kok',
#  'nah kalo ini kumpulan barang siap sedia alias tersedia alias ls list officialunoff oriofficial unoff ada yang oriofficial ada yg ngga',
#  'tiap pencarian deg deg an terus takut kurang pas tau senang poll',
#  'oh iya ya bisa jadi sih karena mau ganti bagian agensi lagian sm hiburan senang banget bikin acara tibatiba begitu wkwk',
#  'exol memilih untuk baekhyun',
#  'hampir lupa ini bukti tangkapan layar hari ini suho grey suit dday _greysuit_pm',
#  'ya allah hun kamu ganteng banget sih coba sini kasih tau siapa yang bisa kalahin kegantengan tuan muda oh sehun',
#  'aktivitas baru kris wu jadi sedang trend apakah kris wu sudah bebas',
#  'selamat ulang tahun kepada suho ketua super kita',
#  'menurut akun twitter hallyu pop fest london mereka menginfokan bahwa video pesan artis untuk chen akan segera hadir',
#  'tapi lay bertanya apakah kamu mau dan mencoba membagikan popcorn kepada orangorang di sekitarnya',
#  'happy birthday mas junmyeon terima kasih telah menjadi salah warna di kehidupanku aku berharap mas junmyeon selalu bahagia apapun hal yang dilakukan menikmati hari bersama orang tersayang kimjunmyeon',
#  'selamat ulang tahun suho mumpung ulang tahunnya barengan jadi beli satu kue aja wkwkwk __',
#  'jangan lupa memilih baekhyun di tta',
#  'suho terbang ke dubai jepang c usa to seoul',
#  'maudy aja bisa nikah sama marga choi kayak nya aku juga bisa nikah sama marga kim deh',
#  'memilih untuk baekhyun',
#  'jangan lupa milih baekhyun exol memilih baekhyun di tta exol pilihlah baekhyun di tta exol memilih baekhyun di tta',
#  'udah yuk balik fokus sama idol kita tercinta promosi exomember aja lebih utama',
#  'udah ah daripada mengurus perang saja kembali ke exo lagi exo lebih dari segalanya exol terbaik',
#  'karena kebanyakan yg no aku pilih dvd kive japan aja deh selamat ulang tahun suho __',
#  'meninjau drama korea days my prince do exo dan namjihyun jadi tokoh utama',
#  'terima kasih sudah menjadi ketua exo terima kasih sudah menjaga member exo __',
#  'salah satu kebanggaan jadi exol sikap nya exo',
#  'yok exo keliling dunia lagi yok suho sudah banyak kemajuan nih',
#  'aku bangga banget sama suho',
#  'raja kai',
#  'raja kai',
#  'raja jongin',
#  'suho juga sma kayak kita guys habisin waktu nya nonton vidio di tiktok sama youtube',
#  'bangga bgt gw sama bapak suho yg tidak berhenti buat bangga exo dan exol',
#  'hari ini dimabuk banget upadate barengan woii',
#  'apa nih kira akan ada kegiatan apa lagi',
#  'sederhana tapi udah senang bgt cinta banyak banyak untuk exo tahan bentar lagi',
#  'dah lama banget pengen buat chibi si teman kita yg satu ini dan akhirnya terwujud jg',
#  'spesial collab sepertinya ada nama kai di botol nya siapa yg mau borong boleh lah bagi mimin',
#  'saya menjual album exomiraclesindecember cinasver seharga rp ayo beli di shopee',
#  'saya menjual album exo sc whatalife seharga rp ayo beli di shopee',
#  'saya menjual pc suho exo album tempo seharga rp ayo beli di shopee',
#  'wts album exo hanya loveshot album poster detail bisa lihat di link di bawah ini',
#  'di tunggu penampilannya',
#  'chanyeol instagram hari ini',
#  'halloaku udah buat daftar lagu khusus dari rekomendasi kyungsoo di bubble dan yg pernah disebut langsung sama dia selamat menikmati',
#  'suho sehun and chanyeol x',
#  'chanyeo instagram mumpung belum tutup ya bang di samperin',
#  'cerita instagram hari ini omg chanyeol pergi ke cafioca',
#  'sehun ke acara dior di la baru jam pagi sedangkan seoul udah jam petang acara dior jam malam waktu la dan masih lebih dari jam sebelum acara dimulai',
#  'sehun di la',
#  'sehun ada di la sekarang',
#  'pilih baekhyun',
#  'iya siapa lagi kai exo',
#  'wts kartu foto baekhyun exo expan baekhyun hanya tempat perhiasa jaemin hanya dom bandung bisa menjaga acara condi bisa dm bisa satuan pilihan bijak',
#  'selamat ulang tahun peterpanku aku harap kebaikan selalu bersamamu tetap menetap hingga aku menemukan peterpan di dunia nyataku mari mencintai untuk waktu yg lebih lama',
#  'mau cari mutual exol dan sijeuni yuk yuk mutualan',
#  'suho exo bahas peran di grup tak anggap diri sendiri sosok penting meski ketua',
#  'drama korea yang dibintangi oleh do exo dan pratinjau decolsin obat batuk dan flu',
#  'ini namanya perasaan nya dapet mereka karena sudah menjiwai tapi kalo ingat pertunjukan overdose tuh pas hyung loey lupa koreografi dg percaya diri nya ke depan hingga meninggalkan do di belakang koreografi sendirian',
#  'saya menjual miraclesindecember the winter special album seharga rp ayo beli di shopee',
#  'senang banget lihat begini semoga bahagia terus di sana bang suho cinta kamu',
#  'kita satu exo versi ketengan dulu bunda versi lengkap harap bersabar',
#  'bapak ketua aktif banget gue jadi pengen liburan jg ajak aku liburan bang jumyeon',
#  'si paling estetik',
#  'instagram kimjuncotton pembaruan kiriman senang bertemu denganmu seni membuat dunia berputar musik membuat dunia berputar',
#  'sebenarnya aku itu menonton drama korea jadi aku mengikuti dia sebagai aktor kyungsoo tapi aku kenal dia itu di exo soalnya waktu pertama kali tau exo itu ya do soalnya mudah di ingat yang paling mungil dan namanya pun juga begitu',
#  'tapi kalau do ama jaemin mau main drama lagi pasti aku nonton sama semua drama nya member exo nct rasa nya wajib aku tonton',
#  'mau bilang makasih sama pencetus konsep exo sebagai alien dari exo planet yg punya kekuatan masihmasing itu juga salah satu alasan gua nge stan exo karena menurut gua konsep nya itu unik dan beda dari yang lain banyak teorinya juga jadi kaya seru aja gitu',
#  'lagi ketagihan nonton reaksi video exo jadi semakin sayang lagi sama mereka dan gua juga merasa selama thn terakhir ini gk rugi kenal mereka',
#  'sm entertainment kembali tambahkan nama lay ke profil resmi exo',
#  'exo berhasil menorehkan prestasi membanggakan salah satu nya yaitu mendapat sebutan nations pick dari warga korsel kesuksesan exo bukan semata berasal dari agensi besar namun juga karena bakat para member yang luar biasa selengkapnya klik link ini ya',
#  'kangen sehun banget kangen exo juga kangen kyungsoo',
#  'lagi kangen banget sama exo gatau kenapa mengulang semua drama yang ada exo nya terus pas nonton do kyungsoo lucu banget',
#  'mau heran tapi ini exo diam aja tapi sering banget ada di puncak jadi kapan nih kembali',
#  'exo nih stabil banget loh peringkat yg dimana kembali aja jarang bangga',
#  'tujuan baekhyun di masa depan aku ingin exo menjadi sejarah musik korea sehingga tahun dari sekarang kami di ingat sebagai grup besar jika aku bisa aku ingin mencoba mendirikan program hiburan atau akting',
#  'exo bakal selalu jadi nomor mereka punya tempat sendiri di hati dan gak mungkin terganti',
#  'tapi jujur bridges nya exo tuh bagus bagus kayak nya hampir semua lagu bridges nya bikin merinding aku gak dengarin lagu yg batu tapi dari era tempo ke sebelumnya tuh mantap banget',
#  'lagi bayangin kalau exo nct svt sama treasure kumpul satu tempat rame nya macem mana ya',
#  'tetap setia sama exo di era gempuran idol lain pada kembali',
#  'gue suka kpop gara gara bts and exo sejak',
#  'luhan suho lay chanyeol baekhyun kyungsoo sehun kai kebanyakan member exo udah terkenal dari sebelum debut']

# %%
#remove whitespace
data_no_whitespace_neg = []
for line in data_no_number_neg:
  if len(line.split()) > 1:
    result = ' '.join(line.split())
    data_no_whitespace_neg.append(result)

data_no_whitespace_neg
# Out:
# ['lucu banget liat kai marah gegara eribong di sembunyi kyungsoo kyungsoo juga berperilaku polos sehun sampai memperhatikan hyung nya marah',
#  'tidak sabar menanti kji tapi tunggu itu berarti enlist semakin dekat',
#  'beri suara baekhyun di tta yuk eri ayo keluarin lagi mode beri suara monsternya',
#  'pesan suara dari untuk th hari jadi debut exo cbx di jepang cr chenniepii miss you chen',
#  'biasa mendapat tinjauan harian chanyeol tiap hari padahal baru beberapa hari gak muncul udah berasa setahun gak muncul chanyeol jam segini lagi ngapain ya masih libur atau udah balik ke barak',
#  'kimjunmyeon sudah sampai di korea gak lama di korea bakal pergi ke dubai lagi istirahat yg cukup ya myeonnie',
#  'hari sampai baekhyun s dipulangkan',
#  'karena anginrambutku menjadi seperti ini photo slide aku akan mengirimi kalian video begitu aku sampai di dubai selamat tinggal',
#  'kabarin dong kalo lagi kenapa tuh jangan menghilang terus',
#  'tutup aurora nya bang',
#  'ada badut apaan sih lay suho',
#  'ketika lay merindukan peristiwa itu aku dan exol lainnya pun sangat merindukan peristiwa itu juga',
#  'lucu aja sih kemana aja lo selama ini dari kemarin banyak yg ghibahin akun lu kali',
#  'hubungannya apa ya aku tidak paham lo ini exol hanya butuh untuk tidak diusik amp',
#  'sedih banget ketinggalan instagram siaran langsung nya bapak ketua padahal dari tadi lagi pegang hp gara scroll tiktok mulu nih jadi buka instagram udah selesai aja tapinya tetap mau mengucapkan selamat ulang tahun buat papi',
#  'kesal banget sama agensi itu astaga c bisa bisanya lay dihilangkan mancing keributan emang si sm dari dulu udah khawatir banget sama exo semenjak do mengeluarkan single terbarunya beberapa tahun lalu exo ada pokok nya',
#  'foto yg dimaksud itu foto nya chanyeol yg pernah gw buat foto profil wa nangis sih aslinya',
#  'tolong eri abaikan kaum jendes lumutsiapapun fokus ke exo amp',
#  'biasakan selesaikan masalah tanpa menyeret yg lain demi menutupi kebusukanpembelaan silahkan rnb kalo berminat',
#  'betapa lucunya bagaimana mereka membandingkan idola mereka dengan grup jeda seperti exo jika mereka protes idol mereka yang terbaik jadi kenapa menyentuh exo tenang tak dimusikpun member akan mondar mandir di fashion variety show karena lakilaki ku adalah yang terbaik dengan grup atau secara individual nikmatilah jrk',
#  'apakah dua foto ini sudah cukup menyadarkan diri kalian wahai exol hahaha tentu tidak memaksakan diri adalah gaya saya',
#  'ungu tuh sebenarnya terobsesi lo sama exo lama ga muncul sekarang jd pakar ekspresi iri aku sama kalian tuh segitu obses nya sama exo aku padahal aku gak pernah mikirin punyamu loh',
#  'ayok yg only aja mutualan tidak hijau ungu pink mejikuhibiniu khusus exol bukan multi atau solo stan grup lain bantu rt bestie',
#  'curiga aku pak jangan mau buat pabrik anggur juga bangga kepadamu kimjunmyeon',
#  'jam jam kangen semua akun yg dulu udah aku retweet atau suka harus diulang karena ini akun kedua yg kuingat sebelum pas akun pertama aku lupa semoga ini bertahan lama tapi kalo buat beri suara masih ada akun juga sih disini lebih nyaman dari sosial media lainnya apalagi segi perbaruan',
#  'ini ketua pamer makanan mulu kan jadi pengen makan bareng',
#  'belum lihat episode ini tapi kayak do xiumin yang udah gasabar ingin terjun disisi lain suho kai yg belum siap terjun',
#  'kai tolong jangan bikin aku cemburu',
#  'exo ladder musim ketiga besok episode terakhir',
#  'gak bisa nih gw seperti ini suho tanggung jawab lo tiap hari bikin anak orang gak waras',
#  'konser nya berpencar ya ini para peterpan ku',
#  'contoh makhluk tidak berotak yang dianugrahi bisa mengetik laporkan dan blokir jangan terlibat',
#  'ini benaran konser yg di dubai gratis ya allah kenapa ga indonesia aja sih',
#  'mau hidup waras kok susah banget ya',
#  'exo jeda sepi konten exo jeda bikin exol mabok perbaruan dan visual tiap saat',
#  'mau ikutan trend tapi pocky kemahalan',
#  'junmyeon kayak anak yg terpaksa ikut ayahnya untuk ketemu klien',
#  'kenapa kalo lagu exo di cover ga dapet rasa nya ya kek lewat lewat aja gitu',
#  'tao adalah member yang paling sering menangis fakta exo',
#  'kangen masa dulu semangat buat promosi exo ada kabar langsung senang banget sekarang mau semangat buat promosi exo semangat hidup aja nggak ada',
#  'kayak nya makin banyak yg ninggal exo ya di linimasa udah dikit bgt yg promosi exo pada pindah kemana nih',
#  'asli deh padahal udah gua nyala semua notif nya instagram semua member exo tapi pas sehun sama jongin kemaren perbarui cerita instagram kenapa gaada pemberitahuan nya sih',
#  'tolong exo segera kembali sebelum aku terjatuh lebih jauh ke brondong dream',
#  'baru sadar selama stan exo aku ga punya momen utama yang bikin aku suka banget ke sehun tentu saja aku promosi dan mendukung dia terus exo stan era sedangkan aku punya momen itu ke member lain',
#  'padahal dulu suka banget nonton video konser suju shinee exo karena terasa nggak lipsync sekarang coba tonton konser idol sm rasa nya kurang greget aja gitu',
#  'harapan gua terlalu muluk kayak nya kalo liat exo kembali tahun ini apapun itu yang jelas gua kangen banget sama mereka']

# %%
# !pip install PySastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PySastrawi
#   Downloading PySastrawi-1.2.0-py2.py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 4.2 MB/s
# Installing collected packages: PySastrawi
# Successfully installed PySastrawi-1.2.0

# %%
#stemming untuk teks berbahasa Indonesia
import string
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()

translator = str.maketrans("", "", string.punctuation)
data_stemmed = map(lambda x: stemmer.stem(x), data_no_whitespace)
data_no_punc = map(lambda x: x.lower().translate(translator), data_stemmed)

# %%
#stemming untuk teks berbahasa Indonesia
import string
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()

translator = str.maketrans("", "", string.punctuation)
data_stemmed_pos = map(lambda x: stemmer.stem(x), data_no_whitespace_pos)
data_no_punc_pos = map(lambda x: x.lower().translate(translator), data_stemmed_pos)

# %%
#stemming untuk teks berbahasa Indonesia
import string
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()

translator = str.maketrans("", "", string.punctuation)
data_stemmed_neg = map(lambda x: stemmer.stem(x), data_no_whitespace_neg)
data_no_punc_neg = map(lambda x: x.lower().translate(translator), data_stemmed_neg)

# %%
import nltk
nltk.download("punkt")
nltk.download("stopwords")
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#stopwords removal
stopword = stopwords.words("indonesian")
stopword.extend(["exo", "yaa", "guys", "ngabrut", "awokawokawok", "bengek", "awokawokawok", "akuuhhh", "siii", "huaaaaa", "amp", "chat", "plis", "dg", 
                 "toh", "gak", "otw", "kok", "dm", "u", "haha", "ayokk", "kuy", "bestie", "apaan", "rt", "yukk", "deh", "pliss", "gua", "php", "doang", "ooh", "tuhan", "kayanya",
                 "gpp", "gw", "gua", "Hemm", "please", "yak", "deg", "an", "poll", "Wkwk", "ya", "wkwkkwkw", "bapak", "hbd", "babang", "tks", "pls", "thn", "nd", "gaes", 
                 "yeah", "wah", "btw", "dah", "hiks", "duh", "hehey", "ehh", "papi", "yok", "woii", "rp", "Huhuhu", "oleng", "ayang", "k", "sumpah", "ter", "beb", "yoy", 
                 "ab", "abai", "th", "adeknya", "zetkidlin", "zulkidin", "abis", "adem", "bilang", "lihat", "tolong", "gitu", "situ", "lari", "tangan", "pas", "cari", "biar", "oke", "on",
                 "pakai", "ayah", "pas", "juta", "jam", "menit", "orang", "ubah", "papa", "by", "lupa", "mari", "duluan", "betapa", "ubah", "to", "anak", "pilih", "selamat", "ulang", "tahun",
                 "bikin", "gimana", "gin", "moga", "terima", "jual", "kirim", "capai", "lampau", "kayak", "langsung", "harga", "emang", "yey", "yuhu", "ygngg", "with", "agak",
                 "ya", "guys", "selamat", "mas", "nya", "bgt", "amp", "untuk", "x", "dg", "udah", "kuy", "by", "ooh", "gaes", "dah", "ya", "bang", "th", "tuh", "aja", "yg",
                 "ini", "kayak", "lu", "kan", "ter", "yuk", "kalo", "lagi", "loh", "of", "abang", "ga", "kek", "gk", "wkwk", "si", "and", "sih", "banget", "thanks", "sih", "omg", "ga", "gk", "iya", 
                 "jg", "nang", "its", "okey", "kek", "oh", "hehe", "gue", "my", "mu", "nih", "adik", "agakagak", "ah", "yaampun", "yangs", "you", "your", "yoo", "yangyang", "aka", "wkwkwk"])

datafinal = []
for line in data_no_punc:
  word_token = nltk.word_tokenize(line)
  word_token = [word for word in word_token if word not in stopword and not word[0].isdigit()]
  datafinal.append(word_token)

datafinal
# Out:
# [['laku', 'baekhyun'],
#  ['peristiwa', 'kumpul'],
#  ['tertawa',
#   'tingkah',
#   'hun',
#   'tim',
#   'produksi',
#   'kyungsoo',
#   'sesak',
#   'nafas',
#   'kai',
#   'hun',
#   'alias',
#   'raja',
#   'kakak'],
#  ['laku', 'baekhyun'],
#  ['pikir',
#   'milik',
#   'tunggu',
#   'sulit',
#   'kenang',
#   'masamasa',
#   'bahagia',
#   'bersiapsiap',
#   'temu',
#   'ayo',
#   'temu',
#   'cepat',
#   'cinta',
#   'exol'],
#  ['baekhyun'],
#  ['pamer',
#   'debut',
#   'konser',
#   'bahagia',
#   'smtown',
#   'temu',
#   'sehat',
#   'temu',
#   'buah',
#   'janji',
#   'tinggal'],
#  ['baekhyun'],
#  ['cbx', 'sayang'],
#  ['debut', 'beda', 'beda', 'heran', 'exol', 'tahan', 'banting'],
#  ['ganteng'],
#  ['exocbx',
#   'jepang',
#   'debut',
#   'cepat',
#   'baekhyun',
#   'selesai',
#   'wajib',
#   'militer'],
#  ['update', 'pesan', 'xiumin', 'exocbx', 'debut', 'japan'],
#  ['baekhyun'],
#  ['laku', 'baekhyun'],
#  ['senang',
#   'gila',
#   'pesan',
#   'unggah',
#   'suho',
#   'gatau',
#   'perhatiin',
#   'ngga',
#   'kaya',
#   'aneh',
#   'foto',
#   'selfie',
#   'suho'],
#  ['cerita',
#   'lagu',
#   'sedih',
#   'nikmat',
#   'musik',
#   'permission',
#   'dance',
#   'dont',
#   'fight',
#   'the',
#   'feeling',
#   'hangat',
#   'senang',
#   'untung',
#   'candu',
#   'drama',
#   'korea',
#   'cinta',
#   'musik',
#   'korea',
#   'sembuh'],
#  ['hun', 'diorerl'],
#  ['incheon', 'dubai'],
#  ['suho', 'terbang', 'dubai', 'japan', 'usa', 'seoul'],
#  ['pikat', 'sihir', 'jiwa', 'kagum', 'pandang', 'dunia'],
#  ['kai', 'the', 'exordium', 'seoul', 'iconic'],
#  ['kumpul', 'senang', 'sehatsehat'],
#  ['aura', 'aktor', 'hun', 'yeonseok'],
#  ['china',
#   'puncak',
#   'peringkat',
#   'daftar',
#   'top',
#   'pasar',
#   'musik',
#   'dunia',
#   'ifpi',
#   'puncak',
#   'daftar',
#   'bantu',
#   'pasar',
#   'cina'],
#  ['terbang', 'seoul', 'dubai', 'seoul'],
#  ['hubung',
#   'tim',
#   'uang',
#   'ace',
#   'jeda',
#   'detail',
#   'hasil',
#   'donasi',
#   'kjm',
#   'terimakasih',
#   'donatur',
#   'tim',
#   'streaming',
#   'jumpa',
#   'projek'],
#  ['ig',
#   'musik',
#   'unggah',
#   'baju',
#   'sengaja',
#   'lelah',
#   'kasih',
#   'latih',
#   'ajar'],
#  ['suka', 'lagu', 'bayang', 'nyanyi'],
#  ['bentar', 'juni', 'dont', 'fight', 'for', 'then', 'feeling', 'no', 'matter'],
#  ['jaehyuk', 'baekhyun', 'renjun', 'jisung'],
#  ['runaway'],
#  ['exol', 'ayok', 'mutualan', 'kawan', 'besti'],
#  ['maknae', 'palsu', 'xiumin'],
#  ['eri', 'ayo', 'semangat', 'dukung', 'baekhyun', 'jarak', 'tipis'],
#  ['vitamin', 'xiu', 'tahan', 'vitamin', 'xiu', 'minggu', 'xiumin'],
#  ['masternim', 'kai', 'aktif', 'aumicky'],
#  ['member', 'kangen', 'kah'],
#  ['nyata', 'foto', 'hun', 'smc'],
#  ['muncul',
#   'sosial',
#   'media',
#   'intip',
#   'jalan',
#   'cinta',
#   'jennie',
#   'blackpink',
#   'kai',
#   'v',
#   'bts'],
#  ['nego', 'mulus', 'isi', 'lengkap'],
#  ['baekhyun'],
#  ['baekhyun'],
#  ['suho', 'terbang', 'dubai', 'jepang', 'usa', 'seoul'],
#  ['hun', 'instragram', 'hun', 'foto', 'suho', 'member'],
#  ['foto', 'simpel', 'bagus', 'feed', 'instagram', 'rapi', 'estetik'],
#  ['hun', 'instagram', 'imut', 'imut', 'imut', 'sayang'],
#  ['suho', 'hun'],
#  ['hun'],
#  ['doa',
#   'gaboleh',
#   'ragu',
#   'salah',
#   'foto',
#   'jodoh',
#   'serah',
#   'kanan',
#   'kiri',
#   'samping',
#   'kanan',
#   'samping',
#   'kiri'],
#  ['suho', 'instagram', 'jumpa'],
#  ['baekhyun'],
#  ['smtown', 'shanghai'],
#  ['sembilan', 'saranghaja'],
#  ['hun'],
#  ['sehat', 'nyapa', 'exol', 'cinta', 'oppa'],
#  ['usaha', 'stabil', 'pikir'],
#  ['suho', 'terimakasih', 'sehat', 'sukses', 'karir', 'solo', 'grup'],
#  ['exol', 'habis', 'kena', 'drama', 'makasih', 'hun'],
#  ['hun'],
#  ['suho'],
#  ['suho'],
#  ['ketua', 'terimakasih', 'kerja', 'keras', 'sehat', 'temu', 'terimakasih'],
#  ['dengar', 'nada', 'lagu', 'judul', 'playboy'],
#  ['hemm', 'ganteng'],
#  ['kumpul',
#   'barang',
#   'sedia',
#   'alias',
#   'sedia',
#   'alias',
#   'ls',
#   'list',
#   'officialunoff',
#   'oriofficial',
#   'unoff',
#   'oriofficial',
#   'ngga'],
#  ['takut', 'tau', 'senang'],
#  ['ganti', 'agens', 'sm', 'hibur', 'senang', 'acara', 'tibatiba'],
#  ['exol', 'baekhyun'],
#  ['bukti',
#   'tangkap',
#   'layar',
#   'suho',
#   'grey',
#   'suit',
#   'dday',
#   'greysuit',
#   'pm'],
#  ['allah',
#   'hun',
#   'ganteng',
#   'coba',
#   'kasih',
#   'tau',
#   'kalahin',
#   'ganteng',
#   'tuan',
#   'muda',
#   'hun'],
#  ['aktivitas', 'kris', 'wu', 'trend', 'kris', 'wu', 'bebas'],
#  ['suho', 'ketua', 'super'],
#  ['akun',
#   'twitter',
#   'hallyu',
#   'pop',
#   'fest',
#   'london',
#   'info',
#   'video',
#   'pesan',
#   'artis',
#   'chen',
#   'hadir'],
#  ['lay', 'coba', 'popcorn', 'orangorang'],
#  ['happy',
#   'birthday',
#   'junmyeon',
#   'kasih',
#   'salah',
#   'warna',
#   'hidup',
#   'harap',
#   'junmyeon',
#   'bahagia',
#   'laku',
#   'nikmat',
#   'sayang',
#   'kimjunmyeon'],
#  ['suho', 'mumpung', 'bareng', 'beli', 'kue'],
#  ['baekhyun', 'tta'],
#  ['suho', 'terbang', 'dubai', 'jepang', 'c', 'usa', 'seoul'],
#  ['maudy', 'nikah', 'marga', 'choi', 'nikah', 'marga', 'kim'],
#  ['baekhyun'],
#  ['milih',
#   'baekhyun',
#   'exol',
#   'baekhyun',
#   'tta',
#   'exol',
#   'baekhyun',
#   'tta',
#   'exol',
#   'baekhyun',
#   'tta'],
#  ['fokus', 'idol', 'cinta', 'promosi', 'exomember', 'utama'],
#  ['urus', 'perang', 'exol'],
#  ['no', 'dvd', 'kive', 'japan', 'suho'],
#  ['tinjau',
#   'drama',
#   'korea',
#   'days',
#   'prince',
#   'do',
#   'namjihyun',
#   'tokoh',
#   'utama'],
#  ['kasih', 'ketua', 'kasih', 'jaga', 'member'],
#  ['suho', 'kasih', 'lahir', 'kasih', 'smtown', 'kasih', 'lagu', 'bagus'],
#  ['ketua', 'kimjunmyeon', 'kasih', 'juang', 'kasih', 'exol'],
#  ['leader', 'hebat', 'sehat', 'kuat', 'dukung', 'tunggu', 'kau', 'laku'],
#  ['ketua', 'sayang', 'aeri'],
#  ['kencang', 'kencang', 'perang', 'kencang', 'baekhyun'],
#  ['selesai',
#   'atur',
#   'album',
#   'greysuit',
#   'min',
#   'suho',
#   'keren',
#   'foto',
#   'cuman',
#   'kacamata',
#   'hitam',
#   'nambah',
#   'ganteng'],
#  ['maaf', 'tim', 'exol', 'only', 'exol'],
#  ['suho', 'sehat', 'sehat'],
#  ['suho', 'sayang', 'harap'],
#  ['lamar',
#   'suho',
#   'terimakasih',
#   'ketua',
#   'baikpendengar',
#   'baikorang',
#   'hidupaku',
#   'cinta'],
#  ['ketua', 'ganteng', 'estetik'],
#  ['anggota',
#   'sibuk',
#   'giat',
#   'exol',
#   'sembilan',
#   'dukung',
#   'member',
#   'sayang'],
#  ['kimjunmyeon',
#   'sehat',
#   'makan',
#   'kurus',
#   'promosi',
#   'grey',
#   'suit',
#   'kasih',
#   'bahagia',
#   'exol',
#   'bangga',
#   'love'],
#  ['trinity',
#   'bias',
#   'kemarin',
#   'tinggal',
#   'wajib',
#   'militer',
#   'bareng',
#   'pulang',
#   'bareng'],
#  ['tampan', 'suara', 'emas', 'nyanyi', 'sayang', 'kimjunmyeon', 'suho'],
#  ['kimjunmyeon', 'umur', 'sehat', 'doa'],
#  ['ketua', 'suho', 'bahagia', 'sehat', 'ketua', 'tau', 'harap', 'cinta'],
#  ['ketua',
#   'kimjunmyeon',
#   'makasih',
#   'ketua',
#   'jaga',
#   'member',
#   'makasih',
#   'sehat',
#   'bahagia',
#   'cinta',
#   'happy',
#   'birthday',
#   'suho'],
#  ['kimjunmyeon', 'doa'],
#  ['kimjunmyeon',
#   'umur',
#   'sehat',
#   'sukses',
#   'berkarir',
#   'ganteng',
#   'cepat',
#   'kumpul',
#   'member'],
#  ['ketua',
#   'sayang',
#   'exol',
#   'kasih',
#   'jaga',
#   'kerja',
#   'keras',
#   'exol',
#   'sehat',
#   'bahagia',
#   'cinta'],
#  ['utama', 'sampul', 'singles', 'edisi', 'juni', 'suho'],
#  ['ketua', 'bahagia', 'sukses', 'bahagia', 'terimakasih', 'malaikat', 'jaga'],
#  ['suho', 'ketua', 'sayang', 'ketua', 'bangga', 'cinta', 'kimjunmyeon'],
#  ['ketua',
#   'kak',
#   'suho',
#   'kasih',
#   'ketua',
#   'sabar',
#   'sehat',
#   'bahagia',
#   'kak'],
#  ['ketua', 'suho'],
#  ['kimjunmyeon', 'umur', 'sehat', 'bangga', 'suho', 'membe'],
#  ['kimjunmyeon', 'umur', 'sehat', 'bangga', 'suho', 'member'],
#  ['selamt', 'kimjunmyeon', 'umur', 'sehat', 'bangga', 'suho', 'member'],
#  ['kimjunmyeon', 'umur', 'sehat'],
#  ['kimjunmyeon', 'umur', 'sehat', 'bangga', 'suho', 'member'],
#  ['kimjunmyeon', 'bangga', 'suho', 'member'],
#  ['kimjunmyeon', 'ketua', 'sabar', 'umur', 'sehat'],
#  ['kimjunmyeon', 'umur', 'sehat', 'bangga', 'suho', 'member'],
#  ['kimjunmyeon', 'ketua', 'terimakasih', 'kerja', 'keras'],
#  ['ketua', 'kimjunmyeon', 'sehat', 'bahagia'],
#  ['suho', 'kimjunmyeon', 'jumpa', 'konser', 'idol', 'gemar', 'cinta'],
#  ['kimjunmyeon', 'harap', 'sehat', 'bahagia'],
#  ['kai', 'icu', 'awakening', 'dir', 'jae', 'via'],
#  ['kimjunmyeon',
#   'ketua',
#   'terimakasih',
#   'kerja',
#   'keras',
#   'exol',
#   'bangga',
#   'sehat',
#   'temu'],
#  ['ngomongin',
#   'pimpin',
#   'kasih',
#   'jempol',
#   'ngomongin',
#   'bakat',
#   'salah',
#   'main',
#   'non',
#   'vokal',
#   'favorit',
#   'daya',
#   'foto',
#   'suka'],
#  ['twibbon',
#   'suho',
#   'day',
#   'bingkai',
#   'foto',
#   'desain',
#   'sederhana',
#   'elegan',
#   'raya',
#   'suho',
#   'is',
#   'nine'],
#  ['sayang',
#   'kasih',
#   'hadir',
#   'hidup',
#   'kasih',
#   'karya',
#   'kerja',
#   'keras',
#   'keren',
#   'kasih',
#   'sehat'],
#  ['baju',
#   'suho',
#   'jaemin',
#   'tulis',
#   'jeno',
#   'kece',
#   'omong',
#   'omong',
#   'kimjunmyeon',
#   'sehat',
#   'sehat',
#   'bahagia',
#   'kim',
#   'jumyeon',
#   'jeno',
#   'jaemin'],
#  ['happy',
#   'birthday',
#   'kimjunmyeon',
#   'sehat',
#   'selalukuat',
#   'semangat',
#   'bahagia',
#   'makasih',
#   'juang',
#   'tahan',
#   'inisemoga',
#   'berkat',
#   'senantiasa',
#   'cinta'],
#  ['lakilaki', 'gemar', 'bangga'],
#  ['suho',
#   'kasih',
#   'ketua',
#   'jaga',
#   'bimbing',
#   'kasih',
#   'tahan',
#   'iniselalu',
#   'jaga',
#   'sehat',
#   'bahagia',
#   'suho',
#   'kimjunmyeon'],
#  ['suho',
#   'hyeong',
#   'cape',
#   'kali',
#   'bangun',
#   'tidur',
#   'kasihan',
#   'mata',
#   'bahagia',
#   'spesial',
#   'siar',
#   'sapa',
#   'eri'],
#  ['nggak',
#   'tinggal',
#   'ketua',
#   'siar',
#   'terimakasih',
#   'suho',
#   'aktif',
#   'update'],
#  ['baju', 'jaemin', 'jalan', 'mall', 'ketua', 'suho', 'cinta', 'kucing'],
#  ['suho', 'baju', 'jaemin', 'siar', 'instagram', 'jaemin', 'jeno', 'dreamies'],
#  ['kimjunmyeon', 'sehat', 'karir', 'lancar', 'pokok', 'nikmat', 'indah'],
#  ['kimjunmyeon',
#   'lulus',
#   's',
#   'inha',
#   'university',
#   'junmyeon',
#   'cy',
#   'program',
#   'giat',
#   'sekolah',
#   'musim',
#   'panas',
#   'universitas',
#   'inha',
#   'unv'],
#  ['exol', 'exol', 'gatau', 'sayang', 'sehat', 'sehat'],
#  ['nyaman', 'sembilan', 'pokok', 'nambah', 'inti', 'sembilan'],
#  ['minseok',
#   'vokal',
#   'bagus',
#   'minseok',
#   'tar',
#   'bagus',
#   'minseok',
#   'nyanyi',
#   'bagus',
#   'minseok',
#   'kakak',
#   'hebat'],
#  ['minseok',
#   'vokal',
#   'bagus',
#   'minseok',
#   'nari',
#   'bagus',
#   'minseok',
#   'nyanyi',
#   'bagus',
#   'minseok',
#   'kakak',
#   'hebat'],
#  ['perang', 'gemar', 'saing', 'via', 'suara', 'eriexol'],
#  ['tertawa', 'hun', 'semangat', 'xiumin', 'takut', 'bayi'],
#  ['hubung', 'penggemarpenggemarku', 'percaya', 'bersamasama'],
#  ['percaya', 'sisi', 'lotto'],
#  ['ganteng', 'kimjunmyeon'],
#  ['suho',
#   'duta',
#   'ikutin',
#   'jejak',
#   'gege',
#   'yixing',
#   'keren',
#   'pokok',
#   'ketua'],
#  ['baekhyun', 'tta'],
#  ['bantu',
#   'minimal',
#   'bantu',
#   'hashtag',
#   'kalah',
#   'perang',
#   'skefo',
#   'lawan',
#   'kremy',
#   'exol',
#   'baekhyun',
#   'tta',
#   'exol',
#   'vote',
#   'baekhyun',
#   'tta',
#   'exol',
#   'baekhyun',
#   'tta'],
#  ['suho', 'bicara', 'konferensi', 'studi', 'korea', 'universitas', 'stanford'],
#  ['suho', 'ketua', 'bawa', 'korea', 'musik', 'cinta'],
#  ['exol', 'ayo', 'baekhyun', 'tta', 'link'],
#  ['kangen', 'konser', 'nonton', 'konser', 'dreamies'],
#  ['baekhyun', 'jarak'],
#  ['info', 'pergi', 'dunia', 'tangga', 'musim', 'siar', 'trans', 'tv', 'juli'],
#  ['info',
#   'artikel',
#   'keliling',
#   'dunia',
#   'tangga',
#   'musim',
#   'siar',
#   'indonesia',
#   'trans',
#   'tv',
#   'juli'],
#  ['episode',
#   'bahagia',
#   'senyum',
#   'bahagia',
#   'jalan',
#   'muas',
#   'tertawa',
#   'lepas',
#   'layar'],
#  ['dubai', 'tunggu', 'suho'],
#  ['suho',
#   'stanford',
#   'panggil',
#   'suho',
#   'junmyeon',
#   'oppa',
#   'panggil',
#   'seonsaengnim',
#   'guru',
#   'karna',
#   'cuman',
#   'seonsaengnim',
#   'leesooman',
#   'sunbaenim',
#   'suka'],
#  ['info', 'beli', 'lightstick', 'versi', 'jogja'],
#  ['kyungsoo', 'jenius'],
#  ['suho', 'bangga'],
#  ['berputa', 'whitenoise', 'gulir', 'retweet', 'penuhin', 'linimasa', 'moots'],
#  ['suho', 'bangga', 'member'],
#  ['jongin', 'suka', 'jerit'],
#  ['chanyeol', 'layan', 'jjareu', 'ratu'],
#  ['chanyeol',
#   'putri',
#   'sayang',
#   'putri',
#   'bonus',
#   'foto',
#   'instragram',
#   'toben'],
#  ['astaga', 'penasaran', 'bau', 'suho', 'wangi'],
#  ['tau',
#   'stan',
#   'fandom',
#   'favorit',
#   'judul',
#   'lagu',
#   'tempo',
#   'favorit',
#   'bside',
#   'been',
#   'through',
#   'favorit',
#   'video',
#   'musik',
#   'overdose',
#   'favorit',
#   'koreografi',
#   'history',
#   'bias',
#   'do',
#   'bias',
#   'do',
#   'chanyeol'],
#  ['keluarga',
#   'sm',
#   'sibuk',
#   'nct',
#   'dream',
#   'tampil',
#   'nct',
#   'siar',
#   'ig',
#   'wayv',
#   'siar',
#   'weibo',
#   'sambut',
#   'rv',
#   'bandara',
#   'liat',
#   'suho',
#   'stanford',
#   'nambah'],
#  ['manusia',
#   'manusia',
#   'keren',
#   'tampan',
#   'wibawa',
#   'muda',
#   'kaya',
#   'sempurna'],
#  ['bias', 'bias', 'bias', 'hancur', 'pokok', 'kai'],
#  ['tampil', 'everglow', 'sf', 'panggung', 'tampil', 'bagus'],
#  ['ramai',
#   'mutualan',
#   'exol',
#   'multi',
#   'mutual',
#   'solo',
#   'stan',
#   'bantu',
#   'retweet'],
#  ['permisi',
#   'ayo',
#   'nyari',
#   'mututal',
#   'exol',
#   'multi',
#   'ungu',
#   'ijo',
#   'orange',
#   'kelabu',
#   'solo',
#   'stan',
#   'khusus',
#   'onl',
#   'rapat',
#   'bantu',
#   'retweet',
#   'kasih'],
#  ['kyungsoo',
#   'cinderella',
#   'versi',
#   'cowok',
#   'kyungja',
#   'sepatu',
#   'hilang',
#   'hun',
#   'ketawa',
#   'puas'],
#  ['baekhyun'],
#  ['aura', 'tuan', 'pabrik', 'wine'],
#  ['bahas', 'hadir', 'konferensi', 'studi', 'korea', 'universitas', 'stanford'],
#  ['hadir',
#   'konferensi',
#   'studi',
#   'korea',
#   'universitas',
#   'stanford',
#   'bahas',
#   'pengaruh',
#   'gelombang',
#   'hallyu',
#   'lengkap'],
#  ['daebak',
#   'suho',
#   'oppa',
#   'well',
#   'done',
#   'eri',
#   'khusyuk',
#   'dengar',
#   'fokus',
#   'suho'],
#  ['sempurna', 'tuan', 'muda', 'hun', 'diorerl'],
#  ['jongin', 'lucu', 'cerita', 'kaya', 'antusias'],
#  ['chen', 'sibuk', 'idol', 'status', 'suami'],
#  ['profile', 'chen', 'idol', 'pria', 'sukses', 'nyanyi', 'solo'],
#  ['potret',
#   'tampan',
#   'suho',
#   'bicara',
#   'diskusi',
#   'panel',
#   'university',
#   'stanford',
#   'fokus'],
#  ['bahasa',
#   'inggris',
#   'suho',
#   'bagus',
#   'bangga',
#   'suho',
#   'usaha',
#   'ajar',
#   'bahasa',
#   'inggris',
#   'lancar',
#   'ngomongnya',
#   'apresiasi',
#   'suho'],
#  ['amerika',
#   'konser',
#   'amerika',
#   'ngisi',
#   'seminar',
#   'stanford',
#   'bangga',
#   'dengamu',
#   'ketua'],
#  ['deja', 'vu', 'foto', 'junmyeon', 'foto', 'pokok', 'foto', 'bicara'],
#  ['aura', 'pintar', 'beda'],
#  ['suho',
#   'hadir',
#   'konferensi',
#   'studi',
#   'korea',
#   'universitas',
#   'stanford',
#   'panel',
#   'diskusi',
#   'koreawave',
#   'kisah',
#   'pribadi',
#   'artis',
#   'korea',
#   'pop',
#   'pengaruh',
#   'global',
#   'budaya',
#   'korea',
#   'hidup',
#   'seharihari',
#   'korea'],
#  ['bangga', 'suami', 'online'],
#  ['ketua', 'keren'],
#  ['bangga', 'ketua'],
#  ['jadwal', 'padat'],
#  ['bangga'],
#  ['baekhyun', 'toge', 'inumaki'],
#  ['jujur',
#   'dengar',
#   'lagu',
#   'keren',
#   'gila',
#   'suka',
#   'terngiangngiang',
#   'lagu',
#   'dengar',
#   'dengar',
#   'keren'],
#  ['aura', 'aura', 'aura', 'ketua', 'leader', 'bangga', 'kimjunmyeon'],
#  ['bangga',
#   'suho',
#   'ketua',
#   'dunia',
#   'kenal',
#   'exol',
#   'korea',
#   'musik',
#   'sungguh',
#   'masingmasing',
#   'exol',
#   'bangga',
#   'kenal'],
#  ['jujur',
#   'haru',
#   'bahagia',
#   'allah',
#   'suho',
#   'keren',
#   'hebat',
#   'wibawa',
#   'henti',
#   'keren',
#   'bangga',
#   'cinta',
#   'bangga',
#   'kimjunmyeon'],
#  ['suho', 'konser', 'nabung'],
#  ['suho',
#   'keren',
#   'ken',
#   'sekolah',
#   'ajar',
#   'rajin',
#   'paham',
#   'bakat',
#   'keren',
#   'kaya',
#   'suhoacademik',
#   'nonacademik',
#   'sikap',
#   'loyalitas',
#   'visual',
#   'mantep',
#   'bintang'],
#  ['bangga',
#   'suho',
#   'salah',
#   'manusia',
#   'bangga',
#   'kagum',
#   'member',
#   'bangga',
#   'exol',
#   'sayang',
#   'exol'],
#  ['pesona', 'tampan', 'dosen', 'muda'],
#  ['pokok',
#   'bangga',
#   'baper',
#   'suho',
#   'ngelakuin',
#   'neng',
#   'campur',
#   'haru',
#   'bangga',
#   'suhoexoand',
#   'exol'],
#  ['bangga',
#   'ketua',
#   'banga',
#   'suho',
#   'presentasi',
#   'keren',
#   'liat',
#   'nikmat',
#   'wibawa',
#   'lucu',
#   'nggak',
#   'kenalin',
#   'exol'],
#  ['ngga',
#   'tau',
#   'inti',
#   'exol',
#   'bangga',
#   'suho',
#   'presentasi',
#   'stanford',
#   'saranghaja',
#   'bangga',
#   'suho'],
#  ['liat',
#   'fotovideo',
#   'suho',
#   'bawa',
#   'bangga',
#   'keren',
#   'jun',
#   'bangga',
#   'kimjunmyeon'],
#  ['definisi', 'tampan', 'rupawan', 'cendikiawan'],
#  ['ganteng'],
#  ['jujur',
#   'bangga',
#   'ketua',
#   'suho',
#   'exol',
#   'kalimat',
#   'urut',
#   'alfabet',
#   'huruf'],
#  ['suho', 'keren', 'parah', 'eri', 'bangga'],
#  ['bangga', 'suho', 'keren', 'iri', 'fans', 'bunga', 'bunga', 'debut', 'akun'],
#  ['junmyeon', 'bangga', 'bawa', 'nama', 'musik', 'korea', 'pikir', 'junmyeon'],
#  ['ketua',
#   'keren',
#   'suho',
#   'bangga',
#   'bangga',
#   'serius',
#   'member',
#   'bangga',
#   'bangga',
#   'suhoexoand',
#   'exol'],
#  ['suho', 'aura', 'mainmain'],
#  ['bangga', 'suho', 'maju', 'bangga', 'kim', 'junmyeon'],
#  ['rajin', 'update', 'media', 'sosial', 'cakep'],
#  ['bangga', 'suho'],
#  ['ganteng'],
#  ['ganteng', 'pinter', 'bakat', 'ramah', 'manis', 'ketua', 'pokok'],
#  ['ketua',
#   'suho',
#   'grup',
#   'bangga',
#   'budaya',
#   'negara',
#   'tumpang',
#   'nama',
#   'musik',
#   'korea',
#   'patut',
#   'contoh'],
#  ['bangga', 'bangga', 'kim', 'junmyeon'],
#  ['takdir', 'terimakasih', 'kenal', 'musik'],
#  ['suho', 'keren'],
#  ['bangga', 'suho'],
#  ['militer',
#   'solo',
#   'album',
#   'ketemu',
#   'gemar',
#   'vlog',
#   'temu',
#   'fans',
#   'pulau',
#   'jeju',
#   'ngisi',
#   'pidato',
#   'stanford',
#   'kimjunmyeon',
#   'patut',
#   'apresiasidia',
#   'benarbenar',
#   'kerja',
#   'keras',
#   'bangga',
#   'dengganmu'],
#  ['ketua',
#   'debut',
#   'tweet',
#   'salah',
#   'prof',
#   'stanford',
#   'hebat',
#   'suho',
#   'bangga',
#   'suho'],
#  ['bangga', 'exol', 'ketua'],
#  ['jujur',
#   'allah',
#   'suho',
#   'keren',
#   'hebat',
#   'wibawa',
#   'bangga',
#   'cinta',
#   'bangga',
#   'kim',
#   'junmyeon'],
#  ['tau', 'suho', 'ceo'],
#  ['ganteng', 'pinter', 'sikap', 'bagus', 'aura', 'ketua', 'pokok'],
#  ['suho', 'presiden', 'musik', 'korea'],
#  ['allah',
#   'bangga',
#   'suho',
#   'untung',
#   'kenal',
#   'terimakasih',
#   'leader',
#   'dunia',
#   'lcinta',
#   'bangga',
#   'kim',
#   'junmyeon'],
#  ['bangga',
#   'ketua',
#   'suho',
#   'bahasa',
#   'inggris',
#   'makasih',
#   'kerja',
#   'keras',
#   'suho',
#   'presentasi',
#   'exol',
#   'indonesia',
#   'leleh',
#   'tungguin',
#   'konser',
#   'member',
#   'kumpul',
#   'sehat'],
#  ['malam', 'begadang', 'nonton', 'suho', 'suho', 'stanford'],
#  ['kai', 'exol', 'andal', 'suho', 'stanford'],
#  ['keren', 'suho', 'stanford'],
#  ['neng', 'suho', 'kasih', 'hadiah', 'suho', 'stanford'],
#  ['suho', 'stanford'],
#  ['habis', 'konser', 'negeri', 'terjemah', 'juru', 'bicara', 'ketua'],
#  ['bentar',
#   'bentar',
#   'ganteng',
#   'keren',
#   'gagah',
#   'wibawa',
#   'ampun',
#   'kenalin',
#   'bos',
#   'ketua',
#   'kimjunmyeon',
#   'suho',
#   'bangga',
#   'suho'],
#  ['suho',
#   'bahasa',
#   'inggris',
#   'sempurna',
#   'salah',
#   'keren',
#   'bahasa',
#   'inggris',
#   'tingkat',
#   'pesat',
#   'ketua',
#   'bangga'],
#  ['bangga', 'suho', 'malaikat', 'musik', 'korea'],
#  ['bangga', 'suho', 'malaikat', 'musik', 'korea'],
#  ['suho', 'keren', 'bangga', 'kimjunmyeon'],
#  ['bangga', 'ayo', 'angkat', 'bangga', 'kimjunmyeon'],
#  ['suho', 'member', 'konser'],
#  ['chanyeol', 'minimal', 'warm', 'streaming', 'spotify'],
#  ['chanyeol', 'tomorrow', 'streaming', 'spotify'],
#  ['bangun',
#   'pagi',
#   'fokus',
#   'jun',
#   'bawa',
#   'ketua',
#   'jun',
#   'presiden',
#   'inget',
#   'minseok',
#   'bangga',
#   'kim',
#   'junmyeon'],
#  ['suho',
#   'lo',
#   'bangga',
#   'borong',
#   'pinter',
#   'jago',
#   'nari',
#   'nyanyi',
#   'ganteng',
#   'bangga',
#   'kimjunmyeon'],
#  ['wawancara', 'giat', 'negeri', 'suho', 'cuman', 'musik', 'korea'],
#  ['bangga', 'kimjunmyeon', 'keren', 'ketua'],
#  ['tampan', 'mapan', 'rupawan', 'wawas', 'kimjunmyeon', 'bangga', 'suho'],
#  ['suho',
#   'presentasi',
#   'tipikal',
#   'kerja',
#   'ngomong',
#   'kerja',
#   'bagus',
#   'ketua'],
#  ['suho', 'terbang', 'dubai', 'jepang', 'usa', 'seoul'],
#  ['gamau', 'ngajar', 'kampus'],
#  ['suka', 'junmyeon', 'harap', 'leader', 'bangga', 'suho'],
#  ['bunga', 'indah', 'suho', 'senang', 'simpan', 'bawa', 'korea'],
#  ['jun', 'manis', 'bangga', 'kimjunmyeon'],
#  ['mentor',
#   'dosen',
#   'bangga',
#   'kimjunmyeon',
#   'malaikat',
#   'malaikat',
#   'kpop',
#   'suho',
#   'stanford'],
#  ['keluarin', 'foto', 'mba', 'bangga', 'kimjunmyeon'],
#  ['bagus', 'exol', 'kuliah', 'stanford', 'suho'],
#  ['junmyeon',
#   'nasihat',
#   'bawa',
#   'enak',
#   'formal',
#   'serius',
#   'tenang',
#   'humor',
#   'nyaman',
#   'dengar',
#   'bangga',
#   'suho'],
#  ['senyum', 'manis', 'bangga', 'kim', 'junmyeon'],
#  ['suho', 'persis', 'dosen', 'suho', 'lirik', 'kampus', 'ku'],
#  ['tunggu', 'saranghaja'],
#  ['tinggal', 'bangga', 'kimjunmyeon'],
#  ['bangga', 'suho', 'keren', 'sayang'],
#  ['senyum', 'manis', 'ampun', 'leleh', 'planet'],
#  ['bangga', 'ketua', 'senang', 'haru'],
#  ['hebat', 'suho'],
#  ['suho',
#   'keren',
#   'nikmat',
#   'gugup',
#   'bahasa',
#   'inggris',
#   'keren',
#   'tampil',
#   'wibawa',
#   'kenalin',
#   'exol',
#   'bangga',
#   'kim',
#   'junmyeon'],
#  ['bangga',
#   'suho',
#   'lancar',
#   'ngomong',
#   'tonton',
#   'ketawa',
#   'kenalin',
#   'exol'],
#  ['tunggu', 'gapapa', 'rela', 'nungguin'],
#  ['proud', 'kimjunmyeon', 'keren'],
#  ['indonesian', 'perhati', 'persentasi', 'suho'],
#  ['andai',
#   'dosen',
#   'bawa',
#   'materi',
#   'seasik',
#   'suho',
#   'jamin',
#   'mahasiswa',
#   'absen',
#   'ngantuk',
#   'd',
#   'materi',
#   'hes',
#   'really',
#   'great'],
#  ['sesi', 'suho', 'ngomong', 'suho', 'stanford'],
#  ['lelucon', 'cocok', 'suho', 'cair', 'suasana'],
#  ['cerah', 'liat', 'junmyeon', 'senyum', 'bangga', 'kim', 'junmyeon'],
#  ['idol',
#   'suho',
#   'malas',
#   'ayo',
#   'hebat',
#   'samasama',
#   'bangga',
#   'kim',
#   'junmyeon'],
#  ['heh',
#   'lusa',
#   'umur',
#   'eh',
#   'suka',
#   'bahagia',
#   'kiyowo',
#   'ganteng',
#   'paripurna',
#   'bangga',
#   'kim',
#   'junmyeon'],
#  ['bangga', 'suho', 'senang', 'indonesia', 'perhati', 'persentasi'],
#  ['pagipagi', 'kasih', 'liat', 'bangga', 'kimjunmyeon'],
#  ['sayang', 'eri', 'hati'],
#  ['artikel', 'nulis', 'oneit', 'member', 'tulis', 'lengkap'],
#  ['bagus', 'tau', 'inggris', 'sayang', 'suho', 'pokok'],
#  ['sempurna', 'suami', 'hidup'],
#  ['bangga', 'suho', 'berita', 'bagus'],
#  ['jun', 'oppa', 'keren', 'suho', 'stanford'],
#  ['menang',
#   'kenal',
#   'dunia',
#   'eri',
#   'keliling',
#   'dunia',
#   'percaya',
#   'suho',
#   'realisasi',
#   'malaikat',
#   'musik',
#   'korea'],
#  ['malaikat', 'musik', 'korea', 'suho', 'stanford'],
#  ['exol', 'bangga', 'ketua', 'suho', 'malaikat', 'musik', 'korea'],
#  ['bangga', 'ketua'],
#  ['suho', 'kemarin', 'kenal', 'dunia', 'dunia'],
#  ['bangga', 'kimjunmyeon'],
#  ['pagi', 'eri', 'baekhyu', 'tta', 'takut', 'salip', 'jarak', 'lumayan', 'no'],
#  ['gila', 'keren', 'ketua'],
#  ['salah', 'bangga', 'exol', 'sikap'],
#  ['keliling', 'dunia', 'suho', 'maju'],
#  ['bangga', 'suho'],
#  ['raja', 'kai'],
#  ['raja', 'kai'],
#  ['raja', 'jongin'],
#  ['suho', 'sma', 'habisin', 'nonton', 'vidio', 'tiktok', 'youtube'],
#  ['bangga', 'suho', 'henti', 'bangga', 'exol'],
#  ['mabuk', 'upadate', 'bareng'],
#  ['giat'],
#  ['sederhana', 'senang', 'cinta', 'tahan', 'bentar'],
#  ['ken', 'chibi', 'teman', 'wujud'],
#  ['spesial', 'collab', 'nama', 'kai', 'botol', 'borong', 'mimin'],
#  ['album', 'exomiraclesindecember', 'cinasver', 'ayo', 'beli', 'shopee'],
#  ['album', 'sc', 'whatalife', 'ayo', 'beli', 'shopee'],
#  ['pc', 'suho', 'album', 'tempo', 'ayo', 'beli', 'shopee'],
#  ['wts', 'album', 'loveshot', 'album', 'poster', 'detail', 'link'],
#  ['tunggu', 'tampil'],
#  ['chanyeol', 'instagram'],
#  ['halloaku',
#   'daftar',
#   'lagu',
#   'khusus',
#   'rekomendasi',
#   'kyungsoo',
#   'bubble',
#   'nikmat'],
#  ['suho', 'hun', 'chanyeol'],
#  ['chanyeo', 'instagram', 'mumpung', 'tutup', 'samperin'],
#  ['cerita', 'instagram', 'chanyeol', 'pergi', 'cafioca'],
#  ['hun',
#   'acara',
#   'dior',
#   'la',
#   'pagi',
#   'seoul',
#   'petang',
#   'acara',
#   'dior',
#   'malam',
#   'la',
#   'acara'],
#  ['hun', 'la'],
#  ['hun', 'la'],
#  ['baekhyun'],
#  ['kai'],
#  ['wts',
#   'kartu',
#   'foto',
#   'baekhyun',
#   'expan',
#   'baekhyun',
#   'perhiasa',
#   'jaemin',
#   'dom',
#   'bandung',
#   'jaga',
#   'acara',
#   'condi',
#   'bijak'],
#  ['pan', 'harap', 'temu', 'pan', 'dunia', 'nyata', 'cinta'],
#  ['mutual', 'exol', 'sijeuni', 'mutualan'],
#  ['suho', 'bahas', 'peran', 'grup', 'anggap', 'sosok', 'ketua'],
#  ['drama',
#   'korea',
#   'bintang',
#   'do',
#   'pratinjau',
#   'decolsin',
#   'obat',
#   'batuk',
#   'flu'],
#  ['nama',
#   'asa',
#   'dapet',
#   'jiwa',
#   'overdose',
#   'hyung',
#   'loey',
#   'koreografi',
#   'percaya',
#   'tinggal',
#   'do',
#   'koreografi'],
#  ['miraclesindecember',
#   'the',
#   'winter',
#   'special',
#   'album',
#   'ayo',
#   'beli',
#   'shopee'],
#  ['senang', 'bahagia', 'suho', 'cinta'],
#  ['versi', 'keteng', 'bunda', 'versi', 'lengkap', 'harap', 'sabar'],
#  ['ketua', 'aktif', 'ken', 'libur', 'ajak', 'libur', 'jumyeon'],
#  ['estetik'],
#  ['lucu',
#   'liat',
#   'kai',
#   'marah',
#   'gegara',
#   'eribong',
#   'sembunyi',
#   'kyungsoo',
#   'kyungsoo',
#   'perilaku',
#   'polos',
#   'hun',
#   'perhati',
#   'hyung',
#   'marah'],
#  ['sabar', 'kji', 'tunggu', 'arti', 'enlist'],
#  ['suara',
#   'baekhyun',
#   'tta',
#   'eri',
#   'ayo',
#   'keluarin',
#   'mode',
#   'suara',
#   'monster'],
#  ['pesan',
#   'suara',
#   'debut',
#   'cbx',
#   'jepang',
#   'cr',
#   'chenniepii',
#   'miss',
#   'chen'],
#  ['tinjau',
#   'chanyeol',
#   'muncul',
#   'asa',
#   'muncul',
#   'chanyeol',
#   'ngapain',
#   'libur',
#   'barak'],
#  ['kimjunmyeon', 'korea', 'korea', 'pergi', 'dubai', 'istirahat', 'myeonnie'],
#  ['baekhyun', 's', 'pulang'],
#  ['anginrambutku', 'photo', 'slide', 'video', 'dubai', 'tinggal'],
#  ['kabarin', 'hilang'],
#  ['tutup', 'aurora'],
#  ['badut', 'lay', 'suho'],
#  ['lay', 'rindu', 'peristiwa', 'exol', 'rindu', 'peristiwa'],
#  ['exol', 'bangun', 'fokus', 'idol', 'campur', 'urus', 'idol', 'bantu', 'rnb'],
#  ['exol', 'mutual', 'bantu', 'retweet', 'selektif'],
#  ['exol',
#   'istilah',
#   'idol',
#   'urus',
#   'fokus',
#   'campur',
#   'idol',
#   'garam',
#   'kencan',
#   'idol',
#   'ganti',
#   'foto',
#   'pribadi'],
#  ['fokus', 'eri', 'idol', 'campur'],
#  ['exol', 'fokus', 'campur'],
#  ['nama',
#   'lay',
#   'hapus',
#   'profil',
#   'sm',
#   'entertainment',
#   'protes',
#   'gemar',
#   'pasal',
#   'sm',
#   'entertainment',
#   'lay',
#   'nyata'],
#  ['chanyeol', 'trending', 'asa'],
#  ['niat', 'istirahat'],
#  ['nemu', 'video', 'tiktok', 'fyp', 'kangen'],
#  ['post', 'harap', 'palsu', 'ih'],
#  ['harap', 'bawain', 'lagu', 'fall', 'live', 'kaya'],
#  ['lay', 'panggil', 'baobei', 'panggil', 'lay', 'ge'],
#  ['instagram', 'junmyeon', 'gel', 'badan'],
#  ['lzen', 'istirahat', 'jeno', 'kapal', 'hun', 'muat', 'foto'],
#  ['silah',
#   'tameng',
#   'usik',
#   'kai',
#   'drama',
#   'grup',
#   'jeda',
#   'sayang',
#   'guncang',
#   'jagat',
#   'raya'],
#  ['susah', 'umin', 'brangkat', 'bawa', 'suasan', 'hati', 'linimasa', 'sedih'],
#  ['susah',
#   'stand',
#   'idol',
#   'pake',
#   'hati',
#   'senang',
#   'mulfand',
#   'bawa',
#   'idola',
#   'konten',
#   'bandingin',
#   'sedih',
#   'seru',
#   'rasain',
#   'exol'],
#  ['komentar', 'ditambahin', 'hilang', 'sembilan'],
#  ['pantes', 'dejavubukan', 'membandingkantapi', 'kangen', 'lemah'],
#  ['simpang', 'dikit', 'silah', 'laporin'],
#  ['ngaku',
#   'only',
#   'idol',
#   'only',
#   'serius',
#   'kali',
#   'bersih',
#   'bersih',
#   'khusus',
#   'ungu',
#   'ijo',
#   'silah',
#   'henti',
#   'ungu'],
#  ['mohon',
#   'maaf',
#   'moots',
#   'follow',
#   'ungu',
#   'ijo',
#   'henti',
#   'silah',
#   'moots',
#   'ku',
#   'henti',
#   'butuh',
#   'exol',
#   'moots',
#   'terimakasih'],
#  ['erti', 'usaha', 'paham', 'hakim'],
#  ['serius',
#   'gemar',
#   'foto',
#   'profil',
#   'exol',
#   'foto',
#   'profil',
#   'idol',
#   'lo',
#   'serius',
#   'segitukah',
#   'pikir',
#   'telaah',
#   'condong',
#   'lucu'],
#  ['lucu', 'lo', 'kemarin', 'ghibahin', 'akun', 'kali'],
#  ['hubung', 'paham', 'lo', 'exol', 'butuh', 'usik'],
#  ['sedih',
#   'tinggal',
#   'instagram',
#   'siar',
#   'ketua',
#   'pegang',
#   'hp',
#   'gara',
#   'scroll',
#   'tiktok',
#   'mulu',
#   'buka',
#   'instagram',
#   'selesai'],
#  ['kesal',
#   'agens',
#   'astaga',
#   'c',
#   'lay',
#   'hilang',
#   'mancing',
#   'ribut',
#   'sm',
#   'khawatir',
#   'semenjak',
#   'do',
#   'single',
#   'pokok'],
#  ['foto', 'maksud', 'foto', 'chanyeol', 'foto', 'profil', 'wa', 'asli'],
#  ['eri', 'kaum', 'jendes', 'lumutsiapapun', 'fokus'],
#  ['selesai', 'seret', 'tutup', 'kebusukanpembelaan', 'silah', 'rnb', 'minat'],
#  ['lucu',
#   'banding',
#   'idola',
#   'grup',
#   'jeda',
#   'protes',
#   'idol',
#   'sentuh',
#   'tenang',
#   'musik',
#   'member',
#   'mondar',
#   'mandir',
#   'fashion',
#   'variety',
#   'show',
#   'lakilaki',
#   'ku',
#   'grup',
#   'individual',
#   'nikmat',
#   'jrk'],
#  ['foto', 'sadar', 'exol', 'hahaha', 'paksa', 'gaya'],
#  ['ungu',
#   'obsesi',
#   'lo',
#   'muncul',
#   'jd',
#   'pakar',
#   'ekspresi',
#   'iri',
#   'segitu',
#   'obses',
#   'mikirin'],
#  ['ayok',
#   'only',
#   'mutualan',
#   'hijau',
#   'ungu',
#   'pink',
#   'mejikuhibiniu',
#   'khusus',
#   'exol',
#   'multi',
#   'solo',
#   'stan',
#   'grup',
#   'bantu'],
#  ['curiga', 'pabrik', 'anggur', 'bangga', 'kimjunmyeon'],
#  ['kangen',
#   'akun',
#   'retweet',
#   'suka',
#   'akun',
#   'akun',
#   'tahan',
#   'suara',
#   'akun',
#   'nyaman',
#   'sosial',
#   'media',
#   'segi'],
#  ['ketua', 'pamer', 'makan', 'mulu', 'ken', 'makan', 'bareng'],
#  ['episode',
#   'do',
#   'xiumin',
#   'gasabar',
#   'terjun',
#   'sisi',
#   'suho',
#   'kai',
#   'terjun'],
#  ['kai', 'cemburu'],
#  ['ladder', 'musim', 'besok', 'episode'],
#  ['suho', 'tanggung', 'lo', 'waras'],
#  ['konser', 'pencar', 'pan', 'ku'],
#  ['instagram',
#   'kimjuncotton',
#   'senang',
#   'temu',
#   'seni',
#   'dunia',
#   'putar',
#   'musik',
#   'dunia',
#   'putar'],
#  ['tonton',
#   'drama',
#   'korea',
#   'aktor',
#   'kyungsoo',
#   'kenal',
#   'kali',
#   'tau',
#   'do',
#   'mudah',
#   'mungil',
#   'nama'],
#  ['semenjak',
#   'wajib',
#   'militer',
#   'asa',
#   'hidup',
#   'jantung',
#   'cant',
#   'wait',
#   'for',
#   'exos'],
#  ['tiktok', 'muncul', 'kangen', 'buah', 'grup'],
#  ['dokyungsoo', 'trus', 'ketemu', 'najaemin'],
#  ['fokus', 'liat'],
#  ['curah',
#   'hati',
#   'makasih',
#   'tani',
#   'makasih',
#   'bahagia',
#   'sisa',
#   'hidup',
#   'cinta',
#   'allah',
#   'penasaran',
#   'istri'],
#  ['pidato', 'pergi', 'tidur', 'senang', 'pesan'],
#  ['dengar'],
#  ['artikel', 'do', 'batin', 'do', 'kyungsoo', 'periksa', 'tidur'],
#  ['cakep', 'kai'],
#  ['topik',
#   'follow',
#   'akun',
#   'kai',
#   'baca',
#   'dasar',
#   'kim',
#   'jongin',
#   'eh',
#   'kim',
#   'kai',
#   'deng',
#   'eh',
#   'juluk',
#   'kim'],
#  ['do', 'ngapain', 'imut'],
#  ['baekhyun', 'vokalis'],
#  ['dapet',
#   'kartu',
#   'foto',
#   'haechan',
#   'nct',
#   'chanyeol',
#   'koleksi',
#   'kartu',
#   'foto',
#   'chanyeol',
#   'exol',
#   'nctdream',
#   'tukeran'],
#  ['bicara', 'mimpi', 'seniman', 'peran', 'grup', 'lengkap'],
#  ['cerita', 'panggung', 'dengar', 'ria', 'gemar'],
#  ['suka', 'rambut', 'umin', 'warna', 'hitam'],
#  ['tarik',
#   'kereta',
#   'dorong',
#   'bawa',
#   'anggota',
#   'kereta',
#   'cerita',
#   'kisah',
#   'coba',
#   'dengar',
#   'anggota'],
#  ['ganteng', 'tiada', 'jeda'],
#  ['instagram', 'kimjuncotton', 'lampu', 'hijau', 'musik', 'korea', 'nyala'],
#  ['visual', 'mainmain', 'ketua'],
#  ['suho', 'majalah', 'singles'],
#  ['hoodie', 'celana', 'pendek', 'lepas'],
#  ['baekhyun'],
#  ['info',
#   'suho',
#   'tampil',
#   'acara',
#   'festival',
#   'musik',
#   'seoul',
#   'park',
#   'taman',
#   'olympic',
#   'seoul',
#   'juni'],
#  ['minseok', 'kabar'],
#  ['ratarata', 'lagu', 'lembut', 'dengar'],
#  ['info',
#   'suho',
#   'giat',
#   'dubai',
#   'festival',
#   'city',
#   'tanggal',
#   'mei',
#   'bawa',
#   'lagu',
#   'lotto'],
#  ['jaga', 'video', 'kai', 'youtube', 'ken', 'tidur', 'kai', 'indah', 'huhuhu'],
#  ['wajib', 'militer', 'gemar', 'penuh', 'berita', 'chanyeol', 'cinta'],
#  ['sayang', 'kimjongin', 'spam', 'pesan', 'gemas'],
#  ['wajib', 'militer', 'ganteng', 'dj', 'raiden', 'for', 'update'],
#  ['hyeong', 'ganteng', 'coba'],
#  ['haluan', 'teman', 'hidup', 'nama', 'halu', 'rendah', 'contoh'],
#  ['kabar',
#   'suho',
#   'junmyeon',
#   'bareng',
#   'ahjusshi',
#   'tiktok',
#   'muncul',
#   'hun'],
#  ['allah',
#   'baekhyun',
#   'ken',
#   'peluk',
#   'capek',
#   'kabar',
#   'pokok',
#   'sayang',
#   'baekhyun'],
#  ['murah',
#   'album',
#   'ku',
#   'album',
#   'printilan',
#   'kartu',
#   'foto',
#   'poster',
#   'tes',
#   'ombak',
#   'minat'],
#  ['baekhyun', 'gemas'],
#  ['kai', 'incheon', 'areaa'],
#  ['makasih',
#   'nyesel',
#   'kenal',
#   'suasana',
#   'hati',
#   'pikir',
#   'percaya',
#   'obat',
#   'cinta'],
#  ['baekhyuns', 'aura', 'debut'],
#  ['kapas', 'kena', 'angin', 'eropa', 'aura', 'badai'],
#  ['makasih', 'suasana', 'hati', 'gegara', 'baekhyun', 'kasih', 'kabar'],
#  ['chanyeol', 'ganteng', 'chanyeol', 'ganteng', 'chanyeol', 'ganteng'],
#  ['park', 'chanyeol', 'idol', 'wajib', 'militer', 'foto', 'hd'],
#  ['rambut', 'suka'],
#  ['chen',
#   'kasih',
#   'hadiah',
#   'video',
#   'unggah',
#   'youtube',
#   'ayok',
#   'ikan',
#   'chen',
#   'penuh',
#   'tiket',
#   'sore',
#   'teman'],
#  ['kai',
#   'hyung',
#   'bandara',
#   'keren',
#   'mode',
#   'pacar',
#   'jalan',
#   'red',
#   'carpet',
#   'cocok',
#   'lahir'],
#  ['nonton',
#   'ladder',
#   'eps',
#   'seru',
#   'kai',
#   'kasi',
#   'makan',
#   'yogurt',
#   'curiga',
#   'kyungsoo'],
#  ['suho', 'suho'],
#  ['subscribe',
#   'youtube',
#   'chen',
#   'akun',
#   'google',
#   'youtube',
#   'chen',
#   'tuju',
#   'dandelion',
#   'kabar',
#   'jongdae'],
#  ['comeback'],
#  ['borong'],
#  ['kangen'],
#  ['ganteng'],
#  ['fokus', 'park', 'chanyeol', 'ganteng', 'seragam'],
#  ['thank', 'kai', 'laku', 'sayang', 'kai'],
#  ['baekhyun'],
#  ['kangen', 'huhuhu'],
#  ['vokalis',
#   'boygroup',
#   'sm',
#   'nomer',
#   'changmin',
#   'nomer',
#   'kry',
#   'nomer',
#   'chen',
#   'fix',
#   'gaada',
#   'debat'],
#  ['lucu', 'suara', 'lucu', 'chanyeol', 'chanyeol'],
#  ['nonton', 'konten', 'sembuh'],
#  ['kpop',
#   'kobam',
#   'kokobop',
#   'lagu',
#   'teman',
#   'lambang',
#   'foto',
#   'profil',
#   'instagram',
#   'ganja'],
#  ['tau',
#   'nada',
#   'musik',
#   'lagu',
#   'mama',
#   'kode',
#   'tarung',
#   'tau',
#   'diamdiam',
#   'tau'],
#  ['rumah', 'hantu', 'tao', 'takut', 'hun', 'ketawa', 'takut'],
#  ['ken',
#   'liat',
#   'ot',
#   'jelasin',
#   'senang',
#   'kumpul',
#   'ganjal',
#   'tunggu',
#   'ot',
#   'kumpul',
#   'tunggu'],
#  ['gegara', 'liat', 'in', 'idol', 'muda', 'aura', 'matang'],
#  ['rangka',
#   'kangen',
#   'tidur',
#   'nonton',
#   'chanyeol',
#   'the',
#   'box',
#   'chanyeol',
#   'keren',
#   'park',
#   'chanyeol'],
#  ['besok', 'beli', 'album', 'rilis'],
#  ['jatuh', 'cinta', 'era', 'power', 'gantengganteng'],
#  ['do',
#   'ama',
#   'jaemin',
#   'main',
#   'drama',
#   'nonton',
#   'drama',
#   'member',
#   'nct',
#   'wajib',
#   'tonton'],
#  ['makasih',
#   'cetus',
#   'konsep',
#   'alien',
#   'planet',
#   'kuat',
#   'masihmasing',
#   'salah',
#   'alas',
#   'nge',
#   'stan',
#   'konsep',
#   'unik',
#   'beda',
#   'teori',
#   'kaya',
#   'seru'],
#  ['tagih', 'nonton', 'reaksi', 'video', 'sayang', 'rugi', 'kenal'],
#  ['sm', 'entertainment', 'nama', 'lay', 'profil', 'resmi'],
#  ['hasil',
#   'toreh',
#   'prestasi',
#   'bangga',
#   'salah',
#   'nations',
#   'pick',
#   'warga',
#   'korsel',
#   'sukses',
#   'agens',
#   'bakat',
#   'member',
#   'lengkap',
#   'klik',
#   'link'],
#  ['kangen', 'hun', 'kangen', 'kangen', 'kyungsoo'],
#  ['kangen', 'gatau', 'drama', 'nonton', 'do', 'kyungsoo', 'lucu'],
#  ['heran', 'diam', 'puncak'],
#  ['stabil', 'peringkat', 'jarang', 'bangga'],
#  ['tuju',
#   'baekhyun',
#   'sejarah',
#   'musik',
#   'korea',
#   'grup',
#   'coba',
#   'program',
#   'hibur',
#   'akting'],
#  ['nomor', 'hati', 'ganti'],
#  ['jujur',
#   'bridges',
#   'bagus',
#   'bagus',
#   'lagu',
#   'bridges',
#   'merinding',
#   'dengarin',
#   'lagu',
#   'batu',
#   'era',
#   'tempo',
#   'mantap'],
#  ['bayangin', 'nct', 'svt', 'treasure', 'kumpul', 'rame', 'macem'],
#  ['setia', 'era', 'gempur', 'idol'],
#  ['suka', 'kpop', 'gara', 'gara', 'bts'],
#  ['luhan',
#   'suho',
#   'lay',
#   'chanyeol',
#   'baekhyun',
#   'kyungsoo',
#   'hun',
#   'kai',
#   'member',
#   'kenal',
#   'debut'],
#  ['contoh',
#   'makhluk',
#   'otak',
#   'dianugrahi',
#   'etik',
#   'lapor',
#   'blokir',
#   'libat'],
#  ['konser', 'dubai', 'gratis', 'allah', 'indonesia'],
#  ['hidup', 'waras', 'susah'],
#  ['jeda', 'sepi', 'konten', 'jeda', 'exol', 'mabok', 'visual'],
#  ['trend', 'pocky', 'mahal'],
#  ['junmyeon', 'paksa', 'ketemu', 'klien'],
#  ['lagu', 'cover', 'dapet'],
#  ['tao', 'member', 'menang', 'fakta'],
#  ['kangen',
#   'semangat',
#   'promosi',
#   'kabar',
#   'senang',
#   'semangat',
#   'promosi',
#   'semangat',
#   'hidup',
#   'nggak'],
#  ['ninggal', 'linimasa', 'dikit', 'promosi', 'pindah'],
#  ['asli',
#   'nyala',
#   'notif',
#   'instagram',
#   'member',
#   'hun',
#   'jongin',
#   'kemaren',
#   'cerita',
#   'instagram',
#   'gaada',
#   'pemberitahuan'],
#  ['jatuh', 'brondong', 'dream'],
#  ['sadar',
#   'stan',
#   'momen',
#   'utama',
#   'suka',
#   'hun',
#   'promosi',
#   'dukung',
#   'stan',
#   'era',
#   'momen',
#   'member'],
#  ['suka',
#   'nonton',
#   'video',
#   'konser',
#   'suju',
#   'shinee',
#   'asa',
#   'nggak',
#   'lipsync',
#   'coba',
#   'tonton',
#   'konser',
#   'idol',
#   'sm',
#   'greget'],
#  ['harap', 'muluk', 'liat', 'kangen']]

# %%
#stopwords removal
stopword = stopwords.words("indonesian")
stopword.extend(["exo", "yaa", "guys", "ngabrut", "awokawokawok", "bengek", "awokawokawok", "akuuhhh", "siii", "huaaaaa", "amp", "chat", "plis", "dg", 
                 "toh", "gak", "otw", "kok", "dm", "u", "haha", "ayokk", "kuy", "bestie", "apaan", "rt", "yukk", "deh", "pliss", "gua", "php", "doang", "ooh", "tuhan", "kayanya",
                 "gpp", "gw", "gua", "Hemm", "please", "yak", "deg", "an", "poll", "Wkwk", "ya", "wkwkkwkw", "bapak", "hbd", "babang", "tks", "pls", "thn", "nd", "gaes", 
                 "yeah", "wah", "btw", "dah", "hiks", "duh", "hehey", "ehh", "papi", "yok", "woii", "rp", "Huhuhu", "oleng", "ayang", "k", "sumpah", "ter", "beb", "yoy", 
                 "ab", "abai", "th", "adeknya", "zetkidlin", "zulkidin", "abis", "adem", "bilang", "lihat", "tolong", "gitu", "situ", "lari", "tangan", "pas", "cari", "biar", "oke", "on",
                 "pakai", "ayah", "pas", "juta", "jam", "menit", "orang", "ubah", "papa", "by", "lupa", "mari", "duluan", "betapa", "ubah", "to", "anak", "pilih", "selamat", "ulang", "tahun",
                 "bikin", "gimana", "gin", "moga", "terima", "jual", "kirim", "capai", "lampau", "kayak", "langsung", "harga", "emang", "yey", "yuhu", "ygngg", "with", "agak",
                 "ya", "guys", "selamat", "mas", "nya", "bgt", "amp", "untuk", "x", "dg", "udah", "kuy", "by", "ooh", "gaes", "dah", "ya", "bang", "th", "tuh", "aja", "yg",
                 "ini", "kayak", "lu", "kan", "ter", "yuk", "kalo", "lagi", "loh", "of", "abang", "ga", "kek", "gk", "wkwk", "si", "and", "sih", "banget", "thanks", "sih", "omg", "ga", "gk", "iya", 
                 "jg", "nang", "its", "okey", "kek", "oh", "hehe", "gue", "my", "mu", "nih", "adik", "agakagak", "ah", "yaampun", "yangs", "you", "your", "yoo", "yangyang", "aka", "wkwkwk"])

datafinal1 = []
for line in data_no_punc_pos:
  word_token = nltk.word_tokenize(line)
  word_token = [word for word in word_token if word not in stopword and not word[0].isdigit()]
  datafinal1.append(word_token)

datafinal1
# Out:
# [['laku', 'baekhyun'],
#  ['peristiwa', 'kumpul'],
#  ['tertawa',
#   'tingkah',
#   'hun',
#   'tim',
#   'produksi',
#   'kyungsoo',
#   'sesak',
#   'nafas',
#   'kai',
#   'hun',
#   'alias',
#   'raja',
#   'kakak'],
#  ['laku', 'baekhyun'],
#  ['pikir',
#   'milik',
#   'tunggu',
#   'sulit',
#   'kenang',
#   'masamasa',
#   'bahagia',
#   'bersiapsiap',
#   'temu',
#   'ayo',
#   'temu',
#   'cepat',
#   'cinta',
#   'exol'],
#  ['baekhyun'],
#  ['pamer',
#   'debut',
#   'konser',
#   'bahagia',
#   'smtown',
#   'temu',
#   'sehat',
#   'temu',
#   'buah',
#   'janji',
#   'tinggal'],
#  ['baekhyun'],
#  ['cbx', 'sayang'],
#  ['debut', 'beda', 'beda', 'heran', 'exol', 'tahan', 'banting'],
#  ['ganteng'],
#  ['exocbx',
#   'jepang',
#   'debut',
#   'cepat',
#   'baekhyun',
#   'selesai',
#   'wajib',
#   'militer'],
#  ['update', 'pesan', 'xiumin', 'exocbx', 'debut', 'japan'],
#  ['baekhyun'],
#  ['laku', 'baekhyun'],
#  ['senang',
#   'gila',
#   'pesan',
#   'unggah',
#   'suho',
#   'gatau',
#   'perhatiin',
#   'ngga',
#   'kaya',
#   'aneh',
#   'foto',
#   'selfie',
#   'suho'],
#  ['cerita',
#   'lagu',
#   'sedih',
#   'nikmat',
#   'musik',
#   'permission',
#   'dance',
#   'dont',
#   'fight',
#   'the',
#   'feeling',
#   'hangat',
#   'senang',
#   'untung',
#   'candu',
#   'drama',
#   'korea',
#   'cinta',
#   'musik',
#   'korea',
#   'sembuh'],
#  ['hun', 'diorerl'],
#  ['incheon', 'dubai'],
#  ['suho', 'terbang', 'dubai', 'japan', 'usa', 'seoul'],
#  ['pikat', 'sihir', 'jiwa', 'kagum', 'pandang', 'dunia'],
#  ['kai', 'the', 'exordium', 'seoul', 'iconic'],
#  ['kumpul', 'senang', 'sehatsehat'],
#  ['aura', 'aktor', 'hun', 'yeonseok'],
#  ['china',
#   'puncak',
#   'peringkat',
#   'daftar',
#   'top',
#   'pasar',
#   'musik',
#   'dunia',
#   'ifpi',
#   'puncak',
#   'daftar',
#   'bantu',
#   'pasar',
#   'cina'],
#  ['terbang', 'seoul', 'dubai', 'seoul'],
#  ['hubung',
#   'tim',
#   'uang',
#   'ace',
#   'jeda',
#   'detail',
#   'hasil',
#   'donasi',
#   'kjm',
#   'terimakasih',
#   'donatur',
#   'tim',
#   'streaming',
#   'jumpa',
#   'projek'],
#  ['ig',
#   'musik',
#   'unggah',
#   'baju',
#   'sengaja',
#   'lelah',
#   'kasih',
#   'latih',
#   'ajar'],
#  ['suka', 'lagu', 'bayang', 'nyanyi'],
#  ['bentar', 'juni', 'dont', 'fight', 'for', 'then', 'feeling', 'no', 'matter'],
#  ['jaehyuk', 'baekhyun', 'renjun', 'jisung'],
#  ['runaway'],
#  ['exol', 'ayok', 'mutualan', 'kawan', 'besti'],
#  ['maknae', 'palsu', 'xiumin'],
#  ['eri', 'ayo', 'semangat', 'dukung', 'baekhyun', 'jarak', 'tipis'],
#  ['vitamin', 'xiu', 'tahan', 'vitamin', 'xiu', 'minggu', 'xiumin'],
#  ['masternim', 'kai', 'aktif', 'aumicky'],
#  ['member', 'kangen', 'kah'],
#  ['nyata', 'foto', 'hun', 'smc'],
#  ['muncul',
#   'sosial',
#   'media',
#   'intip',
#   'jalan',
#   'cinta',
#   'jennie',
#   'blackpink',
#   'kai',
#   'v',
#   'bts'],
#  ['nego', 'mulus', 'isi', 'lengkap'],
#  ['baekhyun'],
#  ['baekhyun'],
#  ['suho', 'terbang', 'dubai', 'jepang', 'usa', 'seoul'],
#  ['hun', 'instragram', 'hun', 'foto', 'suho', 'member'],
#  ['foto', 'simpel', 'bagus', 'feed', 'instagram', 'rapi', 'estetik'],
#  ['hun', 'instagram', 'imut', 'imut', 'imut', 'sayang'],
#  ['suho', 'hun'],
#  ['hun'],
#  ['doa',
#   'gaboleh',
#   'ragu',
#   'salah',
#   'foto',
#   'jodoh',
#   'serah',
#   'kanan',
#   'kiri',
#   'samping',
#   'kanan',
#   'samping',
#   'kiri'],
#  ['suho', 'instagram', 'jumpa'],
#  ['baekhyun'],
#  ['smtown', 'shanghai'],
#  ['sembilan', 'saranghaja'],
#  ['hun'],
#  ['sehat', 'nyapa', 'exol', 'cinta', 'oppa'],
#  ['usaha', 'stabil', 'pikir'],
#  ['suho', 'terimakasih', 'sehat', 'sukses', 'karir', 'solo', 'grup'],
#  ['exol', 'habis', 'kena', 'drama', 'makasih', 'hun'],
#  ['hun'],
#  ['suho'],
#  ['suho'],
#  ['ketua', 'terimakasih', 'kerja', 'keras', 'sehat', 'temu', 'terimakasih'],
#  ['dengar', 'nada', 'lagu', 'judul', 'playboy'],
#  ['hemm', 'ganteng'],
#  ['kumpul',
#   'barang',
#   'sedia',
#   'alias',
#   'sedia',
#   'alias',
#   'ls',
#   'list',
#   'officialunoff',
#   'oriofficial',
#   'unoff',
#   'oriofficial',
#   'ngga'],
#  ['takut', 'tau', 'senang'],
#  ['ganti', 'agens', 'sm', 'hibur', 'senang', 'acara', 'tibatiba'],
#  ['exol', 'baekhyun'],
#  ['bukti',
#   'tangkap',
#   'layar',
#   'suho',
#   'grey',
#   'suit',
#   'dday',
#   'greysuit',
#   'pm'],
#  ['allah',
#   'hun',
#   'ganteng',
#   'coba',
#   'kasih',
#   'tau',
#   'kalahin',
#   'ganteng',
#   'tuan',
#   'muda',
#   'hun'],
#  ['aktivitas', 'kris', 'wu', 'trend', 'kris', 'wu', 'bebas'],
#  ['suho', 'ketua', 'super'],
#  ['akun',
#   'twitter',
#   'hallyu',
#   'pop',
#   'fest',
#   'london',
#   'info',
#   'video',
#   'pesan',
#   'artis',
#   'chen',
#   'hadir'],
#  ['lay', 'coba', 'popcorn', 'orangorang'],
#  ['happy',
#   'birthday',
#   'junmyeon',
#   'kasih',
#   'salah',
#   'warna',
#   'hidup',
#   'harap',
#   'junmyeon',
#   'bahagia',
#   'laku',
#   'nikmat',
#   'sayang',
#   'kimjunmyeon'],
#  ['suho', 'mumpung', 'bareng', 'beli', 'kue'],
#  ['baekhyun', 'tta'],
#  ['suho', 'terbang', 'dubai', 'jepang', 'c', 'usa', 'seoul'],
#  ['maudy', 'nikah', 'marga', 'choi', 'nikah', 'marga', 'kim'],
#  ['baekhyun'],
#  ['milih',
#   'baekhyun',
#   'exol',
#   'baekhyun',
#   'tta',
#   'exol',
#   'baekhyun',
#   'tta',
#   'exol',
#   'baekhyun',
#   'tta'],
#  ['fokus', 'idol', 'cinta', 'promosi', 'exomember', 'utama'],
#  ['urus', 'perang', 'exol'],
#  ['no', 'dvd', 'kive', 'japan', 'suho'],
#  ['tinjau',
#   'drama',
#   'korea',
#   'days',
#   'prince',
#   'do',
#   'namjihyun',
#   'tokoh',
#   'utama'],
#  ['kasih', 'ketua', 'kasih', 'jaga', 'member'],
#  ['suho', 'kasih', 'lahir', 'kasih', 'smtown', 'kasih', 'lagu', 'bagus'],
#  ['ketua', 'kimjunmyeon', 'kasih', 'juang', 'kasih', 'exol'],
#  ['leader', 'hebat', 'sehat', 'kuat', 'dukung', 'tunggu', 'kau', 'laku'],
#  ['ketua', 'sayang', 'aeri'],
#  ['kencang', 'kencang', 'perang', 'kencang', 'baekhyun'],
#  ['selesai',
#   'atur',
#   'album',
#   'greysuit',
#   'min',
#   'suho',
#   'keren',
#   'foto',
#   'cuman',
#   'kacamata',
#   'hitam',
#   'nambah',
#   'ganteng'],
#  ['maaf', 'tim', 'exol', 'only', 'exol'],
#  ['suho', 'sehat', 'sehat'],
#  ['suho', 'sayang', 'harap'],
#  ['lamar',
#   'suho',
#   'terimakasih',
#   'ketua',
#   'baikpendengar',
#   'baikorang',
#   'hidupaku',
#   'cinta'],
#  ['ketua', 'ganteng', 'estetik'],
#  ['anggota',
#   'sibuk',
#   'giat',
#   'exol',
#   'sembilan',
#   'dukung',
#   'member',
#   'sayang'],
#  ['kimjunmyeon',
#   'sehat',
#   'makan',
#   'kurus',
#   'promosi',
#   'grey',
#   'suit',
#   'kasih',
#   'bahagia',
#   'exol',
#   'bangga',
#   'love'],
#  ['trinity',
#   'bias',
#   'kemarin',
#   'tinggal',
#   'wajib',
#   'militer',
#   'bareng',
#   'pulang',
#   'bareng'],
#  ['tampan', 'suara', 'emas', 'nyanyi', 'sayang', 'kimjunmyeon', 'suho'],
#  ['kimjunmyeon', 'umur', 'sehat', 'doa'],
#  ['ketua', 'suho', 'bahagia', 'sehat', 'ketua', 'tau', 'harap', 'cinta'],
#  ['ketua',
#   'kimjunmyeon',
#   'makasih',
#   'ketua',
#   'jaga',
#   'member',
#   'makasih',
#   'sehat',
#   'bahagia',
#   'cinta',
#   'happy',
#   'birthday',
#   'suho'],
#  ['kimjunmyeon', 'doa'],
#  ['kimjunmyeon',
#   'umur',
#   'sehat',
#   'sukses',
#   'berkarir',
#   'ganteng',
#   'cepat',
#   'kumpul',
#   'member'],
#  ['ketua',
#   'sayang',
#   'exol',
#   'kasih',
#   'jaga',
#   'kerja',
#   'keras',
#   'exol',
#   'sehat',
#   'bahagia',
#   'cinta'],
#  ['utama', 'sampul', 'singles', 'edisi', 'juni', 'suho'],
#  ['ketua', 'bahagia', 'sukses', 'bahagia', 'terimakasih', 'malaikat', 'jaga'],
#  ['suho', 'ketua', 'sayang', 'ketua', 'bangga', 'cinta', 'kimjunmyeon'],
#  ['ketua',
#   'kak',
#   'suho',
#   'kasih',
#   'ketua',
#   'sabar',
#   'sehat',
#   'bahagia',
#   'kak'],
#  ['ketua', 'suho'],
#  ['kimjunmyeon', 'umur', 'sehat', 'bangga', 'suho', 'member'],
#  ['kimjunmyeon', 'umur', 'sehat', 'bangga', 'suho', 'member'],
#  ['selamt', 'kimjunmyeon', 'umur', 'sehat', 'bangga', 'suho', 'member'],
#  ['kimjunmyeon', 'umur', 'sehat'],
#  ['kimjunmyeon', 'umur', 'sehat', 'bangga', 'suho', 'member'],
#  ['kimjunmyeon', 'bangga', 'suho', 'member'],
#  ['kimjunmyeon', 'ketua', 'sabar', 'umur', 'sehat'],
#  ['kimjunmyeon', 'umur', 'sehat', 'bangga', 'suho', 'member'],
#  ['kimjunmyeon', 'ketua', 'terimakasih', 'kerja', 'keras'],
#  ['ketua', 'kimjunmyeon', 'sehat', 'bahagia'],
#  ['suho', 'kimjunmyeon', 'jumpa', 'konser', 'idol', 'gemar', 'cinta'],
#  ['kimjunmyeon', 'harap', 'sehat', 'bahagia'],
#  ['kai', 'icu', 'awakening', 'dir', 'jae', 'via'],
#  ['kimjunmyeon',
#   'ketua',
#   'terimakasih',
#   'kerja',
#   'keras',
#   'exol',
#   'bangga',
#   'sehat',
#   'temu'],
#  ['ngomongin',
#   'pimpin',
#   'kasih',
#   'jempol',
#   'ngomongin',
#   'bakat',
#   'salah',
#   'main',
#   'non',
#   'vokal',
#   'favorit',
#   'daya',
#   'foto',
#   'suka'],
#  ['twibbon',
#   'suho',
#   'day',
#   'bingkai',
#   'foto',
#   'desain',
#   'sederhana',
#   'elegan',
#   'raya',
#   'suho',
#   'is',
#   'nine'],
#  ['sayang',
#   'kasih',
#   'hadir',
#   'hidup',
#   'kasih',
#   'karya',
#   'kerja',
#   'keras',
#   'keren',
#   'kasih',
#   'sehat'],
#  ['baju',
#   'suho',
#   'jaemin',
#   'tulis',
#   'jeno',
#   'kece',
#   'omong',
#   'omong',
#   'kimjunmyeon',
#   'sehat',
#   'sehat',
#   'bahagia',
#   'kim',
#   'jumyeon',
#   'jeno',
#   'jaemin'],
#  ['happy',
#   'birthday',
#   'kimjunmyeon',
#   'sehat',
#   'selalukuat',
#   'semangat',
#   'bahagia',
#   'makasih',
#   'juang',
#   'tahan',
#   'inisemoga',
#   'berkat',
#   'senantiasa',
#   'cinta'],
#  ['lakilaki', 'gemar', 'bangga'],
#  ['suho',
#   'kasih',
#   'ketua',
#   'jaga',
#   'bimbing',
#   'kasih',
#   'tahan',
#   'iniselalu',
#   'jaga',
#   'sehat',
#   'bahagia',
#   'suho',
#   'kimjunmyeon'],
#  ['suho',
#   'hyeong',
#   'cape',
#   'kali',
#   'bangun',
#   'tidur',
#   'kasihan',
#   'mata',
#   'bahagia',
#   'spesial',
#   'siar',
#   'sapa',
#   'eri'],
#  ['nggak',
#   'tinggal',
#   'ketua',
#   'siar',
#   'terimakasih',
#   'suho',
#   'aktif',
#   'update'],
#  ['baju', 'jaemin', 'jalan', 'mall', 'ketua', 'suho', 'cinta', 'kucing'],
#  ['suho', 'baju', 'jaemin', 'siar', 'instagram', 'jaemin', 'jeno', 'dreamies'],
#  ['kimjunmyeon', 'sehat', 'karir', 'lancar', 'pokok', 'nikmat', 'indah'],
#  ['kimjunmyeon',
#   'lulus',
#   's',
#   'inha',
#   'university',
#   'junmyeon',
#   'cy',
#   'program',
#   'giat',
#   'sekolah',
#   'musim',
#   'panas',
#   'universitas',
#   'inha',
#   'unv'],
#  ['exol', 'exol', 'gatau', 'sayang', 'sehat', 'sehat'],
#  ['nyaman', 'sembilan', 'pokok', 'nambah', 'inti', 'sembilan'],
#  ['minseok',
#   'vokal',
#   'bagus',
#   'minseok',
#   'tar',
#   'bagus',
#   'minseok',
#   'nyanyi',
#   'bagus',
#   'minseok',
#   'kakak',
#   'hebat'],
#  ['minseok',
#   'vokal',
#   'bagus',
#   'minseok',
#   'nari',
#   'bagus',
#   'minseok',
#   'nyanyi',
#   'bagus',
#   'minseok',
#   'kakak',
#   'hebat'],
#  ['perang', 'gemar', 'saing', 'via', 'suara', 'eriexol'],
#  ['tertawa', 'hun', 'semangat', 'xiumin', 'takut', 'bayi'],
#  ['hubung', 'penggemarpenggemarku', 'percaya', 'bersamasama'],
#  ['percaya', 'sisi', 'lotto'],
#  ['ganteng', 'kimjunmyeon'],
#  ['suho',
#   'duta',
#   'ikutin',
#   'jejak',
#   'gege',
#   'yixing',
#   'keren',
#   'pokok',
#   'ketua'],
#  ['baekhyun', 'tta'],
#  ['bantu',
#   'minimal',
#   'bantu',
#   'hashtag',
#   'kalah',
#   'perang',
#   'skefo',
#   'lawan',
#   'kremy',
#   'exol',
#   'baekhyun',
#   'tta',
#   'exol',
#   'vote',
#   'baekhyun',
#   'tta',
#   'exol',
#   'baekhyun',
#   'tta'],
#  ['suho', 'bicara', 'konferensi', 'studi', 'korea', 'universitas', 'stanford'],
#  ['suho', 'ketua', 'bawa', 'korea', 'musik', 'cinta'],
#  ['exol', 'ayo', 'baekhyun', 'tta', 'link'],
#  ['kangen', 'konser', 'nonton', 'konser', 'dreamies'],
#  ['baekhyun', 'jarak'],
#  ['info', 'pergi', 'dunia', 'tangga', 'musim', 'siar', 'trans', 'tv', 'juli'],
#  ['info',
#   'artikel',
#   'keliling',
#   'dunia',
#   'tangga',
#   'musim',
#   'siar',
#   'indonesia',
#   'trans',
#   'tv',
#   'juli'],
#  ['episode',
#   'bahagia',
#   'senyum',
#   'bahagia',
#   'jalan',
#   'muas',
#   'tertawa',
#   'lepas',
#   'layar'],
#  ['dubai', 'tunggu', 'suho'],
#  ['suho',
#   'stanford',
#   'panggil',
#   'suho',
#   'junmyeon',
#   'oppa',
#   'panggil',
#   'seonsaengnim',
#   'guru',
#   'karna',
#   'cuman',
#   'seonsaengnim',
#   'leesooman',
#   'sunbaenim',
#   'suka'],
#  ['info', 'beli', 'lightstick', 'versi', 'jogja'],
#  ['kyungsoo', 'jenius'],
#  ['suho', 'bangga'],
#  ['berputa', 'whitenoise', 'gulir', 'retweet', 'penuhin', 'linimasa', 'moots'],
#  ['suho', 'bangga', 'member'],
#  ['jongin', 'suka', 'jerit'],
#  ['chanyeol', 'layan', 'jjareu', 'ratu'],
#  ['chanyeol',
#   'putri',
#   'sayang',
#   'putri',
#   'bonus',
#   'foto',
#   'instragram',
#   'toben'],
#  ['astaga', 'penasaran', 'bau', 'suho', 'wangi'],
#  ['tau',
#   'stan',
#   'fandom',
#   'favorit',
#   'judul',
#   'lagu',
#   'tempo',
#   'favorit',
#   'bside',
#   'been',
#   'through',
#   'favorit',
#   'video',
#   'musik',
#   'overdose',
#   'favorit',
#   'koreografi',
#   'history',
#   'bias',
#   'do',
#   'bias',
#   'do',
#   'chanyeol'],
#  ['keluarga',
#   'sm',
#   'sibuk',
#   'nct',
#   'dream',
#   'tampil',
#   'nct',
#   'siar',
#   'ig',
#   'wayv',
#   'siar',
#   'weibo',
#   'sambut',
#   'rv',
#   'bandara',
#   'liat',
#   'suho',
#   'stanford',
#   'nambah'],
#  ['manusia',
#   'manusia',
#   'keren',
#   'tampan',
#   'wibawa',
#   'muda',
#   'kaya',
#   'sempurna'],
#  ['bias', 'bias', 'bias', 'hancur', 'pokok', 'kai'],
#  ['tampil', 'everglow', 'sf', 'panggung', 'tampil', 'bagus'],
#  ['ramai',
#   'mutualan',
#   'exol',
#   'multi',
#   'mutual',
#   'solo',
#   'stan',
#   'bantu',
#   'retweet'],
#  ['permisi',
#   'ayo',
#   'nyari',
#   'mututal',
#   'exol',
#   'multi',
#   'ungu',
#   'ijo',
#   'orange',
#   'kelabu',
#   'solo',
#   'stan',
#   'khusus',
#   'onl',
#   'rapat',
#   'bantu',
#   'retweet',
#   'kasih'],
#  ['kyungsoo',
#   'cinderella',
#   'versi',
#   'cowok',
#   'kyungja',
#   'sepatu',
#   'hilang',
#   'hun',
#   'ketawa',
#   'puas'],
#  ['baekhyun'],
#  ['aura', 'tuan', 'pabrik', 'wine'],
#  ['bahas', 'hadir', 'konferensi', 'studi', 'korea', 'universitas', 'stanford'],
#  ['hadir',
#   'konferensi',
#   'studi',
#   'korea',
#   'universitas',
#   'stanford',
#   'bahas',
#   'pengaruh',
#   'gelombang',
#   'hallyu',
#   'lengkap'],
#  ['daebak',
#   'suho',
#   'oppa',
#   'well',
#   'done',
#   'eri',
#   'khusyuk',
#   'dengar',
#   'fokus',
#   'suho'],
#  ['sempurna', 'tuan', 'muda', 'hun', 'diorerl'],
#  ['jongin', 'lucu', 'cerita', 'kaya', 'antusias'],
#  ['chen', 'sibuk', 'idol', 'status', 'suami'],
#  ['profile', 'chen', 'idol', 'pria', 'sukses', 'nyanyi', 'solo'],
#  ['potret',
#   'tampan',
#   'suho',
#   'bicara',
#   'diskusi',
#   'panel',
#   'university',
#   'stanford',
#   'fokus'],
#  ['bahasa',
#   'inggris',
#   'suho',
#   'bagus',
#   'bangga',
#   'suho',
#   'usaha',
#   'ajar',
#   'bahasa',
#   'inggris',
#   'lancar',
#   'ngomongnya',
#   'apresiasi',
#   'suho'],
#  ['amerika',
#   'konser',
#   'amerika',
#   'ngisi',
#   'seminar',
#   'stanford',
#   'bangga',
#   'dengamu',
#   'ketua'],
#  ['deja', 'vu', 'foto', 'junmyeon', 'foto', 'pokok', 'foto', 'bicara'],
#  ['aura', 'pintar', 'beda'],
#  ['suho',
#   'hadir',
#   'konferensi',
#   'studi',
#   'korea',
#   'universitas',
#   'stanford',
#   'panel',
#   'diskusi',
#   'koreawave',
#   'kisah',
#   'pribadi',
#   'artis',
#   'korea',
#   'pop',
#   'pengaruh',
#   'global',
#   'budaya',
#   'korea',
#   'hidup',
#   'seharihari',
#   'korea'],
#  ['bangga', 'suami', 'online'],
#  ['ketua', 'keren'],
#  ['bangga', 'ketua'],
#  ['jadwal', 'padat'],
#  ['bangga'],
#  ['baekhyun', 'toge', 'inumaki'],
#  ['jujur',
#   'dengar',
#   'lagu',
#   'keren',
#   'gila',
#   'suka',
#   'terngiangngiang',
#   'lagu',
#   'dengar',
#   'dengar',
#   'keren'],
#  ['aura', 'aura', 'aura', 'ketua', 'leader', 'bangga', 'kimjunmyeon'],
#  ['bangga',
#   'suho',
#   'ketua',
#   'dunia',
#   'kenal',
#   'exol',
#   'korea',
#   'musik',
#   'sungguh',
#   'masingmasing',
#   'exol',
#   'bangga',
#   'kenal'],
#  ['jujur',
#   'haru',
#   'bahagia',
#   'allah',
#   'suho',
#   'keren',
#   'hebat',
#   'wibawa',
#   'henti',
#   'keren',
#   'bangga',
#   'cinta',
#   'bangga',
#   'kimjunmyeon'],
#  ['suho', 'konser', 'nabung'],
#  ['suho',
#   'keren',
#   'ken',
#   'sekolah',
#   'ajar',
#   'rajin',
#   'paham',
#   'bakat',
#   'keren',
#   'kaya',
#   'suhoacademik',
#   'nonacademik',
#   'sikap',
#   'loyalitas',
#   'visual',
#   'mantep',
#   'bintang'],
#  ['bangga',
#   'suho',
#   'salah',
#   'manusia',
#   'bangga',
#   'kagum',
#   'member',
#   'bangga',
#   'exol',
#   'sayang',
#   'exol'],
#  ['pesona', 'tampan', 'dosen', 'muda'],
#  ['pokok',
#   'bangga',
#   'baper',
#   'suho',
#   'ngelakuin',
#   'neng',
#   'campur',
#   'haru',
#   'bangga',
#   'suhoexoand',
#   'exol'],
#  ['bangga',
#   'ketua',
#   'banga',
#   'suho',
#   'presentasi',
#   'keren',
#   'liat',
#   'nikmat',
#   'wibawa',
#   'lucu',
#   'nggak',
#   'kenalin',
#   'exol'],
#  ['ngga',
#   'tau',
#   'inti',
#   'exol',
#   'bangga',
#   'suho',
#   'presentasi',
#   'stanford',
#   'saranghaja',
#   'bangga',
#   'suho'],
#  ['liat',
#   'fotovideo',
#   'suho',
#   'bawa',
#   'bangga',
#   'keren',
#   'jun',
#   'bangga',
#   'kimjunmyeon'],
#  ['definisi', 'tampan', 'rupawan', 'cendikiawan'],
#  ['ganteng'],
#  ['jujur',
#   'bangga',
#   'ketua',
#   'suho',
#   'exol',
#   'kalimat',
#   'urut',
#   'alfabet',
#   'huruf'],
#  ['suho', 'keren', 'parah', 'eri', 'bangga'],
#  ['bangga', 'suho', 'keren', 'iri', 'fans', 'bunga', 'bunga', 'debut', 'akun'],
#  ['junmyeon', 'bangga', 'bawa', 'nama', 'musik', 'korea', 'pikir', 'junmyeon'],
#  ['ketua',
#   'keren',
#   'suho',
#   'bangga',
#   'bangga',
#   'serius',
#   'member',
#   'bangga',
#   'bangga',
#   'suhoexoand',
#   'exol'],
#  ['suho', 'aura', 'mainmain'],
#  ['bangga', 'suho', 'maju', 'bangga', 'kim', 'junmyeon'],
#  ['rajin', 'update', 'media', 'sosial', 'cakep'],
#  ['bangga', 'suho'],
#  ['ganteng'],
#  ['ganteng', 'pinter', 'bakat', 'ramah', 'manis', 'ketua', 'pokok'],
#  ['ketua',
#   'suho',
#   'grup',
#   'bangga',
#   'budaya',
#   'negara',
#   'tumpang',
#   'nama',
#   'musik',
#   'korea',
#   'patut',
#   'contoh'],
#  ['bangga', 'bangga', 'kim', 'junmyeon'],
#  ['takdir', 'terimakasih', 'kenal', 'musik'],
#  ['suho', 'keren'],
#  ['bangga', 'suho'],
#  ['militer',
#   'solo',
#   'album',
#   'ketemu',
#   'gemar',
#   'vlog',
#   'temu',
#   'fans',
#   'pulau',
#   'jeju',
#   'ngisi',
#   'pidato',
#   'stanford',
#   'kimjunmyeon',
#   'patut',
#   'apresiasidia',
#   'benarbenar',
#   'kerja',
#   'keras',
#   'bangga',
#   'dengganmu'],
#  ['ketua',
#   'debut',
#   'tweet',
#   'salah',
#   'prof',
#   'stanford',
#   'hebat',
#   'suho',
#   'bangga',
#   'suho'],
#  ['bangga', 'exol', 'ketua'],
#  ['jujur',
#   'allah',
#   'suho',
#   'keren',
#   'hebat',
#   'wibawa',
#   'bangga',
#   'cinta',
#   'bangga',
#   'kim',
#   'junmyeon'],
#  ['tau', 'suho', 'ceo'],
#  ['ganteng', 'pinter', 'sikap', 'bagus', 'aura', 'ketua', 'pokok'],
#  ['suho', 'presiden', 'musik', 'korea'],
#  ['allah',
#   'bangga',
#   'suho',
#   'untung',
#   'kenal',
#   'terimakasih',
#   'leader',
#   'dunia',
#   'lcinta',
#   'bangga',
#   'kim',
#   'junmyeon'],
#  ['bangga',
#   'ketua',
#   'suho',
#   'bahasa',
#   'inggris',
#   'makasih',
#   'kerja',
#   'keras',
#   'suho',
#   'presentasi',
#   'exol',
#   'indonesia',
#   'leleh',
#   'tungguin',
#   'konser',
#   'member',
#   'kumpul',
#   'sehat'],
#  ['malam', 'begadang', 'nonton', 'suho', 'suho', 'stanford'],
#  ['kai', 'exol', 'andal', 'suho', 'stanford'],
#  ['keren', 'suho', 'stanford'],
#  ['neng', 'suho', 'kasih', 'hadiah', 'suho', 'stanford'],
#  ['suho', 'stanford'],
#  ['habis', 'konser', 'negeri', 'terjemah', 'juru', 'bicara', 'ketua'],
#  ['bentar',
#   'bentar',
#   'ganteng',
#   'keren',
#   'gagah',
#   'wibawa',
#   'ampun',
#   'kenalin',
#   'bos',
#   'ketua',
#   'kimjunmyeon',
#   'suho',
#   'bangga',
#   'suho'],
#  ['suho',
#   'bahasa',
#   'inggris',
#   'sempurna',
#   'salah',
#   'keren',
#   'bahasa',
#   'inggris',
#   'tingkat',
#   'pesat',
#   'ketua',
#   'bangga'],
#  ['bangga', 'suho', 'malaikat', 'musik', 'korea'],
#  ['bangga', 'suho', 'malaikat', 'musik', 'korea'],
#  ['suho', 'keren', 'bangga', 'kimjunmyeon'],
#  ['bangga', 'ayo', 'angkat', 'bangga', 'kimjunmyeon'],
#  ['suho', 'member', 'konser'],
#  ['chanyeol', 'minimal', 'warm', 'streaming', 'spotify'],
#  ['chanyeol', 'tomorrow', 'streaming', 'spotify'],
#  ['bangun',
#   'pagi',
#   'fokus',
#   'jun',
#   'bawa',
#   'ketua',
#   'jun',
#   'presiden',
#   'inget',
#   'minseok',
#   'bangga',
#   'kim',
#   'junmyeon'],
#  ['suho',
#   'lo',
#   'bangga',
#   'borong',
#   'pinter',
#   'jago',
#   'nari',
#   'nyanyi',
#   'ganteng',
#   'bangga',
#   'kimjunmyeon'],
#  ['wawancara', 'giat', 'negeri', 'suho', 'cuman', 'musik', 'korea'],
#  ['bangga', 'kimjunmyeon', 'keren', 'ketua'],
#  ['tampan', 'mapan', 'rupawan', 'wawas', 'kimjunmyeon', 'bangga', 'suho'],
#  ['suho',
#   'presentasi',
#   'tipikal',
#   'kerja',
#   'ngomong',
#   'kerja',
#   'bagus',
#   'ketua'],
#  ['suho', 'terbang', 'dubai', 'jepang', 'usa', 'seoul'],
#  ['gamau', 'ngajar', 'kampus'],
#  ['suka', 'junmyeon', 'harap', 'leader', 'bangga', 'suho'],
#  ['bunga', 'indah', 'suho', 'senang', 'simpan', 'bawa', 'korea'],
#  ['jun', 'manis', 'bangga', 'kimjunmyeon'],
#  ['mentor',
#   'dosen',
#   'bangga',
#   'kimjunmyeon',
#   'malaikat',
#   'malaikat',
#   'kpop',
#   'suho',
#   'stanford'],
#  ['keluarin', 'foto', 'mba', 'bangga', 'kimjunmyeon'],
#  ['bagus', 'exol', 'kuliah', 'stanford', 'suho'],
#  ['junmyeon',
#   'nasihat',
#   'bawa',
#   'enak',
#   'formal',
#   'serius',
#   'tenang',
#   'humor',
#   'nyaman',
#   'dengar',
#   'bangga',
#   'suho'],
#  ['senyum', 'manis', 'bangga', 'kim', 'junmyeon'],
#  ['suho', 'persis', 'dosen', 'suho', 'lirik', 'kampus', 'ku'],
#  ['tunggu', 'saranghaja'],
#  ['tinggal', 'bangga', 'kimjunmyeon'],
#  ['bangga', 'suho', 'keren', 'sayang'],
#  ['senyum', 'manis', 'ampun', 'leleh', 'planet'],
#  ['bangga', 'ketua', 'senang', 'haru'],
#  ['hebat', 'suho'],
#  ['suho',
#   'keren',
#   'nikmat',
#   'gugup',
#   'bahasa',
#   'inggris',
#   'keren',
#   'tampil',
#   'wibawa',
#   'kenalin',
#   'exol',
#   'bangga',
#   'kim',
#   'junmyeon'],
#  ['bangga',
#   'suho',
#   'lancar',
#   'ngomong',
#   'tonton',
#   'ketawa',
#   'kenalin',
#   'exol'],
#  ['tunggu', 'gapapa', 'rela', 'nungguin'],
#  ['proud', 'kimjunmyeon', 'keren'],
#  ['indonesian', 'perhati', 'persentasi', 'suho'],
#  ['andai',
#   'dosen',
#   'bawa',
#   'materi',
#   'seasik',
#   'suho',
#   'jamin',
#   'mahasiswa',
#   'absen',
#   'ngantuk',
#   'd',
#   'materi',
#   'hes',
#   'really',
#   'great'],
#  ['sesi', 'suho', 'ngomong', 'suho', 'stanford'],
#  ['lelucon', 'cocok', 'suho', 'cair', 'suasana'],
#  ['cerah', 'liat', 'junmyeon', 'senyum', 'bangga', 'kim', 'junmyeon'],
#  ['idol',
#   'suho',
#   'malas',
#   'ayo',
#   'hebat',
#   'samasama',
#   'bangga',
#   'kim',
#   'junmyeon'],
#  ['heh',
#   'lusa',
#   'umur',
#   'eh',
#   'suka',
#   'bahagia',
#   'kiyowo',
#   'ganteng',
#   'paripurna',
#   'bangga',
#   'kim',
#   'junmyeon'],
#  ['bangga', 'suho', 'senang', 'indonesia', 'perhati', 'persentasi'],
#  ['pagipagi', 'kasih', 'liat', 'bangga', 'kimjunmyeon'],
#  ['sayang', 'eri', 'hati'],
#  ['artikel', 'nulis', 'oneit', 'member', 'tulis', 'lengkap'],
#  ['bagus', 'tau', 'inggris', 'sayang', 'suho', 'pokok'],
#  ['sempurna', 'suami', 'hidup'],
#  ['bangga', 'suho', 'berita', 'bagus'],
#  ['jun', 'oppa', 'keren', 'suho', 'stanford'],
#  ['menang',
#   'kenal',
#   'dunia',
#   'eri',
#   'keliling',
#   'dunia',
#   'percaya',
#   'suho',
#   'realisasi',
#   'malaikat',
#   'musik',
#   'korea'],
#  ['malaikat', 'musik', 'korea', 'suho', 'stanford'],
#  ['exol', 'bangga', 'ketua', 'suho', 'malaikat', 'musik', 'korea'],
#  ['bangga', 'ketua'],
#  ['suho', 'kemarin', 'kenal', 'dunia', 'dunia'],
#  ['bangga', 'kimjunmyeon'],
#  ['pagi', 'eri', 'baekhyu', 'tta', 'takut', 'salip', 'jarak', 'lumayan', 'no'],
#  ['gila', 'keren', 'ketua'],
#  ['salah', 'bangga', 'exol', 'sikap'],
#  ['keliling', 'dunia', 'suho', 'maju'],
#  ['bangga', 'suho'],
#  ['raja', 'kai'],
#  ['raja', 'kai'],
#  ['raja', 'jongin'],
#  ['suho', 'sma', 'habisin', 'nonton', 'vidio', 'tiktok', 'youtube'],
#  ['bangga', 'suho', 'henti', 'bangga', 'exol'],
#  ['mabuk', 'upadate', 'bareng'],
#  ['giat'],
#  ['sederhana', 'senang', 'cinta', 'tahan', 'bentar'],
#  ['ken', 'chibi', 'teman', 'wujud'],
#  ['spesial', 'collab', 'nama', 'kai', 'botol', 'borong', 'mimin'],
#  ['album', 'exomiraclesindecember', 'cinasver', 'ayo', 'beli', 'shopee'],
#  ['album', 'sc', 'whatalife', 'ayo', 'beli', 'shopee'],
#  ['pc', 'suho', 'album', 'tempo', 'ayo', 'beli', 'shopee'],
#  ['wts', 'album', 'loveshot', 'album', 'poster', 'detail', 'link'],
#  ['tunggu', 'tampil'],
#  ['chanyeol', 'instagram'],
#  ['halloaku',
#   'daftar',
#   'lagu',
#   'khusus',
#   'rekomendasi',
#   'kyungsoo',
#   'bubble',
#   'nikmat'],
#  ['suho', 'hun', 'chanyeol'],
#  ['chanyeo', 'instagram', 'mumpung', 'tutup', 'samperin'],
#  ['cerita', 'instagram', 'chanyeol', 'pergi', 'cafioca'],
#  ['hun',
#   'acara',
#   'dior',
#   'la',
#   'pagi',
#   'seoul',
#   'petang',
#   'acara',
#   'dior',
#   'malam',
#   'la',
#   'acara'],
#  ['hun', 'la'],
#  ['hun', 'la'],
#  ['baekhyun'],
#  ['kai'],
#  ['wts',
#   'kartu',
#   'foto',
#   'baekhyun',
#   'expan',
#   'baekhyun',
#   'perhiasa',
#   'jaemin',
#   'dom',
#   'bandung',
#   'jaga',
#   'acara',
#   'condi',
#   'bijak'],
#  ['pan', 'harap', 'temu', 'pan', 'dunia', 'nyata', 'cinta'],
#  ['mutual', 'exol', 'sijeuni', 'mutualan'],
#  ['suho', 'bahas', 'peran', 'grup', 'anggap', 'sosok', 'ketua'],
#  ['drama',
#   'korea',
#   'bintang',
#   'do',
#   'pratinjau',
#   'decolsin',
#   'obat',
#   'batuk',
#   'flu'],
#  ['nama',
#   'asa',
#   'dapet',
#   'jiwa',
#   'overdose',
#   'hyung',
#   'loey',
#   'koreografi',
#   'percaya',
#   'tinggal',
#   'do',
#   'koreografi'],
#  ['miraclesindecember',
#   'the',
#   'winter',
#   'special',
#   'album',
#   'ayo',
#   'beli',
#   'shopee'],
#  ['senang', 'bahagia', 'suho', 'cinta'],
#  ['versi', 'keteng', 'bunda', 'versi', 'lengkap', 'harap', 'sabar'],
#  ['ketua', 'aktif', 'ken', 'libur', 'ajak', 'libur', 'jumyeon'],
#  ['estetik'],
#  ['instagram',
#   'kimjuncotton',
#   'senang',
#   'temu',
#   'seni',
#   'dunia',
#   'putar',
#   'musik',
#   'dunia',
#   'putar'],
#  ['tonton',
#   'drama',
#   'korea',
#   'aktor',
#   'kyungsoo',
#   'kenal',
#   'kali',
#   'tau',
#   'do',
#   'mudah',
#   'mungil',
#   'nama'],
#  ['semenjak',
#   'wajib',
#   'militer',
#   'asa',
#   'hidup',
#   'jantung',
#   'cant',
#   'wait',
#   'for',
#   'exos'],
#  ['tiktok', 'muncul', 'kangen', 'buah', 'grup'],
#  ['dokyungsoo', 'trus', 'ketemu', 'najaemin'],
#  ['fokus', 'liat'],
#  ['curah',
#   'hati',
#   'makasih',
#   'tani',
#   'makasih',
#   'bahagia',
#   'sisa',
#   'hidup',
#   'cinta',
#   'allah',
#   'penasaran',
#   'istri'],
#  ['pidato', 'pergi', 'tidur', 'senang', 'pesan'],
#  ['dengar'],
#  ['artikel', 'do', 'batin', 'do', 'kyungsoo', 'periksa', 'tidur'],
#  ['cakep', 'kai'],
#  ['topik',
#   'follow',
#   'akun',
#   'kai',
#   'baca',
#   'dasar',
#   'kim',
#   'jongin',
#   'eh',
#   'kim',
#   'kai',
#   'deng',
#   'eh',
#   'juluk',
#   'kim'],
#  ['do', 'ngapain', 'imut'],
#  ['baekhyun', 'vokalis'],
#  ['dapet',
#   'kartu',
#   'foto',
#   'haechan',
#   'nct',
#   'chanyeol',
#   'koleksi',
#   'kartu',
#   'foto',
#   'chanyeol',
#   'exol',
#   'nctdream',
#   'tukeran'],
#  ['bicara', 'mimpi', 'seniman', 'peran', 'grup', 'lengkap'],
#  ['cerita', 'panggung', 'dengar', 'ria', 'gemar'],
#  ['suka', 'rambut', 'umin', 'warna', 'hitam'],
#  ['tarik',
#   'kereta',
#   'dorong',
#   'bawa',
#   'anggota',
#   'kereta',
#   'cerita',
#   'kisah',
#   'coba',
#   'dengar',
#   'anggota'],
#  ['ganteng', 'tiada', 'jeda'],
#  ['instagram', 'kimjuncotton', 'lampu', 'hijau', 'musik', 'korea', 'nyala'],
#  ['visual', 'mainmain', 'ketua'],
#  ['suho', 'majalah', 'singles'],
#  ['hoodie', 'celana', 'pendek', 'lepas'],
#  ['baekhyun'],
#  ['info',
#   'suho',
#   'tampil',
#   'acara',
#   'festival',
#   'musik',
#   'seoul',
#   'park',
#   'taman',
#   'olympic',
#   'seoul',
#   'juni'],
#  ['minseok', 'kabar'],
#  ['ratarata', 'lagu', 'lembut', 'dengar'],
#  ['info',
#   'suho',
#   'giat',
#   'dubai',
#   'festival',
#   'city',
#   'tanggal',
#   'mei',
#   'bawa',
#   'lagu',
#   'lotto'],
#  ['jaga', 'video', 'kai', 'youtube', 'ken', 'tidur', 'kai', 'indah', 'huhuhu'],
#  ['wajib', 'militer', 'gemar', 'penuh', 'berita', 'chanyeol', 'cinta'],
#  ['sayang', 'kimjongin', 'spam', 'pesan', 'gemas'],
#  ['wajib', 'militer', 'ganteng', 'dj', 'raiden', 'for', 'update'],
#  ['hyeong', 'ganteng', 'coba'],
#  ['haluan', 'teman', 'hidup', 'nama', 'halu', 'rendah', 'contoh'],
#  ['kabar',
#   'suho',
#   'junmyeon',
#   'bareng',
#   'ahjusshi',
#   'tiktok',
#   'muncul',
#   'hun'],
#  ['allah',
#   'baekhyun',
#   'ken',
#   'peluk',
#   'capek',
#   'kabar',
#   'pokok',
#   'sayang',
#   'baekhyun'],
#  ['murah',
#   'album',
#   'ku',
#   'album',
#   'printilan',
#   'kartu',
#   'foto',
#   'poster',
#   'tes',
#   'ombak',
#   'minat'],
#  ['baekhyun', 'gemas'],
#  ['kai', 'incheon', 'areaa'],
#  ['makasih',
#   'nyesel',
#   'kenal',
#   'suasana',
#   'hati',
#   'pikir',
#   'percaya',
#   'obat',
#   'cinta'],
#  ['baekhyuns', 'aura', 'debut'],
#  ['kapas', 'kena', 'angin', 'eropa', 'aura', 'badai'],
#  ['makasih', 'suasana', 'hati', 'gegara', 'baekhyun', 'kasih', 'kabar'],
#  ['chanyeol', 'ganteng', 'chanyeol', 'ganteng', 'chanyeol', 'ganteng'],
#  ['park', 'chanyeol', 'idol', 'wajib', 'militer', 'foto', 'hd'],
#  ['rambut', 'suka'],
#  ['chen',
#   'kasih',
#   'hadiah',
#   'video',
#   'unggah',
#   'youtube',
#   'ayok',
#   'ikan',
#   'chen',
#   'penuh',
#   'tiket',
#   'sore',
#   'teman'],
#  ['kai',
#   'hyung',
#   'bandara',
#   'keren',
#   'mode',
#   'pacar',
#   'jalan',
#   'red',
#   'carpet',
#   'cocok',
#   'lahir'],
#  ['nonton',
#   'ladder',
#   'eps',
#   'seru',
#   'kai',
#   'kasi',
#   'makan',
#   'yogurt',
#   'curiga',
#   'kyungsoo'],
#  ['suho', 'suho'],
#  ['subscribe',
#   'youtube',
#   'chen',
#   'akun',
#   'google',
#   'youtube',
#   'chen',
#   'tuju',
#   'dandelion',
#   'kabar',
#   'jongdae'],
#  ['comeback'],
#  ['borong'],
#  ['kangen'],
#  ['ganteng'],
#  ['fokus', 'park', 'chanyeol', 'ganteng', 'seragam'],
#  ['thank', 'kai', 'laku', 'sayang', 'kai'],
#  ['baekhyun'],
#  ['kangen', 'huhuhu'],
#  ['vokalis',
#   'boygroup',
#   'sm',
#   'nomer',
#   'changmin',
#   'nomer',
#   'kry',
#   'nomer',
#   'chen',
#   'fix',
#   'gaada',
#   'debat'],
#  ['lucu', 'suara', 'lucu', 'chanyeol', 'chanyeol'],
#  ['nonton', 'konten', 'sembuh'],
#  ['kpop',
#   'kobam',
#   'kokobop',
#   'lagu',
#   'teman',
#   'lambang',
#   'foto',
#   'profil',
#   'instagram',
#   'ganja'],
#  ['tau',
#   'nada',
#   'musik',
#   'lagu',
#   'mama',
#   'kode',
#   'tarung',
#   'tau',
#   'diamdiam',
#   'tau'],
#  ['rumah', 'hantu', 'tao', 'takut', 'hun', 'ketawa', 'takut'],
#  ['ken',
#   'liat',
#   'ot',
#   'jelasin',
#   'senang',
#   'kumpul',
#   'ganjal',
#   'tunggu',
#   'ot',
#   'kumpul',
#   'tunggu'],
#  ['gegara', 'liat', 'in', 'idol', 'muda', 'aura', 'matang'],
#  ['rangka',
#   'kangen',
#   'tidur',
#   'nonton',
#   'chanyeol',
#   'the',
#   'box',
#   'chanyeol',
#   'keren',
#   'park',
#   'chanyeol'],
#  ['besok', 'beli', 'album', 'rilis'],
#  ['jatuh', 'cinta', 'era', 'power', 'gantengganteng'],
#  ['do',
#   'ama',
#   'jaemin',
#   'main',
#   'drama',
#   'nonton',
#   'drama',
#   'member',
#   'nct',
#   'wajib',
#   'tonton'],
#  ['makasih',
#   'cetus',
#   'konsep',
#   'alien',
#   'planet',
#   'kuat',
#   'masihmasing',
#   'salah',
#   'alas',
#   'nge',
#   'stan',
#   'konsep',
#   'unik',
#   'beda',
#   'teori',
#   'kaya',
#   'seru'],
#  ['tagih', 'nonton', 'reaksi', 'video', 'sayang', 'rugi', 'kenal'],
#  ['sm', 'entertainment', 'nama', 'lay', 'profil', 'resmi'],
#  ['hasil',
#   'toreh',
#   'prestasi',
#   'bangga',
#   'salah',
#   'nations',
#   'pick',
#   'warga',
#   'korsel',
#   'sukses',
#   'agens',
#   'bakat',
#   'member',
#   'lengkap',
#   'klik',
#   'link'],
#  ['kangen', 'hun', 'kangen', 'kangen', 'kyungsoo'],
#  ['kangen', 'gatau', 'drama', 'nonton', 'do', 'kyungsoo', 'lucu'],
#  ['heran', 'diam', 'puncak'],
#  ['stabil', 'peringkat', 'jarang', 'bangga'],
#  ['tuju',
#   'baekhyun',
#   'sejarah',
#   'musik',
#   'korea',
#   'grup',
#   'coba',
#   'program',
#   'hibur',
#   'akting'],
#  ['nomor', 'hati', 'ganti'],
#  ['jujur',
#   'bridges',
#   'bagus',
#   'bagus',
#   'lagu',
#   'bridges',
#   'merinding',
#   'dengarin',
#   'lagu',
#   'batu',
#   'era',
#   'tempo',
#   'mantap'],
#  ['bayangin', 'nct', 'svt', 'treasure', 'kumpul', 'rame', 'macem'],
#  ['setia', 'era', 'gempur', 'idol'],
#  ['suka', 'kpop', 'gara', 'gara', 'bts'],
#  ['luhan',
#   'suho',
#   'lay',
#   'chanyeol',
#   'baekhyun',
#   'kyungsoo',
#   'hun',
#   'kai',
#   'member',
#   'kenal',
#   'debut']]

# %%
#stopwords removal
stopword = stopwords.words("indonesian")
stopword.extend(["exo", "yaa", "guys", "ngabrut", "awokawokawok", "bengek", "awokawokawok", "akuuhhh", "siii", "huaaaaa", "amp", "chat", "plis", "dg", 
                 "toh", "gak", "otw", "kok", "dm", "u", "haha", "ayokk", "kuy", "bestie", "apaan", "rt", "yukk", "deh", "pliss", "gua", "php", "doang", "ooh", "tuhan", "kayanya",
                 "gpp", "gw", "gua", "Hemm", "please", "yak", "deg", "an", "poll", "Wkwk", "ya", "wkwkkwkw", "bapak", "hbd", "babang", "tks", "pls", "thn", "nd", "gaes", 
                 "yeah", "wah", "btw", "dah", "hiks", "duh", "hehey", "ehh", "papi", "yok", "woii", "rp", "Huhuhu", "oleng", "ayang", "k", "sumpah", "ter", "beb", "yoy", 
                 "ab", "abai", "th", "adeknya", "zetkidlin", "zulkidin", "abis", "adem", "bilang", "lihat", "tolong", "gitu", "situ", "lari", "tangan", "pas", "cari", "biar", "oke", "on",
                 "pakai", "ayah", "pas", "juta", "jam", "menit", "orang", "ubah", "papa", "by", "lupa", "mari", "duluan", "betapa", "ubah", "to", "anak", "pilih", "selamat", "ulang", "tahun",
                 "bikin", "gimana", "gin", "moga", "terima", "jual", "kirim", "capai", "lampau", "kayak", "langsung", "harga", "emang", "yey", "yuhu", "ygngg", "with", "agak",
                 "ya", "guys", "selamat", "mas", "nya", "bgt", "amp", "untuk", "x", "dg", "udah", "kuy", "by", "ooh", "gaes", "dah", "ya", "bang", "th", "tuh", "aja", "yg",
                 "ini", "kayak", "lu", "kan", "ter", "yuk", "kalo", "lagi", "loh", "of", "abang", "ga", "kek", "gk", "wkwk", "si", "and", "sih", "banget", "thanks", "sih", "omg", "ga", "gk", "iya", 
                 "jg", "nang", "its", "okey", "kek", "oh", "hehe", "gue", "my", "mu", "nih", "adik", "agakagak", "ah", "yaampun", "yangs", "you", "your", "yoo", "yangyang", "aka", "wkwkwk"])

datafinal2 = []
for line in data_no_punc_neg:
  word_token = nltk.word_tokenize(line)
  word_token = [word for word in word_token if word not in stopword and not word[0].isdigit()]
  datafinal2.append(word_token)

datafinal2
# Out:
# [['lucu',
#   'liat',
#   'kai',
#   'marah',
#   'gegara',
#   'eribong',
#   'sembunyi',
#   'kyungsoo',
#   'kyungsoo',
#   'perilaku',
#   'polos',
#   'hun',
#   'perhati',
#   'hyung',
#   'marah'],
#  ['sabar', 'kji', 'tunggu', 'arti', 'enlist'],
#  ['suara',
#   'baekhyun',
#   'tta',
#   'eri',
#   'ayo',
#   'keluarin',
#   'mode',
#   'suara',
#   'monster'],
#  ['pesan',
#   'suara',
#   'debut',
#   'cbx',
#   'jepang',
#   'cr',
#   'chenniepii',
#   'miss',
#   'chen'],
#  ['tinjau',
#   'chanyeol',
#   'muncul',
#   'asa',
#   'muncul',
#   'chanyeol',
#   'ngapain',
#   'libur',
#   'barak'],
#  ['kimjunmyeon', 'korea', 'korea', 'pergi', 'dubai', 'istirahat', 'myeonnie'],
#  ['baekhyun', 's', 'pulang'],
#  ['anginrambutku', 'photo', 'slide', 'video', 'dubai', 'tinggal'],
#  ['kabarin', 'hilang'],
#  ['tutup', 'aurora'],
#  ['badut', 'lay', 'suho'],
#  ['lay', 'rindu', 'peristiwa', 'exol', 'rindu', 'peristiwa'],
#  ['exol', 'bangun', 'fokus', 'idol', 'campur', 'urus', 'idol', 'bantu', 'rnb'],
#  ['exol', 'mutual', 'bantu', 'retweet', 'selektif'],
#  ['exol',
#   'istilah',
#   'idol',
#   'urus',
#   'fokus',
#   'campur',
#   'idol',
#   'garam',
#   'kencan',
#   'idol',
#   'ganti',
#   'foto',
#   'pribadi'],
#  ['fokus', 'eri', 'idol', 'campur'],
#  ['exol', 'fokus', 'campur'],
#  ['nama',
#   'lay',
#   'hapus',
#   'profil',
#   'sm',
#   'entertainment',
#   'protes',
#   'gemar',
#   'pasal',
#   'sm',
#   'entertainment',
#   'lay',
#   'nyata'],
#  ['chanyeol', 'trending', 'asa'],
#  ['niat', 'istirahat'],
#  ['nemu', 'video', 'tiktok', 'fyp', 'kangen'],
#  ['post', 'harap', 'palsu', 'ih'],
#  ['harap', 'bawain', 'lagu', 'fall', 'live', 'kaya'],
#  ['lay', 'panggil', 'baobei', 'panggil', 'lay', 'ge'],
#  ['instagram', 'junmyeon', 'gel', 'badan'],
#  ['lzen', 'istirahat', 'jeno', 'kapal', 'hun', 'muat', 'foto'],
#  ['silah',
#   'tameng',
#   'usik',
#   'kai',
#   'drama',
#   'grup',
#   'jeda',
#   'sayang',
#   'guncang',
#   'jagat',
#   'raya'],
#  ['susah', 'umin', 'brangkat', 'bawa', 'suasan', 'hati', 'linimasa', 'sedih'],
#  ['susah',
#   'stand',
#   'idol',
#   'pake',
#   'hati',
#   'senang',
#   'mulfand',
#   'bawa',
#   'idola',
#   'konten',
#   'bandingin',
#   'sedih',
#   'seru',
#   'rasain',
#   'exol'],
#  ['komentar', 'ditambahin', 'hilang', 'sembilan'],
#  ['pantes', 'dejavubukan', 'membandingkantapi', 'kangen', 'lemah'],
#  ['simpang', 'dikit', 'silah', 'laporin'],
#  ['ngaku',
#   'only',
#   'idol',
#   'only',
#   'serius',
#   'kali',
#   'bersih',
#   'bersih',
#   'khusus',
#   'ungu',
#   'ijo',
#   'silah',
#   'henti',
#   'ungu'],
#  ['mohon',
#   'maaf',
#   'moots',
#   'follow',
#   'ungu',
#   'ijo',
#   'henti',
#   'silah',
#   'moots',
#   'ku',
#   'henti',
#   'butuh',
#   'exol',
#   'moots',
#   'terimakasih'],
#  ['erti', 'usaha', 'paham', 'hakim'],
#  ['serius',
#   'gemar',
#   'foto',
#   'profil',
#   'exol',
#   'foto',
#   'profil',
#   'idol',
#   'lo',
#   'serius',
#   'segitukah',
#   'pikir',
#   'telaah',
#   'condong',
#   'lucu'],
#  ['lucu', 'lo', 'kemarin', 'ghibahin', 'akun', 'kali'],
#  ['hubung', 'paham', 'lo', 'exol', 'butuh', 'usik'],
#  ['sedih',
#   'tinggal',
#   'instagram',
#   'siar',
#   'ketua',
#   'pegang',
#   'hp',
#   'gara',
#   'scroll',
#   'tiktok',
#   'mulu',
#   'buka',
#   'instagram',
#   'selesai'],
#  ['kesal',
#   'agens',
#   'astaga',
#   'c',
#   'lay',
#   'hilang',
#   'mancing',
#   'ribut',
#   'sm',
#   'khawatir',
#   'semenjak',
#   'do',
#   'single',
#   'pokok'],
#  ['foto', 'maksud', 'foto', 'chanyeol', 'foto', 'profil', 'wa', 'asli'],
#  ['eri', 'kaum', 'jendes', 'lumutsiapapun', 'fokus'],
#  ['selesai', 'seret', 'tutup', 'kebusukanpembelaan', 'silah', 'rnb', 'minat'],
#  ['lucu',
#   'banding',
#   'idola',
#   'grup',
#   'jeda',
#   'protes',
#   'idol',
#   'sentuh',
#   'tenang',
#   'musik',
#   'member',
#   'mondar',
#   'mandir',
#   'fashion',
#   'variety',
#   'show',
#   'lakilaki',
#   'ku',
#   'grup',
#   'individual',
#   'nikmat',
#   'jrk'],
#  ['foto', 'sadar', 'exol', 'hahaha', 'paksa', 'gaya'],
#  ['ungu',
#   'obsesi',
#   'lo',
#   'muncul',
#   'jd',
#   'pakar',
#   'ekspresi',
#   'iri',
#   'segitu',
#   'obses',
#   'mikirin'],
#  ['ayok',
#   'only',
#   'mutualan',
#   'hijau',
#   'ungu',
#   'pink',
#   'mejikuhibiniu',
#   'khusus',
#   'exol',
#   'multi',
#   'solo',
#   'stan',
#   'grup',
#   'bantu'],
#  ['curiga', 'pabrik', 'anggur', 'bangga', 'kimjunmyeon'],
#  ['kangen',
#   'akun',
#   'retweet',
#   'suka',
#   'akun',
#   'akun',
#   'tahan',
#   'suara',
#   'akun',
#   'nyaman',
#   'sosial',
#   'media',
#   'segi'],
#  ['ketua', 'pamer', 'makan', 'mulu', 'ken', 'makan', 'bareng'],
#  ['episode',
#   'do',
#   'xiumin',
#   'gasabar',
#   'terjun',
#   'sisi',
#   'suho',
#   'kai',
#   'terjun'],
#  ['kai', 'cemburu'],
#  ['ladder', 'musim', 'besok', 'episode'],
#  ['suho', 'tanggung', 'lo', 'waras'],
#  ['konser', 'pencar', 'pan', 'ku'],
#  ['contoh',
#   'makhluk',
#   'otak',
#   'dianugrahi',
#   'etik',
#   'lapor',
#   'blokir',
#   'libat'],
#  ['konser', 'dubai', 'gratis', 'allah', 'indonesia'],
#  ['hidup', 'waras', 'susah'],
#  ['jeda', 'sepi', 'konten', 'jeda', 'exol', 'mabok', 'visual'],
#  ['trend', 'pocky', 'mahal'],
#  ['junmyeon', 'paksa', 'ketemu', 'klien'],
#  ['lagu', 'cover', 'dapet'],
#  ['tao', 'member', 'menang', 'fakta'],
#  ['kangen',
#   'semangat',
#   'promosi',
#   'kabar',
#   'senang',
#   'semangat',
#   'promosi',
#   'semangat',
#   'hidup',
#   'nggak'],
#  ['ninggal', 'linimasa', 'dikit', 'promosi', 'pindah'],
#  ['asli',
#   'nyala',
#   'notif',
#   'instagram',
#   'member',
#   'hun',
#   'jongin',
#   'kemaren',
#   'cerita',
#   'instagram',
#   'gaada',
#   'pemberitahuan'],
#  ['jatuh', 'brondong', 'dream'],
#  ['sadar',
#   'stan',
#   'momen',
#   'utama',
#   'suka',
#   'hun',
#   'promosi',
#   'dukung',
#   'stan',
#   'era',
#   'momen',
#   'member'],
#  ['suka',
#   'nonton',
#   'video',
#   'konser',
#   'suju',
#   'shinee',
#   'asa',
#   'nggak',
#   'lipsync',
#   'coba',
#   'tonton',
#   'konser',
#   'idol',
#   'sm',
#   'greget'],
#  ['harap', 'muluk', 'liat', 'kangen']]

# %% [markdown]
# ##GSDMM

# %%
# !git clone https://github.com/rwalk/gsdmm.git
# Out:
# Cloning into 'gsdmm'...
# remote: Enumerating objects: 62, done.
# remote: Total 62 (delta 0), reused 0 (delta 0), pack-reused 62
# Unpacking objects: 100% (62/62), done.

# %%
import sys
sys.path.append('/content/gsdmm')

# %%
import gsdmm
from gsdmm import MovieGroupProcess

# %%
#Iterasi ke-1
mgp = MovieGroupProcess(K=3, alpha=0.5, beta=0.5, n_iters=30)

# %%
vocab = set(x for i in datafinal for x in i)
n_terms = len(vocab)

# %%
model = mgp.fit(datafinal, n_terms)
# Out:
# In stage 0: transferred 303 clusters with 3 clusters populated
# In stage 1: transferred 181 clusters with 3 clusters populated
# In stage 2: transferred 135 clusters with 3 clusters populated
# In stage 3: transferred 126 clusters with 3 clusters populated
# In stage 4: transferred 108 clusters with 3 clusters populated
# In stage 5: transferred 98 clusters with 3 clusters populated
# In stage 6: transferred 85 clusters with 3 clusters populated
# In stage 7: transferred 71 clusters with 3 clusters populated
# In stage 8: transferred 84 clusters with 3 clusters populated
# In stage 9: transferred 82 clusters with 3 clusters populated
# In stage 10: transferred 94 clusters with 3 clusters populated
# In stage 11: transferred 94 clusters with 3 clusters populated
# In stage 12: transferred 93 clusters with 3 clusters populated
# In stage 13: transferred 79 clusters with 3 clusters populated
# In stage 14: transferred 82 clusters with 3 clusters populated
# In stage 15: transferred 78 clusters with 3 clusters populated
# In stage 16: transferred 97 clusters with 3 clusters populated
# In stage 17: transferred 101 clusters with 3 clusters populated
# In stage 18: transferred 81 clusters with 3 clusters populated
# In stage 19: transferred 94 clusters with 3 clusters populated
# In stage 20: transferred 96 clusters with 3 clusters populated
# In stage 21: transferred 89 clusters with 3 clusters populated
# In stage 22: transferred 94 clusters with 3 clusters populated
# In stage 23: transferred 83 clusters with 3 clusters populated
# In stage 24: transferred 86 clusters with 3 clusters populated
# In stage 25: transferred 95 clusters with 3 clusters populated
# In stage 26: transferred 83 clusters with 3 clusters populated
# In stage 27: transferred 84 clusters with 3 clusters populated
# In stage 28: transferred 89 clusters with 3 clusters populated
# In stage 29: transferred 89 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count = numpy.array(mgp.cluster_doc_count)
print('Number of documents per cluster :', doc_count)
# Out:
# Number of documents per cluster : [141 236 123]

# %%
#Topic sorted by the number of document they are allocated to
top_index = doc_count.argsort()
print('Most important clusters (by number of docs inside):', top_index)
# Out:
# Most important clusters (by number of docs inside): [2 0 1]

# %%
#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

# %%
top_words(mgp.cluster_word_distribution, top_index, 10)
# Out:
# Cluster 2 : [('kai', 17), ('kangen', 15), ('hun', 13), ('chanyeol', 13), ('do', 13), ('korea', 12), ('kyungsoo', 11), ('nonton', 9), ('instagram', 9), ('video', 8)]
#
# Cluster 0 : [('baekhyun', 34), ('exol', 31), ('hun', 17), ('suho', 15), ('foto', 14), ('idol', 14), ('chanyeol', 13), ('tta', 11), ('ganteng', 11), ('seoul', 10)]
#
# Cluster 1 : [('suho', 128), ('bangga', 94), ('ketua', 54), ('kimjunmyeon', 47), ('sehat', 33), ('keren', 30), ('exol', 27), ('bahagia', 22), ('junmyeon', 22), ('kasih', 21)]

# %%
topic_dict = {}
topic_names = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index):
    topic_dict[topic_num]=topic_names[i]

# %%
def create_topics_dataframe(data_text, mgp, threshold, topic_dict, token_list):
    result = pd.DataFrame(columns=["tweet", "topik", "token_list"])
    for i, text in enumerate(data_text):
        result.at[i, 'tweet'] = text
        result.at[i, 'token_list'] = token_list[i]
        prob = mgp.choose_best_label(token_list[i])
        # print(prob)
        if prob[1] >= threshold:
          result.at[i, 'topik'] = topic_dict[prob[0]]
        else:
          result.at[i, 'topik'] = 'Other'
    return result

# %%
result = create_topics_dataframe(data_text=df.tweet, mgp=mgp, threshold=0.3, topic_dict=topic_dict, token_list=datafinal)
result
# Out:
#                                                  tweet    topik  \
# 0    Jimin adalah artis pertama yang mencapai punca...  topik 3
# 1    ForYouth merupakan lagu baru untuk penggemar B...  topik 1
# 2    jhope terlihat menyukai kiriman terbaru dari kaws  topik 2
# 3    album kedua disusun untuk menjelaskan BTS yang...  topik 3
# 4    Daftar lagu album kedua untuk album antologi P...  topik 3
# ..                                                 ...      ...
# 525  Semua tiket PTD di panggung LasVegas 4 hari ud...  topik 3
# 526  Ada beberapa army yang tudung nya udah sampai ...  topik 1
# 527  Masih tidak bisa berkata kata pantas jimin dar...  topik 2
# 528  kebayang ga didepan begitu banyak wartawan dan...  topik 1
# 529  Maaf ya kak  aku sekali lagi telah gagal jadi ...  topik 1
#
#                                             token_list
# 0    [jimin, artis, capai, puncak, nomor, chart, pa...
# 1    [foryouth, rupa, lagu, gemar, army, lagu, kasi...
# 2                           [jhope, suka, kirim, kaws]
# 3    [album, susun, sinar, jalan, sembilan, harga, ...
# 4    [daftar, lagu, album, album, antologi, proof, ...
# ..                                                 ...
# 525  [tiket, ptd, panggung, lasvegas, jual, jual, a...
# 526                      [army, tudung, beli, ukur, l]
# 527  [jimin, kemarin, status, nyata, sakit, jimin, ...
# 528  [bayang, wartawan, tokoh, white, house, deg, d...
# 529  [gagal, gemar, layak, gemar, kali, menang, jat...
#
# [530 rows x 3 columns]

# %%
import gensim
dictionary = gensim.corpora.Dictionary(datafinal)

# %%
#create BOW dictionary
bow_corpus = [dictionary.doc2bow(doc) for doc in datafinal]

# %%
from gensim.models import CoherenceModel

# %%
def get_topics_list(model, top_clusters, n_words):
  topics = []
  for cluster in top_clusters:
    sorted_dict = sorted(model.cluster_word_distribution[cluster].items(), key=lambda k:k[1], reverse=True)[:n_words]
    topic = []
    for k,v in sorted_dict:
      topic.append(k)
    topics.append(topic)
  return topics

# %%
#get topics to feed to coherence model
topics = get_topics_list(mgp, top_index, 10)

# %%
#evaluate model using Topic Coherence score
cm_gsdmm = CoherenceModel(topics=topics,dictionary=dictionary,corpus=bow_corpus,texts=datafinal,coherence='c_v')

# %%
#get coherence value
coherence_gsdmm = cm_gsdmm.get_coherence()
print(coherence_gsdmm)
# Out:
# 0.4095545512370078

# %%
#Iterasi ke-2 (pakai ini)
mgp_2 = MovieGroupProcess(K=3, alpha=0.5, beta=0.5, n_iters=15)

# %%
model_2 = mgp_2.fit(datafinal, n_terms)
# Out:
# In stage 0: transferred 271 clusters with 3 clusters populated
# In stage 1: transferred 181 clusters with 3 clusters populated
# In stage 2: transferred 131 clusters with 3 clusters populated
# In stage 3: transferred 122 clusters with 3 clusters populated
# In stage 4: transferred 96 clusters with 3 clusters populated
# In stage 5: transferred 89 clusters with 3 clusters populated
# In stage 6: transferred 70 clusters with 3 clusters populated
# In stage 7: transferred 58 clusters with 3 clusters populated
# In stage 8: transferred 60 clusters with 3 clusters populated
# In stage 9: transferred 71 clusters with 3 clusters populated
# In stage 10: transferred 73 clusters with 3 clusters populated
# In stage 11: transferred 75 clusters with 3 clusters populated
# In stage 12: transferred 71 clusters with 3 clusters populated
# In stage 13: transferred 70 clusters with 3 clusters populated
# In stage 14: transferred 77 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_2 = numpy.array(mgp_2.cluster_doc_count)
print('Number of documents per cluster :', doc_count_2)

#Topic sorted by the number of document they are allocated to
top_index_2 = doc_count_2.argsort()
print('Most important clusters (by number of docs inside):', top_index_2)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_2.cluster_word_distribution, top_index_2, 10)
# Out:
# Number of documents per cluster : [201  75 224]
# Most important clusters (by number of docs inside): [1 0 2]
#
# Cluster 1 : [('exol', 12), ('dubai', 8), ('lagu', 8), ('bagus', 8), ('suho', 8), ('akun', 8), ('chen', 8), ('seoul', 8), ('minseok', 8), ('ungu', 6)]
#
# Cluster 0 : [('baekhyun', 42), ('hun', 30), ('chanyeol', 25), ('suho', 20), ('kai', 19), ('exol', 18), ('foto', 17), ('idol', 14), ('ganteng', 13), ('kyungsoo', 12)]
#
# Cluster 2 : [('suho', 122), ('bangga', 94), ('ketua', 54), ('kimjunmyeon', 47), ('sehat', 33), ('keren', 29), ('exol', 28), ('bahagia', 21), ('junmyeon', 21), ('korea', 21)]

# %%
topic_dict_2 = {}
topic_names_2 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_2):
    topic_dict_2[topic_num]=topic_names_2[i]

result_2 = create_topics_dataframe(data_text=df.tweet, mgp=mgp_2, threshold=0.3, topic_dict=topic_dict_2, token_list=datafinal)
result_2
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 2
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 2
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 2
# 3                           dilakukan untuk baekhyun    topik 2
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 3
# ..                                                 ...      ...
# 495  asli deh padahal udah gua nyala semua notif ny...  topik 2
# 496  Tolong EXO segera kembali sebelum aku terjatuh...  topik 2
# 497  Baru sadar selama stan exo aku ga punya momen ...  topik 2
# 498  padahal dulu suka banget nonton video konser s...  topik 2
# 499  Harapan gua terlalu muluk kayak nya kalo liat ...  topik 2
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 495  [asli, nyala, notif, instagram, member, hun, j...
# 496                           [jatuh, brondong, dream]
# 497  [sadar, stan, momen, utama, suka, hun, promosi...
# 498  [suka, nonton, video, konser, suju, shinee, as...
# 499                       [harap, muluk, liat, kangen]
#
# [500 rows x 3 columns]

# %%
topics_2 = get_topics_list(mgp_2, top_index_2, 10)
cm_gsdmm_2 = CoherenceModel(topics=topics_2,dictionary=dictionary,corpus=bow_corpus,texts=datafinal,coherence='c_v')
coherence_gsdmm_2 = cm_gsdmm_2.get_coherence()
print(coherence_gsdmm_2)
# Out:
# 0.4033123308222469

# %%
#Iterasi ke-3
mgp_3 = MovieGroupProcess(K=3, alpha=0.5, beta=0.5, n_iters=45)
model_3 = mgp_3.fit(datafinal, n_terms)
# Out:
# In stage 0: transferred 296 clusters with 3 clusters populated
# In stage 1: transferred 209 clusters with 3 clusters populated
# In stage 2: transferred 132 clusters with 3 clusters populated
# In stage 3: transferred 111 clusters with 3 clusters populated
# In stage 4: transferred 107 clusters with 3 clusters populated
# In stage 5: transferred 105 clusters with 3 clusters populated
# In stage 6: transferred 86 clusters with 3 clusters populated
# In stage 7: transferred 93 clusters with 3 clusters populated
# In stage 8: transferred 91 clusters with 3 clusters populated
# In stage 9: transferred 86 clusters with 3 clusters populated
# In stage 10: transferred 89 clusters with 3 clusters populated
# In stage 11: transferred 78 clusters with 3 clusters populated
# In stage 12: transferred 96 clusters with 3 clusters populated
# In stage 13: transferred 94 clusters with 3 clusters populated
# In stage 14: transferred 83 clusters with 3 clusters populated
# In stage 15: transferred 84 clusters with 3 clusters populated
# In stage 16: transferred 93 clusters with 3 clusters populated
# In stage 17: transferred 79 clusters with 3 clusters populated
# In stage 18: transferred 89 clusters with 3 clusters populated
# In stage 19: transferred 86 clusters with 3 clusters populated
# In stage 20: transferred 92 clusters with 3 clusters populated
# In stage 21: transferred 85 clusters with 3 clusters populated
# In stage 22: transferred 88 clusters with 3 clusters populated
# In stage 23: transferred 77 clusters with 3 clusters populated
# In stage 24: transferred 87 clusters with 3 clusters populated
# In stage 25: transferred 90 clusters with 3 clusters populated
# In stage 26: transferred 76 clusters with 3 clusters populated
# In stage 27: transferred 83 clusters with 3 clusters populated
# In stage 28: transferred 87 clusters with 3 clusters populated
# In stage 29: transferred 89 clusters with 3 clusters populated
# In stage 30: transferred 79 clusters with 3 clusters populated
# In stage 31: transferred 83 clusters with 3 clusters populated
# In stage 32: transferred 71 clusters with 3 clusters populated
# In stage 33: transferred 81 clusters with 3 clusters populated
# In stage 34: transferred 87 clusters with 3 clusters populated
# In stage 35: transferred 73 clusters with 3 clusters populated
# In stage 36: transferred 80 clusters with 3 clusters populated
# In stage 37: transferred 75 clusters with 3 clusters populated
# In stage 38: transferred 81 clusters with 3 clusters populated
# In stage 39: transferred 80 clusters with 3 clusters populated
# In stage 40: transferred 87 clusters with 3 clusters populated
# In stage 41: transferred 83 clusters with 3 clusters populated
# In stage 42: transferred 81 clusters with 3 clusters populated
# In stage 43: transferred 85 clusters with 3 clusters populated
# In stage 44: transferred 80 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_3 = numpy.array(mgp_3.cluster_doc_count)
print('Number of documents per cluster :', doc_count_3)

#Topic sorted by the number of document they are allocated to
top_index_3 = doc_count_3.argsort()
print('Most important clusters (by number of docs inside):', top_index_3)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_3.cluster_word_distribution, top_index_3, 10)
# Out:
# Number of documents per cluster : [159 218 123]
# Most important clusters (by number of docs inside): [2 0 1]
#
# Cluster 2 : [('baekhyun', 36), ('exol', 29), ('idol', 13), ('tta', 11), ('suho', 9), ('chen', 9), ('bantu', 8), ('akun', 7), ('hati', 7), ('eri', 6)]
#
# Cluster 0 : [('chanyeol', 26), ('hun', 24), ('suho', 20), ('kai', 18), ('foto', 15), ('ganteng', 14), ('do', 13), ('instagram', 12), ('lagu', 12), ('kyungsoo', 12)]
#
# Cluster 1 : [('suho', 121), ('bangga', 94), ('ketua', 53), ('kimjunmyeon', 47), ('sehat', 33), ('keren', 29), ('exol', 28), ('korea', 22), ('junmyeon', 21), ('bahagia', 20)]

# %%
topic_dict_3 = {}
topic_names_3 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_3):
    topic_dict_3[topic_num]=topic_names_3[i]

result_3 = create_topics_dataframe(data_text=df.tweet, mgp=mgp_3, threshold=0.3, topic_dict=topic_dict_3, token_list=datafinal)
result_3
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 2
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 2
# 3                           dilakukan untuk baekhyun    topik 1
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 3
# ..                                                 ...      ...
# 495  asli deh padahal udah gua nyala semua notif ny...  topik 2
# 496  Tolong EXO segera kembali sebelum aku terjatuh...  topik 1
# 497  Baru sadar selama stan exo aku ga punya momen ...  topik 1
# 498  padahal dulu suka banget nonton video konser s...  topik 2
# 499  Harapan gua terlalu muluk kayak nya kalo liat ...  topik 3
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 495  [asli, nyala, notif, instagram, member, hun, j...
# 496                           [jatuh, brondong, dream]
# 497  [sadar, stan, momen, utama, suka, hun, promosi...
# 498  [suka, nonton, video, konser, suju, shinee, as...
# 499                       [harap, muluk, liat, kangen]
#
# [500 rows x 3 columns]

# %%
topics_3 = get_topics_list(mgp_3, top_index_3, 10)
cm_gsdmm_3 = CoherenceModel(topics=topics_3,dictionary=dictionary,corpus=bow_corpus,texts=datafinal,coherence='c_v')
coherence_gsdmm_3 = cm_gsdmm_3.get_coherence()
print(coherence_gsdmm_3)
# Out:
# 0.3403859629717219

# %%
#Iterasi ke-4
mgp_4 = MovieGroupProcess(K=3, alpha=0.7, beta=0.5, n_iters=30)
model_4 = mgp_4.fit(datafinal, n_terms)
# Out:
# In stage 0: transferred 301 clusters with 3 clusters populated
# In stage 1: transferred 197 clusters with 3 clusters populated
# In stage 2: transferred 132 clusters with 3 clusters populated
# In stage 3: transferred 98 clusters with 3 clusters populated
# In stage 4: transferred 81 clusters with 3 clusters populated
# In stage 5: transferred 80 clusters with 3 clusters populated
# In stage 6: transferred 89 clusters with 3 clusters populated
# In stage 7: transferred 83 clusters with 3 clusters populated
# In stage 8: transferred 71 clusters with 3 clusters populated
# In stage 9: transferred 81 clusters with 3 clusters populated
# In stage 10: transferred 75 clusters with 3 clusters populated
# In stage 11: transferred 92 clusters with 3 clusters populated
# In stage 12: transferred 93 clusters with 3 clusters populated
# In stage 13: transferred 89 clusters with 3 clusters populated
# In stage 14: transferred 81 clusters with 3 clusters populated
# In stage 15: transferred 84 clusters with 3 clusters populated
# In stage 16: transferred 76 clusters with 3 clusters populated
# In stage 17: transferred 62 clusters with 3 clusters populated
# In stage 18: transferred 77 clusters with 3 clusters populated
# In stage 19: transferred 82 clusters with 3 clusters populated
# In stage 20: transferred 89 clusters with 3 clusters populated
# In stage 21: transferred 84 clusters with 3 clusters populated
# In stage 22: transferred 74 clusters with 3 clusters populated
# In stage 23: transferred 79 clusters with 3 clusters populated
# In stage 24: transferred 87 clusters with 3 clusters populated
# In stage 25: transferred 86 clusters with 3 clusters populated
# In stage 26: transferred 78 clusters with 3 clusters populated
# In stage 27: transferred 84 clusters with 3 clusters populated
# In stage 28: transferred 87 clusters with 3 clusters populated
# In stage 29: transferred 73 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_4 = numpy.array(mgp_4.cluster_doc_count)
print('Number of documents per cluster :', doc_count_4)

#Topic sorted by the number of document they are allocated to
top_index_4 = doc_count_4.argsort()
print('Most important clusters (by number of docs inside):', top_index_4)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_4.cluster_word_distribution, top_index_4, 10)
# Out:
# Number of documents per cluster : [232 161 107]
# Most important clusters (by number of docs inside): [2 1 0]
#
# Cluster 2 : [('baekhyun', 32), ('exol', 22), ('suho', 14), ('tta', 11), ('seoul', 10), ('idol', 10), ('minseok', 9), ('bagus', 9), ('album', 9), ('ayo', 8)]
#
# Cluster 1 : [('hun', 28), ('chanyeol', 26), ('kai', 23), ('foto', 15), ('kangen', 13), ('do', 13), ('ganteng', 12), ('kyungsoo', 11), ('suho', 10), ('baekhyun', 9)]
#
# Cluster 0 : [('suho', 126), ('bangga', 94), ('ketua', 54), ('kimjunmyeon', 47), ('sehat', 33), ('exol', 29), ('keren', 27), ('bahagia', 22), ('korea', 22), ('junmyeon', 22)]

# %%
topic_dict_4 = {}
topic_names_4 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_4):
    topic_dict_4[topic_num]=topic_names_4[i]

result_4 = create_topics_dataframe(data_text=df.tweet, mgp=mgp_4, threshold=0.3, topic_dict=topic_dict_4, token_list=datafinal)
result_4
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 1
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 2
# 3                           dilakukan untuk baekhyun    topik 1
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 3
# ..                                                 ...      ...
# 495  asli deh padahal udah gua nyala semua notif ny...  topik 2
# 496  Tolong EXO segera kembali sebelum aku terjatuh...  topik 3
# 497  Baru sadar selama stan exo aku ga punya momen ...  topik 1
# 498  padahal dulu suka banget nonton video konser s...  topik 2
# 499  Harapan gua terlalu muluk kayak nya kalo liat ...  topik 2
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 495  [asli, nyala, notif, instagram, member, hun, j...
# 496                           [jatuh, brondong, dream]
# 497  [sadar, stan, momen, utama, suka, hun, promosi...
# 498  [suka, nonton, video, konser, suju, shinee, as...
# 499                       [harap, muluk, liat, kangen]
#
# [500 rows x 3 columns]

# %%
topics_4 = get_topics_list(mgp_4, top_index_4, 10)
cm_gsdmm_4 = CoherenceModel(topics=topics_4,dictionary=dictionary,corpus=bow_corpus,texts=datafinal,coherence='c_v')
coherence_gsdmm_4 = cm_gsdmm_4.get_coherence()
print(coherence_gsdmm_4)
# Out:
# 0.39885513588336724

# %%
#Iterasi ke-5 (pilih ini)
mgp_5 = MovieGroupProcess(K=3, alpha=0.35, beta=0.5, n_iters=30)
model_5 = mgp_5.fit(datafinal, n_terms)
# Out:
# In stage 0: transferred 277 clusters with 3 clusters populated
# In stage 1: transferred 179 clusters with 3 clusters populated
# In stage 2: transferred 133 clusters with 3 clusters populated
# In stage 3: transferred 123 clusters with 3 clusters populated
# In stage 4: transferred 90 clusters with 3 clusters populated
# In stage 5: transferred 98 clusters with 3 clusters populated
# In stage 6: transferred 86 clusters with 3 clusters populated
# In stage 7: transferred 88 clusters with 3 clusters populated
# In stage 8: transferred 105 clusters with 3 clusters populated
# In stage 9: transferred 97 clusters with 3 clusters populated
# In stage 10: transferred 83 clusters with 3 clusters populated
# In stage 11: transferred 76 clusters with 3 clusters populated
# In stage 12: transferred 96 clusters with 3 clusters populated
# In stage 13: transferred 91 clusters with 3 clusters populated
# In stage 14: transferred 90 clusters with 3 clusters populated
# In stage 15: transferred 93 clusters with 3 clusters populated
# In stage 16: transferred 100 clusters with 3 clusters populated
# In stage 17: transferred 82 clusters with 3 clusters populated
# In stage 18: transferred 84 clusters with 3 clusters populated
# In stage 19: transferred 90 clusters with 3 clusters populated
# In stage 20: transferred 90 clusters with 3 clusters populated
# In stage 21: transferred 89 clusters with 3 clusters populated
# In stage 22: transferred 88 clusters with 3 clusters populated
# In stage 23: transferred 95 clusters with 3 clusters populated
# In stage 24: transferred 97 clusters with 3 clusters populated
# In stage 25: transferred 97 clusters with 3 clusters populated
# In stage 26: transferred 83 clusters with 3 clusters populated
# In stage 27: transferred 91 clusters with 3 clusters populated
# In stage 28: transferred 94 clusters with 3 clusters populated
# In stage 29: transferred 95 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_5 = numpy.array(mgp_5.cluster_doc_count)
print('Number of documents per cluster :', doc_count_5)

#Topic sorted by the number of document they are allocated to
top_index_5 = doc_count_5.argsort()
print('Most important clusters (by number of docs inside):', top_index_5)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_5.cluster_word_distribution, top_index_5, 10)
# Out:
# Number of documents per cluster : [111 162 227]
# Most important clusters (by number of docs inside): [0 1 2]
#
# Cluster 0 : [('baekhyun', 31), ('suho', 18), ('tta', 11), ('exol', 10), ('seoul', 10), ('dubai', 9), ('album', 9), ('kai', 9), ('lay', 8), ('ayo', 7)]
#
# Cluster 1 : [('hun', 28), ('chanyeol', 25), ('foto', 23), ('kai', 15), ('suho', 14), ('korea', 13), ('kangen', 13), ('ganteng', 13), ('kyungsoo', 12), ('idol', 12)]
#
# Cluster 2 : [('suho', 118), ('bangga', 94), ('ketua', 50), ('kimjunmyeon', 47), ('exol', 37), ('sehat', 33), ('keren', 28), ('bahagia', 22), ('kasih', 20), ('junmyeon', 20)]

# %%
topic_dict_5 = {}
topic_names_5 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_5):
    topic_dict_5[topic_num]=topic_names_5[i]

result_5 = create_topics_dataframe(data_text=df.tweet, mgp=mgp_5, threshold=0.3, topic_dict=topic_dict_5, token_list=datafinal)
result_5
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 1
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 2
# 3                           dilakukan untuk baekhyun    topik 1
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 3
# ..                                                 ...      ...
# 495  asli deh padahal udah gua nyala semua notif ny...  topik 2
# 496  Tolong EXO segera kembali sebelum aku terjatuh...  topik 1
# 497  Baru sadar selama stan exo aku ga punya momen ...  topik 2
# 498  padahal dulu suka banget nonton video konser s...  topik 2
# 499  Harapan gua terlalu muluk kayak nya kalo liat ...  topik 1
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 495  [asli, nyala, notif, instagram, member, hun, j...
# 496                           [jatuh, brondong, dream]
# 497  [sadar, stan, momen, utama, suka, hun, promosi...
# 498  [suka, nonton, video, konser, suju, shinee, as...
# 499                       [harap, muluk, liat, kangen]
#
# [500 rows x 3 columns]

# %%
topics_5 = get_topics_list(mgp_5, top_index_5, 10)
cm_gsdmm_5 = CoherenceModel(topics=topics_5,dictionary=dictionary,corpus=bow_corpus,texts=datafinal,coherence='c_v')
coherence_gsdmm_5 = cm_gsdmm_5.get_coherence()
print(coherence_gsdmm_5)
# Out:
# 0.42901776993285123

# %%
#Iterasi ke-6
mgp_6 = MovieGroupProcess(K=3, alpha=0.35, beta=0.7, n_iters=30)
model_6 = mgp_6.fit(datafinal, n_terms)
# Out:
# In stage 0: transferred 283 clusters with 3 clusters populated
# In stage 1: transferred 208 clusters with 3 clusters populated
# In stage 2: transferred 146 clusters with 3 clusters populated
# In stage 3: transferred 153 clusters with 3 clusters populated
# In stage 4: transferred 123 clusters with 3 clusters populated
# In stage 5: transferred 81 clusters with 3 clusters populated
# In stage 6: transferred 101 clusters with 3 clusters populated
# In stage 7: transferred 82 clusters with 3 clusters populated
# In stage 8: transferred 81 clusters with 3 clusters populated
# In stage 9: transferred 79 clusters with 3 clusters populated
# In stage 10: transferred 81 clusters with 3 clusters populated
# In stage 11: transferred 88 clusters with 3 clusters populated
# In stage 12: transferred 81 clusters with 3 clusters populated
# In stage 13: transferred 75 clusters with 3 clusters populated
# In stage 14: transferred 76 clusters with 3 clusters populated
# In stage 15: transferred 89 clusters with 3 clusters populated
# In stage 16: transferred 88 clusters with 3 clusters populated
# In stage 17: transferred 86 clusters with 3 clusters populated
# In stage 18: transferred 95 clusters with 3 clusters populated
# In stage 19: transferred 96 clusters with 3 clusters populated
# In stage 20: transferred 71 clusters with 3 clusters populated
# In stage 21: transferred 91 clusters with 3 clusters populated
# In stage 22: transferred 82 clusters with 3 clusters populated
# In stage 23: transferred 79 clusters with 3 clusters populated
# In stage 24: transferred 89 clusters with 3 clusters populated
# In stage 25: transferred 64 clusters with 3 clusters populated
# In stage 26: transferred 89 clusters with 3 clusters populated
# In stage 27: transferred 95 clusters with 3 clusters populated
# In stage 28: transferred 89 clusters with 3 clusters populated
# In stage 29: transferred 76 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_6 = numpy.array(mgp_6.cluster_doc_count)
print('Number of documents per cluster :', doc_count_6)

#Topic sorted by the number of document they are allocated to
top_index_6 = doc_count_6.argsort()
print('Most important clusters (by number of docs inside):', top_index_6)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_6.cluster_word_distribution, top_index_6, 10)
# Out:
# Number of documents per cluster : [185 241  74]
# Most important clusters (by number of docs inside): [2 0 1]
#
# Cluster 2 : [('suho', 13), ('kai', 11), ('bagus', 10), ('seoul', 9), ('minseok', 9), ('album', 9), ('chen', 9), ('dubai', 8), ('beli', 7), ('foto', 5)]
#
# Cluster 0 : [('baekhyun', 42), ('hun', 30), ('exol', 29), ('chanyeol', 26), ('foto', 19), ('idol', 14), ('kangen', 13), ('do', 12), ('kyungsoo', 12), ('kai', 11)]
#
# Cluster 1 : [('suho', 127), ('bangga', 94), ('ketua', 54), ('kimjunmyeon', 47), ('sehat', 33), ('exol', 29), ('keren', 29), ('bahagia', 22), ('korea', 22), ('junmyeon', 21)]

# %%
topic_dict_6 = {}
topic_names_6 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_6):
    topic_dict_6[topic_num]=topic_names_6[i]

result_6 = create_topics_dataframe(data_text=df.tweet, mgp=mgp_6, threshold=0.3, topic_dict=topic_dict_6, token_list=datafinal)
result_6
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 2
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 2
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 2
# 3                           dilakukan untuk baekhyun    topik 2
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 3
# ..                                                 ...      ...
# 495  asli deh padahal udah gua nyala semua notif ny...  topik 2
# 496  Tolong EXO segera kembali sebelum aku terjatuh...  topik 1
# 497  Baru sadar selama stan exo aku ga punya momen ...  topik 2
# 498  padahal dulu suka banget nonton video konser s...  topik 2
# 499  Harapan gua terlalu muluk kayak nya kalo liat ...  topik 3
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 495  [asli, nyala, notif, instagram, member, hun, j...
# 496                           [jatuh, brondong, dream]
# 497  [sadar, stan, momen, utama, suka, hun, promosi...
# 498  [suka, nonton, video, konser, suju, shinee, as...
# 499                       [harap, muluk, liat, kangen]
#
# [500 rows x 3 columns]

# %%
topics_6 = get_topics_list(mgp_6, top_index_6, 10)
cm_gsdmm_6 = CoherenceModel(topics=topics_6,dictionary=dictionary,corpus=bow_corpus,texts=datafinal,coherence='c_v')
coherence_gsdmm_6 = cm_gsdmm_6.get_coherence()
print(coherence_gsdmm_6)
# Out:
# 0.4108921782746586

# %%
#Iterasi ke-7
mgp_7 = MovieGroupProcess(K=3, alpha=0.35, beta=0.35, n_iters=50)
model_7 = mgp_7.fit(datafinal, n_terms)
# Out:
# In stage 0: transferred 299 clusters with 3 clusters populated
# In stage 1: transferred 166 clusters with 3 clusters populated
# In stage 2: transferred 131 clusters with 3 clusters populated
# In stage 3: transferred 114 clusters with 3 clusters populated
# In stage 4: transferred 92 clusters with 3 clusters populated
# In stage 5: transferred 87 clusters with 3 clusters populated
# In stage 6: transferred 76 clusters with 3 clusters populated
# In stage 7: transferred 81 clusters with 3 clusters populated
# In stage 8: transferred 75 clusters with 3 clusters populated
# In stage 9: transferred 69 clusters with 3 clusters populated
# In stage 10: transferred 72 clusters with 3 clusters populated
# In stage 11: transferred 73 clusters with 3 clusters populated
# In stage 12: transferred 78 clusters with 3 clusters populated
# In stage 13: transferred 69 clusters with 3 clusters populated
# In stage 14: transferred 84 clusters with 3 clusters populated
# In stage 15: transferred 86 clusters with 3 clusters populated
# In stage 16: transferred 87 clusters with 3 clusters populated
# In stage 17: transferred 74 clusters with 3 clusters populated
# In stage 18: transferred 69 clusters with 3 clusters populated
# In stage 19: transferred 65 clusters with 3 clusters populated
# In stage 20: transferred 77 clusters with 3 clusters populated
# In stage 21: transferred 79 clusters with 3 clusters populated
# In stage 22: transferred 91 clusters with 3 clusters populated
# In stage 23: transferred 82 clusters with 3 clusters populated
# In stage 24: transferred 82 clusters with 3 clusters populated
# In stage 25: transferred 72 clusters with 3 clusters populated
# In stage 26: transferred 72 clusters with 3 clusters populated
# In stage 27: transferred 64 clusters with 3 clusters populated
# In stage 28: transferred 69 clusters with 3 clusters populated
# In stage 29: transferred 72 clusters with 3 clusters populated
# In stage 30: transferred 87 clusters with 3 clusters populated
# In stage 31: transferred 65 clusters with 3 clusters populated
# In stage 32: transferred 80 clusters with 3 clusters populated
# In stage 33: transferred 78 clusters with 3 clusters populated
# In stage 34: transferred 75 clusters with 3 clusters populated
# In stage 35: transferred 71 clusters with 3 clusters populated
# In stage 36: transferred 74 clusters with 3 clusters populated
# In stage 37: transferred 85 clusters with 3 clusters populated
# In stage 38: transferred 78 clusters with 3 clusters populated
# In stage 39: transferred 84 clusters with 3 clusters populated
# In stage 40: transferred 83 clusters with 3 clusters populated
# In stage 41: transferred 68 clusters with 3 clusters populated
# In stage 42: transferred 72 clusters with 3 clusters populated
# In stage 43: transferred 76 clusters with 3 clusters populated
# In stage 44: transferred 71 clusters with 3 clusters populated
# In stage 45: transferred 87 clusters with 3 clusters populated
# In stage 46: transferred 88 clusters with 3 clusters populated
# In stage 47: transferred 77 clusters with 3 clusters populated
# In stage 48: transferred 75 clusters with 3 clusters populated
# In stage 49: transferred 63 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_7 = numpy.array(mgp_7.cluster_doc_count)
print('Number of documents per cluster :', doc_count_7)

#Topic sorted by the number of document they are allocated to
top_index_7 = doc_count_7.argsort()
print('Most important clusters (by number of docs inside):', top_index_7)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_7.cluster_word_distribution, top_index_7, 10)
# Out:
# Number of documents per cluster : [252  86 162]
# Most important clusters (by number of docs inside): [1 2 0]
#
# Cluster 1 : [('exol', 18), ('korea', 12), ('suho', 11), ('idol', 10), ('album', 9), ('beli', 7), ('grup', 6), ('jeda', 6), ('ungu', 6), ('stan', 6)]
#
# Cluster 2 : [('hun', 28), ('chanyeol', 26), ('suho', 18), ('foto', 17), ('kai', 16), ('kangen', 14), ('lagu', 13), ('do', 11), ('kyungsoo', 11), ('seoul', 10)]
#
# Cluster 0 : [('suho', 121), ('bangga', 94), ('ketua', 53), ('kimjunmyeon', 46), ('exol', 38), ('baekhyun', 34), ('sehat', 33), ('keren', 27), ('bahagia', 22), ('kasih', 20)]

# %%
topic_dict_7 = {}
topic_names_7 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_7):
    topic_dict_7[topic_num]=topic_names_7[i]

result_7 = create_topics_dataframe(data_text=df.tweet, mgp=mgp_7, threshold=0.3, topic_dict=topic_dict_7, token_list=datafinal)
result_7
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 3
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 3
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 2
# 3                           dilakukan untuk baekhyun    topik 3
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 3
# ..                                                 ...      ...
# 495  asli deh padahal udah gua nyala semua notif ny...  topik 2
# 496  Tolong EXO segera kembali sebelum aku terjatuh...  topik 1
# 497  Baru sadar selama stan exo aku ga punya momen ...  topik 1
# 498  padahal dulu suka banget nonton video konser s...  topik 2
# 499  Harapan gua terlalu muluk kayak nya kalo liat ...  topik 2
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 495  [asli, nyala, notif, instagram, member, hun, j...
# 496                           [jatuh, brondong, dream]
# 497  [sadar, stan, momen, utama, suka, hun, promosi...
# 498  [suka, nonton, video, konser, suju, shinee, as...
# 499                       [harap, muluk, liat, kangen]
#
# [500 rows x 3 columns]

# %%
topics_7 = get_topics_list(mgp_7, top_index_7, 10)
cm_gsdmm_7 = CoherenceModel(topics=topics_7,dictionary=dictionary,corpus=bow_corpus,texts=datafinal,coherence='c_v')
coherence_gsdmm_7 = cm_gsdmm_7.get_coherence()
print(coherence_gsdmm_7)
# Out:
# 0.39444832217559833

# %%
#Iterasi ke-8
mgp_8 = MovieGroupProcess(K=5, alpha=0.35, beta=0.5, n_iters=30)
model_8 = mgp_8.fit(datafinal, n_terms)
# Out:
# In stage 0: transferred 357 clusters with 5 clusters populated
# In stage 1: transferred 256 clusters with 5 clusters populated
# In stage 2: transferred 188 clusters with 5 clusters populated
# In stage 3: transferred 179 clusters with 5 clusters populated
# In stage 4: transferred 153 clusters with 5 clusters populated
# In stage 5: transferred 130 clusters with 5 clusters populated
# In stage 6: transferred 124 clusters with 5 clusters populated
# In stage 7: transferred 126 clusters with 5 clusters populated
# In stage 8: transferred 124 clusters with 5 clusters populated
# In stage 9: transferred 117 clusters with 5 clusters populated
# In stage 10: transferred 122 clusters with 5 clusters populated
# In stage 11: transferred 130 clusters with 5 clusters populated
# In stage 12: transferred 112 clusters with 5 clusters populated
# In stage 13: transferred 118 clusters with 5 clusters populated
# In stage 14: transferred 125 clusters with 5 clusters populated
# In stage 15: transferred 127 clusters with 5 clusters populated
# In stage 16: transferred 113 clusters with 5 clusters populated
# In stage 17: transferred 112 clusters with 5 clusters populated
# In stage 18: transferred 120 clusters with 5 clusters populated
# In stage 19: transferred 116 clusters with 5 clusters populated
# In stage 20: transferred 122 clusters with 5 clusters populated
# In stage 21: transferred 105 clusters with 5 clusters populated
# In stage 22: transferred 102 clusters with 5 clusters populated
# In stage 23: transferred 112 clusters with 5 clusters populated
# In stage 24: transferred 116 clusters with 5 clusters populated
# In stage 25: transferred 112 clusters with 5 clusters populated
# In stage 26: transferred 104 clusters with 5 clusters populated
# In stage 27: transferred 95 clusters with 5 clusters populated
# In stage 28: transferred 103 clusters with 5 clusters populated
# In stage 29: transferred 99 clusters with 5 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_8 = numpy.array(mgp_8.cluster_doc_count)
print('Number of documents per cluster :', doc_count_8)

#Topic sorted by the number of document they are allocated to
top_index_8 = doc_count_8.argsort()
print('Most important clusters (by number of docs inside):', top_index_8)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_8.cluster_word_distribution, top_index_8, 10)
# Out:
# Number of documents per cluster : [113  88 229  39  31]
# Most important clusters (by number of docs inside): [4 3 1 0 2]
#
# Cluster 4 : [('korea', 10), ('suho', 9), ('bagus', 8), ('minseok', 8), ('stanford', 6), ('lagu', 5), ('universitas', 5), ('musik', 5), ('info', 5), ('chen', 5)]
#
# Cluster 3 : [('lagu', 7), ('sm', 5), ('lay', 5), ('bias', 5), ('instagram', 5), ('favorit', 5), ('do', 4), ('nama', 4), ('tau', 4), ('foto', 4)]
#
# Cluster 1 : [('kai', 22), ('hun', 14), ('kangen', 13), ('suho', 11), ('kyungsoo', 11), ('chanyeol', 10), ('do', 9), ('nonton', 9), ('drama', 7), ('akun', 6)]
#
# Cluster 0 : [('baekhyun', 36), ('exol', 27), ('foto', 18), ('idol', 15), ('chanyeol', 14), ('suho', 12), ('tta', 11), ('album', 10), ('ganteng', 9), ('ayo', 8)]
#
# Cluster 2 : [('suho', 118), ('bangga', 92), ('ketua', 52), ('kimjunmyeon', 46), ('sehat', 33), ('exol', 30), ('keren', 28), ('bahagia', 22), ('kasih', 21), ('cinta', 19)]

# %%
topic_dict_8 = {}
topic_names_8 = ["topik 1", "topik 2", "topik 3", "topik 4", "topik 5"]
for i, topic_num in enumerate(top_index_8):
    topic_dict_8[topic_num]=topic_names_8[i]

result_8 = create_topics_dataframe(data_text=df.tweet, mgp=mgp_8, threshold=0.3, topic_dict=topic_dict_8, token_list=datafinal)
result_8
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 4
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 5
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 3
# 3                           dilakukan untuk baekhyun    topik 4
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 5
# ..                                                 ...      ...
# 495  asli deh padahal udah gua nyala semua notif ny...  topik 3
# 496  Tolong EXO segera kembali sebelum aku terjatuh...  topik 4
# 497  Baru sadar selama stan exo aku ga punya momen ...  topik 4
# 498  padahal dulu suka banget nonton video konser s...  topik 3
# 499  Harapan gua terlalu muluk kayak nya kalo liat ...  topik 5
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 495  [asli, nyala, notif, instagram, member, hun, j...
# 496                           [jatuh, brondong, dream]
# 497  [sadar, stan, momen, utama, suka, hun, promosi...
# 498  [suka, nonton, video, konser, suju, shinee, as...
# 499                       [harap, muluk, liat, kangen]
#
# [500 rows x 3 columns]

# %%
topics_8 = get_topics_list(mgp_8, top_index_8, 10)
cm_gsdmm_8 = CoherenceModel(topics=topics_8,dictionary=dictionary,corpus=bow_corpus,texts=datafinal,coherence='c_v')
coherence_gsdmm_8 = cm_gsdmm_8.get_coherence()
print(coherence_gsdmm_8)
# Out:
# 0.37101552188012815

# %% [markdown]
# ##Sentimen Positif

# %%
#Iterasi ke-1 
mgp_9 = MovieGroupProcess(K=3, alpha=0.5, beta=0.5, n_iters=15)
vocab_pos = set(x for i in datafinal1 for x in i)
n_terms_pos = len(vocab_pos)
model_9 = mgp_9.fit(datafinal1, n_terms_pos)
# Out:
# In stage 0: transferred 253 clusters with 3 clusters populated
# In stage 1: transferred 158 clusters with 3 clusters populated
# In stage 2: transferred 132 clusters with 3 clusters populated
# In stage 3: transferred 89 clusters with 3 clusters populated
# In stage 4: transferred 82 clusters with 3 clusters populated
# In stage 5: transferred 73 clusters with 3 clusters populated
# In stage 6: transferred 76 clusters with 3 clusters populated
# In stage 7: transferred 66 clusters with 3 clusters populated
# In stage 8: transferred 59 clusters with 3 clusters populated
# In stage 9: transferred 63 clusters with 3 clusters populated
# In stage 10: transferred 59 clusters with 3 clusters populated
# In stage 11: transferred 77 clusters with 3 clusters populated
# In stage 12: transferred 85 clusters with 3 clusters populated
# In stage 13: transferred 67 clusters with 3 clusters populated
# In stage 14: transferred 72 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_9 = numpy.array(mgp_9.cluster_doc_count)
print('Number of documents per cluster :', doc_count_9)

#Topic sorted by the number of document they are allocated to
top_index_9 = doc_count_9.argsort()
print('Most important clusters (by number of docs inside):', top_index_9)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_9.cluster_word_distribution, top_index_9, 10)
# Out:
# Number of documents per cluster : [ 69 140 221]
# Most important clusters (by number of docs inside): [0 1 2]
#
# Cluster 0 : [('lagu', 13), ('korea', 13), ('suho', 10), ('bagus', 10), ('album', 9), ('minseok', 9), ('chen', 8), ('musik', 7), ('dengar', 7), ('foto', 6)]
#
# Cluster 1 : [('suho', 27), ('hun', 26), ('chanyeol', 21), ('baekhyun', 16), ('kai', 16), ('ganteng', 11), ('seoul', 10), ('kangen', 10), ('nonton', 9), ('kyungsoo', 8)]
#
# Cluster 2 : [('suho', 110), ('bangga', 92), ('ketua', 54), ('kimjunmyeon', 43), ('exol', 40), ('sehat', 33), ('keren', 26), ('baekhyun', 23), ('bahagia', 21), ('junmyeon', 19)]

# %%
topic_dict_9 = {}
topic_names_9 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_9):
    topic_dict_9[topic_num]=topic_names_9[i]

result_9 = create_topics_dataframe(data_text=df_positif.tweet, mgp=mgp_9, threshold=0.3, topic_dict=topic_dict_9, token_list=datafinal1)
result_9
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 3
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 3
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 2
# 3                           dilakukan untuk baekhyun    topik 3
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 3
# ..                                                 ...      ...
# 425   Tapi jujur bridges nya exo tuh bagus bagus ka...  topik 1
# 426  lagi bayangin kalau exo nct svt sama treasure ...  topik 2
# 427  tetap setia sama EXO di era gempuran idol lain...  topik 2
# 428  Gue suka KPop gara gara  BTS and EXO  sejak  2014  topik 2
# 429   Luhan Suho Lay Chanyeol Baekhyun Kyungsoo Seh...  topik 2
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 425  [jujur, bridges, bagus, bagus, lagu, bridges, ...
# 426  [bayangin, nct, svt, treasure, kumpul, rame, m...
# 427                         [setia, era, gempur, idol]
# 428                      [suka, kpop, gara, gara, bts]
# 429  [luhan, suho, lay, chanyeol, baekhyun, kyungso...
#
# [430 rows x 3 columns]

# %%
dictionary_pos = gensim.corpora.Dictionary(datafinal1)
bow_corpus_pos = [dictionary_pos.doc2bow(doc) for doc in datafinal1]

# %%
topics_9 = get_topics_list(mgp_9, top_index_9, 10)
cm_gsdmm_9 = CoherenceModel(topics=topics_9,dictionary=dictionary_pos,corpus=bow_corpus_pos,texts=datafinal1,coherence='c_v')
coherence_gsdmm_9 = cm_gsdmm_9.get_coherence()
print(coherence_gsdmm_9)
# Out:
# 0.4432385431754397

# %%
#Iterasi ke-2
mgp_10 = MovieGroupProcess(K=3, alpha=0.5, beta=0.5, n_iters=30)
model_10 = mgp_10.fit(datafinal1, n_terms_pos)
# Out:
# In stage 0: transferred 249 clusters with 3 clusters populated
# In stage 1: transferred 175 clusters with 3 clusters populated
# In stage 2: transferred 112 clusters with 3 clusters populated
# In stage 3: transferred 90 clusters with 3 clusters populated
# In stage 4: transferred 75 clusters with 3 clusters populated
# In stage 5: transferred 81 clusters with 3 clusters populated
# In stage 6: transferred 68 clusters with 3 clusters populated
# In stage 7: transferred 74 clusters with 3 clusters populated
# In stage 8: transferred 69 clusters with 3 clusters populated
# In stage 9: transferred 71 clusters with 3 clusters populated
# In stage 10: transferred 63 clusters with 3 clusters populated
# In stage 11: transferred 71 clusters with 3 clusters populated
# In stage 12: transferred 69 clusters with 3 clusters populated
# In stage 13: transferred 72 clusters with 3 clusters populated
# In stage 14: transferred 72 clusters with 3 clusters populated
# In stage 15: transferred 79 clusters with 3 clusters populated
# In stage 16: transferred 77 clusters with 3 clusters populated
# In stage 17: transferred 57 clusters with 3 clusters populated
# In stage 18: transferred 73 clusters with 3 clusters populated
# In stage 19: transferred 80 clusters with 3 clusters populated
# In stage 20: transferred 73 clusters with 3 clusters populated
# In stage 21: transferred 80 clusters with 3 clusters populated
# In stage 22: transferred 70 clusters with 3 clusters populated
# In stage 23: transferred 69 clusters with 3 clusters populated
# In stage 24: transferred 69 clusters with 3 clusters populated
# In stage 25: transferred 81 clusters with 3 clusters populated
# In stage 26: transferred 73 clusters with 3 clusters populated
# In stage 27: transferred 65 clusters with 3 clusters populated
# In stage 28: transferred 66 clusters with 3 clusters populated
# In stage 29: transferred 69 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_10 = numpy.array(mgp_10.cluster_doc_count)
print('Number of documents per cluster :', doc_count_10)

#Topic sorted by the number of document they are allocated to
top_index_10 = doc_count_10.argsort()
print('Most important clusters (by number of docs inside):', top_index_10)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_10.cluster_word_distribution, top_index_10, 10)
# Out:
# Number of documents per cluster : [213 127  90]
# Most important clusters (by number of docs inside): [2 1 0]
#
# Cluster 2 : [('baekhyun', 26), ('suho', 22), ('exol', 15), ('tta', 10), ('korea', 10), ('album', 9), ('seoul', 9), ('dubai', 8), ('ayo', 7), ('beli', 7)]
#
# Cluster 1 : [('hun', 25), ('chanyeol', 22), ('kai', 17), ('baekhyun', 14), ('ganteng', 11), ('do', 11), ('kyungsoo', 10), ('suho', 8), ('kangen', 8), ('drama', 7)]
#
# Cluster 0 : [('suho', 117), ('bangga', 92), ('ketua', 54), ('kimjunmyeon', 43), ('sehat', 33), ('exol', 28), ('keren', 28), ('bahagia', 21), ('kasih', 20), ('junmyeon', 19)]

# %%
topic_dict_10 = {}
topic_names_10 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_10):
    topic_dict_10[topic_num]=topic_names_10[i]

result_10 = create_topics_dataframe(data_text=df_positif.tweet, mgp=mgp_10, threshold=0.3, topic_dict=topic_dict_10, token_list=datafinal1)
result_10
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 3
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 2
# 3                           dilakukan untuk baekhyun    topik 1
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 3
# ..                                                 ...      ...
# 425   Tapi jujur bridges nya exo tuh bagus bagus ka...  topik 3
# 426  lagi bayangin kalau exo nct svt sama treasure ...  topik 1
# 427  tetap setia sama EXO di era gempuran idol lain...  topik 2
# 428  Gue suka KPop gara gara  BTS and EXO  sejak  2014  topik 2
# 429   Luhan Suho Lay Chanyeol Baekhyun Kyungsoo Seh...  topik 2
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 425  [jujur, bridges, bagus, bagus, lagu, bridges, ...
# 426  [bayangin, nct, svt, treasure, kumpul, rame, m...
# 427                         [setia, era, gempur, idol]
# 428                      [suka, kpop, gara, gara, bts]
# 429  [luhan, suho, lay, chanyeol, baekhyun, kyungso...
#
# [430 rows x 3 columns]

# %%
topics_10 = get_topics_list(mgp_10, top_index_10, 10)
cm_gsdmm_10 = CoherenceModel(topics=topics_10,dictionary=dictionary_pos,corpus=bow_corpus_pos,texts=datafinal1,coherence='c_v')
coherence_gsdmm_10 = cm_gsdmm_10.get_coherence()
print(coherence_gsdmm_10)
# Out:
# 0.40348694513522015

# %%
#Iterasi ke-3
mgp_11 = MovieGroupProcess(K=3, alpha=0.5, beta=0.5, n_iters=10)
model_11 = mgp_11.fit(datafinal1, n_terms_pos)
# Out:
# In stage 0: transferred 259 clusters with 3 clusters populated
# In stage 1: transferred 139 clusters with 3 clusters populated
# In stage 2: transferred 118 clusters with 3 clusters populated
# In stage 3: transferred 97 clusters with 3 clusters populated
# In stage 4: transferred 85 clusters with 3 clusters populated
# In stage 5: transferred 86 clusters with 3 clusters populated
# In stage 6: transferred 73 clusters with 3 clusters populated
# In stage 7: transferred 76 clusters with 3 clusters populated
# In stage 8: transferred 65 clusters with 3 clusters populated
# In stage 9: transferred 58 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_11 = numpy.array(mgp_11.cluster_doc_count)
print('Number of documents per cluster :', doc_count_11)

#Topic sorted by the number of document they are allocated to
top_index_11 = doc_count_11.argsort()
print('Most important clusters (by number of docs inside):', top_index_11)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_11.cluster_word_distribution, top_index_11, 10)
# Out:
# Number of documents per cluster : [121 211  98]
# Most important clusters (by number of docs inside): [2 0 1]
#
# Cluster 2 : [('hun', 23), ('chanyeol', 20), ('kai', 13), ('foto', 11), ('do', 11), ('kyungsoo', 10), ('lagu', 9), ('bagus', 9), ('ganteng', 8), ('drama', 8)]
#
# Cluster 0 : [('baekhyun', 39), ('suho', 22), ('exol', 16), ('seoul', 10), ('tta', 10), ('album', 9), ('dubai', 8), ('chen', 8), ('kai', 8), ('ayo', 7)]
#
# Cluster 1 : [('suho', 122), ('bangga', 92), ('ketua', 54), ('kimjunmyeon', 45), ('sehat', 33), ('keren', 29), ('exol', 28), ('bahagia', 22), ('stanford', 20), ('kasih', 19)]

# %%
topic_dict_11 = {}
topic_names_11 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_11):
    topic_dict_11[topic_num]=topic_names_11[i]

result_11 = create_topics_dataframe(data_text=df_positif.tweet, mgp=mgp_11, threshold=0.3, topic_dict=topic_dict_11, token_list=datafinal1)
result_11
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 2
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 3
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 1
# 3                           dilakukan untuk baekhyun    topik 2
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 3
# ..                                                 ...      ...
# 425   Tapi jujur bridges nya exo tuh bagus bagus ka...  topik 1
# 426  lagi bayangin kalau exo nct svt sama treasure ...  topik 2
# 427  tetap setia sama EXO di era gempuran idol lain...  topik 2
# 428  Gue suka KPop gara gara  BTS and EXO  sejak  2014  topik 1
# 429   Luhan Suho Lay Chanyeol Baekhyun Kyungsoo Seh...  topik 1
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 425  [jujur, bridges, bagus, bagus, lagu, bridges, ...
# 426  [bayangin, nct, svt, treasure, kumpul, rame, m...
# 427                         [setia, era, gempur, idol]
# 428                      [suka, kpop, gara, gara, bts]
# 429  [luhan, suho, lay, chanyeol, baekhyun, kyungso...
#
# [430 rows x 3 columns]

# %%
topics_11 = get_topics_list(mgp_11, top_index_11, 10)
cm_gsdmm_11 = CoherenceModel(topics=topics_11,dictionary=dictionary_pos,corpus=bow_corpus_pos,texts=datafinal1,coherence='c_v')
coherence_gsdmm_11 = cm_gsdmm_11.get_coherence()
print(coherence_gsdmm_11)
# Out:
# 0.40660086429224895

# %%
#Iterasi ke-4
mgp_12 = MovieGroupProcess(K=3, alpha=0.7, beta=0.5, n_iters=15)
model_12 = mgp_12.fit(datafinal1, n_terms_pos)
# Out:
# In stage 0: transferred 239 clusters with 3 clusters populated
# In stage 1: transferred 159 clusters with 3 clusters populated
# In stage 2: transferred 119 clusters with 3 clusters populated
# In stage 3: transferred 94 clusters with 3 clusters populated
# In stage 4: transferred 70 clusters with 3 clusters populated
# In stage 5: transferred 65 clusters with 3 clusters populated
# In stage 6: transferred 78 clusters with 3 clusters populated
# In stage 7: transferred 61 clusters with 3 clusters populated
# In stage 8: transferred 64 clusters with 3 clusters populated
# In stage 9: transferred 67 clusters with 3 clusters populated
# In stage 10: transferred 77 clusters with 3 clusters populated
# In stage 11: transferred 71 clusters with 3 clusters populated
# In stage 12: transferred 62 clusters with 3 clusters populated
# In stage 13: transferred 71 clusters with 3 clusters populated
# In stage 14: transferred 83 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_12 = numpy.array(mgp_12.cluster_doc_count)
print('Number of documents per cluster :', doc_count_12)

#Topic sorted by the number of document they are allocated to
top_index_12 = doc_count_12.argsort()
print('Most important clusters (by number of docs inside):', top_index_12)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_12.cluster_word_distribution, top_index_12, 10)
# Out:
# Number of documents per cluster : [ 89 224 117]
# Most important clusters (by number of docs inside): [0 2 1]
#
# Cluster 0 : [('baekhyun', 37), ('exol', 16), ('tta', 10), ('hun', 8), ('suho', 8), ('foto', 8), ('album', 8), ('ayo', 7), ('beli', 6), ('bantu', 5)]
#
# Cluster 2 : [('chanyeol', 22), ('kai', 18), ('hun', 17), ('lagu', 12), ('bagus', 10), ('do', 10), ('suho', 9), ('foto', 9), ('minseok', 9), ('kangen', 8)]
#
# Cluster 1 : [('suho', 130), ('bangga', 92), ('ketua', 54), ('kimjunmyeon', 45), ('sehat', 33), ('exol', 28), ('keren', 26), ('bahagia', 22), ('stanford', 20), ('kasih', 19)]

# %%
topic_dict_12 = {}
topic_names_12 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_12):
    topic_dict_12[topic_num]=topic_names_12[i]

result_12 = create_topics_dataframe(data_text=df_positif.tweet, mgp=mgp_12, threshold=0.3, topic_dict=topic_dict_12, token_list=datafinal1)
result_12
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 1
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 1
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 2
# 3                           dilakukan untuk baekhyun    topik 1
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 3
# ..                                                 ...      ...
# 425   Tapi jujur bridges nya exo tuh bagus bagus ka...  topik 2
# 426  lagi bayangin kalau exo nct svt sama treasure ...  topik 2
# 427  tetap setia sama EXO di era gempuran idol lain...  topik 2
# 428  Gue suka KPop gara gara  BTS and EXO  sejak  2014  topik 2
# 429   Luhan Suho Lay Chanyeol Baekhyun Kyungsoo Seh...  topik 2
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 425  [jujur, bridges, bagus, bagus, lagu, bridges, ...
# 426  [bayangin, nct, svt, treasure, kumpul, rame, m...
# 427                         [setia, era, gempur, idol]
# 428                      [suka, kpop, gara, gara, bts]
# 429  [luhan, suho, lay, chanyeol, baekhyun, kyungso...
#
# [430 rows x 3 columns]

# %%
topics_12 = get_topics_list(mgp_12, top_index_12, 10)
cm_gsdmm_12 = CoherenceModel(topics=topics_12,dictionary=dictionary_pos,corpus=bow_corpus_pos,texts=datafinal1,coherence='c_v')
coherence_gsdmm_12 = cm_gsdmm_12.get_coherence()
print(coherence_gsdmm_12)
# Out:
# 0.38532283513706495

# %%
#Iterasi ke-5 (pilih ini)
mgp_13 = MovieGroupProcess(K=3, alpha=0.35, beta=0.5, n_iters=15)
model_13 = mgp_13.fit(datafinal1, n_terms_pos)
# Out:
# In stage 0: transferred 237 clusters with 3 clusters populated
# In stage 1: transferred 169 clusters with 3 clusters populated
# In stage 2: transferred 144 clusters with 3 clusters populated
# In stage 3: transferred 108 clusters with 3 clusters populated
# In stage 4: transferred 82 clusters with 3 clusters populated
# In stage 5: transferred 73 clusters with 3 clusters populated
# In stage 6: transferred 58 clusters with 3 clusters populated
# In stage 7: transferred 55 clusters with 3 clusters populated
# In stage 8: transferred 67 clusters with 3 clusters populated
# In stage 9: transferred 60 clusters with 3 clusters populated
# In stage 10: transferred 59 clusters with 3 clusters populated
# In stage 11: transferred 56 clusters with 3 clusters populated
# In stage 12: transferred 55 clusters with 3 clusters populated
# In stage 13: transferred 63 clusters with 3 clusters populated
# In stage 14: transferred 57 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_13 = numpy.array(mgp_13.cluster_doc_count)
print('Number of documents per cluster :', doc_count_13)

#Topic sorted by the number of document they are allocated to
top_index_13 = doc_count_13.argsort()
print('Most important clusters (by number of docs inside):', top_index_13)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_13.cluster_word_distribution, top_index_13, 10)
# Out:
# Number of documents per cluster : [ 53 163 214]
# Most important clusters (by number of docs inside): [0 1 2]
#
# Cluster 0 : [('kai', 8), ('chen', 8), ('dunia', 7), ('suho', 6), ('foto', 5), ('senang', 5), ('siar', 5), ('suka', 4), ('instagram', 4), ('kim', 4)]
#
# Cluster 1 : [('baekhyun', 39), ('hun', 26), ('chanyeol', 22), ('suho', 21), ('exol', 19), ('ganteng', 15), ('foto', 13), ('kai', 11), ('do', 11), ('seoul', 10)]
#
# Cluster 2 : [('suho', 120), ('bangga', 93), ('ketua', 54), ('kimjunmyeon', 45), ('sehat', 33), ('keren', 28), ('exol', 27), ('bahagia', 21), ('korea', 19), ('kasih', 19)]

# %%
topic_dict_13 = {}
topic_names_13 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_13):
    topic_dict_13[topic_num]=topic_names_13[i]

result_13 = create_topics_dataframe(data_text=df_positif.tweet, mgp=mgp_13, threshold=0.3, topic_dict=topic_dict_13, token_list=datafinal1)
result_13
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 2
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 3
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 2
# 3                           dilakukan untuk baekhyun    topik 2
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 3
# ..                                                 ...      ...
# 425   Tapi jujur bridges nya exo tuh bagus bagus ka...  topik 3
# 426  lagi bayangin kalau exo nct svt sama treasure ...  topik 1
# 427  tetap setia sama EXO di era gempuran idol lain...  topik 1
# 428  Gue suka KPop gara gara  BTS and EXO  sejak  2014  topik 1
# 429   Luhan Suho Lay Chanyeol Baekhyun Kyungsoo Seh...  topik 2
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 425  [jujur, bridges, bagus, bagus, lagu, bridges, ...
# 426  [bayangin, nct, svt, treasure, kumpul, rame, m...
# 427                         [setia, era, gempur, idol]
# 428                      [suka, kpop, gara, gara, bts]
# 429  [luhan, suho, lay, chanyeol, baekhyun, kyungso...
#
# [430 rows x 3 columns]

# %%
topics_13 = get_topics_list(mgp_13, top_index_13, 10)
cm_gsdmm_13 = CoherenceModel(topics=topics_13,dictionary=dictionary_pos,corpus=bow_corpus_pos,texts=datafinal1,coherence='c_v')
coherence_gsdmm_13 = cm_gsdmm_13.get_coherence()
print(coherence_gsdmm_13)
# Out:
# 0.4628058224279896

# %%
#Iterasi ke-6
mgp_14 = MovieGroupProcess(K=5, alpha=0.35, beta=0.7, n_iters=15)
model_14 = mgp_14.fit(datafinal1, n_terms_pos)
# Out:
# In stage 0: transferred 296 clusters with 5 clusters populated
# In stage 1: transferred 232 clusters with 5 clusters populated
# In stage 2: transferred 155 clusters with 5 clusters populated
# In stage 3: transferred 136 clusters with 5 clusters populated
# In stage 4: transferred 123 clusters with 5 clusters populated
# In stage 5: transferred 108 clusters with 5 clusters populated
# In stage 6: transferred 93 clusters with 5 clusters populated
# In stage 7: transferred 97 clusters with 5 clusters populated
# In stage 8: transferred 97 clusters with 5 clusters populated
# In stage 9: transferred 97 clusters with 5 clusters populated
# In stage 10: transferred 99 clusters with 5 clusters populated
# In stage 11: transferred 84 clusters with 5 clusters populated
# In stage 12: transferred 91 clusters with 5 clusters populated
# In stage 13: transferred 88 clusters with 5 clusters populated
# In stage 14: transferred 97 clusters with 5 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_14 = numpy.array(mgp_14.cluster_doc_count)
print('Number of documents per cluster :', doc_count_14)

#Topic sorted by the number of document they are allocated to
top_index_14 = doc_count_14.argsort()
print('Most important clusters (by number of docs inside):', top_index_14)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_14.cluster_word_distribution, top_index_14, 10)
# Out:
# Number of documents per cluster : [133 209  19  23  46]
# Most important clusters (by number of docs inside): [2 3 4 0 1]
#
# Cluster 2 : [('album', 9), ('chen', 7), ('beli', 5), ('ayo', 4), ('shopee', 4), ('salah', 4), ('foto', 3), ('youtube', 3), ('nomer', 3), ('poster', 2)]
#
# Cluster 3 : [('minseok', 8), ('bagus', 7), ('korea', 7), ('universitas', 5), ('stanford', 5), ('konferensi', 4), ('studi', 4), ('siar', 4), ('lengkap', 4), ('suho', 3)]
#
# Cluster 4 : [('baekhyun', 13), ('exol', 13), ('suho', 12), ('tta', 10), ('seoul', 8), ('dubai', 6), ('terbang', 5), ('bantu', 5), ('usa', 4), ('perang', 4)]
#
# Cluster 0 : [('baekhyun', 26), ('hun', 26), ('chanyeol', 21), ('kai', 19), ('foto', 12), ('do', 11), ('ganteng', 10), ('kyungsoo', 10), ('suho', 9), ('kangen', 9)]
#
# Cluster 1 : [('suho', 122), ('bangga', 91), ('ketua', 53), ('kimjunmyeon', 44), ('sehat', 33), ('exol', 30), ('keren', 29), ('bahagia', 21), ('kasih', 19), ('cinta', 18)]

# %%
topic_dict_14 = {}
topic_names_14 = ["topik 1", "topik 2", "topik 3", "topik 4", "topik 5"]
for i, topic_num in enumerate(top_index_14):
    topic_dict_14[topic_num]=topic_names_14[i]

result_14 = create_topics_dataframe(data_text=df_positif.tweet, mgp=mgp_14, threshold=0.3, topic_dict=topic_dict_14, token_list=datafinal1)
result_14
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 4
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 5
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 4
# 3                           dilakukan untuk baekhyun    topik 4
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 5
# ..                                                 ...      ...
# 425   Tapi jujur bridges nya exo tuh bagus bagus ka...  topik 5
# 426  lagi bayangin kalau exo nct svt sama treasure ...  topik 2
# 427  tetap setia sama EXO di era gempuran idol lain...  topik 3
# 428  Gue suka KPop gara gara  BTS and EXO  sejak  2014  topik 5
# 429   Luhan Suho Lay Chanyeol Baekhyun Kyungsoo Seh...  topik 4
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 425  [jujur, bridges, bagus, bagus, lagu, bridges, ...
# 426  [bayangin, nct, svt, treasure, kumpul, rame, m...
# 427                         [setia, era, gempur, idol]
# 428                      [suka, kpop, gara, gara, bts]
# 429  [luhan, suho, lay, chanyeol, baekhyun, kyungso...
#
# [430 rows x 3 columns]

# %%
topics_14 = get_topics_list(mgp_14, top_index_14, 10)
cm_gsdmm_14 = CoherenceModel(topics=topics_14,dictionary=dictionary_pos,corpus=bow_corpus_pos,texts=datafinal1,coherence='c_v')
coherence_gsdmm_14 = cm_gsdmm_14.get_coherence()
print(coherence_gsdmm_14)
# Out:
# 0.3605318795090696

# %%
#Iterasi ke-7
mgp_15 = MovieGroupProcess(K=3, alpha=0.35, beta=0.35, n_iters=15)
model_15 = mgp_15.fit(datafinal1, n_terms_pos)
# Out:
# In stage 0: transferred 265 clusters with 3 clusters populated
# In stage 1: transferred 161 clusters with 3 clusters populated
# In stage 2: transferred 128 clusters with 3 clusters populated
# In stage 3: transferred 102 clusters with 3 clusters populated
# In stage 4: transferred 67 clusters with 3 clusters populated
# In stage 5: transferred 68 clusters with 3 clusters populated
# In stage 6: transferred 69 clusters with 3 clusters populated
# In stage 7: transferred 77 clusters with 3 clusters populated
# In stage 8: transferred 74 clusters with 3 clusters populated
# In stage 9: transferred 64 clusters with 3 clusters populated
# In stage 10: transferred 70 clusters with 3 clusters populated
# In stage 11: transferred 58 clusters with 3 clusters populated
# In stage 12: transferred 60 clusters with 3 clusters populated
# In stage 13: transferred 63 clusters with 3 clusters populated
# In stage 14: transferred 79 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_15 = numpy.array(mgp_15.cluster_doc_count)
print('Number of documents per cluster :', doc_count_15)

#Topic sorted by the number of document they are allocated to
top_index_15 = doc_count_15.argsort()
print('Most important clusters (by number of docs inside):', top_index_15)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_15.cluster_word_distribution, top_index_15, 10)
# Out:
# Number of documents per cluster : [112 107 211]
# Most important clusters (by number of docs inside): [1 0 2]
#
# Cluster 1 : [('suho', 31), ('bahagia', 17), ('kasih', 14), ('ketua', 13), ('sehat', 13), ('cinta', 12), ('kimjunmyeon', 10), ('bagus', 10), ('kai', 10), ('seoul', 9)]
#
# Cluster 0 : [('hun', 26), ('chanyeol', 22), ('foto', 18), ('baekhyun', 11), ('suho', 11), ('do', 11), ('kyungsoo', 10), ('kangen', 9), ('ganteng', 9), ('drama', 8)]
#
# Cluster 2 : [('suho', 105), ('bangga', 89), ('ketua', 41), ('exol', 36), ('kimjunmyeon', 35), ('baekhyun', 29), ('keren', 28), ('korea', 21), ('sehat', 20), ('stanford', 19)]

# %%
topic_dict_15 = {}
topic_names_15 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_15):
    topic_dict_15[topic_num]=topic_names_15[i]

result_15 = create_topics_dataframe(data_text=df_positif.tweet, mgp=mgp_15, threshold=0.3, topic_dict=topic_dict_15, token_list=datafinal1)
result_15
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 3
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 3
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 2
# 3                           dilakukan untuk baekhyun    topik 3
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 1
# ..                                                 ...      ...
# 425   Tapi jujur bridges nya exo tuh bagus bagus ka...  topik 1
# 426  lagi bayangin kalau exo nct svt sama treasure ...  topik 1
# 427  tetap setia sama EXO di era gempuran idol lain...  topik 1
# 428  Gue suka KPop gara gara  BTS and EXO  sejak  2014  topik 1
# 429   Luhan Suho Lay Chanyeol Baekhyun Kyungsoo Seh...  topik 2
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 425  [jujur, bridges, bagus, bagus, lagu, bridges, ...
# 426  [bayangin, nct, svt, treasure, kumpul, rame, m...
# 427                         [setia, era, gempur, idol]
# 428                      [suka, kpop, gara, gara, bts]
# 429  [luhan, suho, lay, chanyeol, baekhyun, kyungso...
#
# [430 rows x 3 columns]

# %%
topics_15 = get_topics_list(mgp_15, top_index_15, 10)
cm_gsdmm_15 = CoherenceModel(topics=topics_15,dictionary=dictionary_pos,corpus=bow_corpus_pos,texts=datafinal1,coherence='c_v')
coherence_gsdmm_15 = cm_gsdmm_15.get_coherence()
print(coherence_gsdmm_15)
# Out:
# 0.37615404938753944

# %%
#Iterasi ke-8
mgp_16 = MovieGroupProcess(K=5, alpha=0.35, beta=0.5, n_iters=15)
model_16 = mgp_16.fit(datafinal1, n_terms_pos)
# Out:
# In stage 0: transferred 313 clusters with 5 clusters populated
# In stage 1: transferred 192 clusters with 5 clusters populated
# In stage 2: transferred 171 clusters with 5 clusters populated
# In stage 3: transferred 146 clusters with 5 clusters populated
# In stage 4: transferred 119 clusters with 5 clusters populated
# In stage 5: transferred 100 clusters with 5 clusters populated
# In stage 6: transferred 104 clusters with 5 clusters populated
# In stage 7: transferred 103 clusters with 5 clusters populated
# In stage 8: transferred 98 clusters with 5 clusters populated
# In stage 9: transferred 93 clusters with 5 clusters populated
# In stage 10: transferred 88 clusters with 5 clusters populated
# In stage 11: transferred 89 clusters with 5 clusters populated
# In stage 12: transferred 80 clusters with 5 clusters populated
# In stage 13: transferred 99 clusters with 5 clusters populated
# In stage 14: transferred 98 clusters with 5 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_16 = numpy.array(mgp_16.cluster_doc_count)
print('Number of documents per cluster :', doc_count_16)

#Topic sorted by the number of document they are allocated to
top_index_16 = doc_count_16.argsort()
print('Most important clusters (by number of docs inside):', top_index_16)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_16.cluster_word_distribution, top_index_16, 10)
# Out:
# Number of documents per cluster : [ 47 116 202  38  27]
# Most important clusters (by number of docs inside): [4 3 0 1 2]
#
# Cluster 4 : [('bagus', 10), ('minseok', 9), ('nyanyi', 4), ('chen', 4), ('lagu', 4), ('salah', 4), ('foto', 4), ('instagram', 4), ('vokal', 3), ('imut', 3)]
#
# Cluster 3 : [('kai', 9), ('exol', 7), ('bias', 6), ('wajib', 4), ('militer', 4), ('chanyeol', 4), ('do', 4), ('kim', 4), ('tau', 4), ('favorit', 4)]
#
# Cluster 0 : [('suho', 13), ('korea', 13), ('musik', 9), ('stanford', 7), ('info', 5), ('dunia', 5), ('lagu', 5), ('universitas', 5), ('kumpul', 5), ('senang', 4)]
#
# Cluster 1 : [('baekhyun', 35), ('hun', 24), ('chanyeol', 18), ('suho', 16), ('foto', 13), ('exol', 10), ('kai', 10), ('tta', 10), ('album', 10), ('kyungsoo', 9)]
#
# Cluster 2 : [('suho', 118), ('bangga', 92), ('ketua', 53), ('kimjunmyeon', 44), ('sehat', 33), ('exol', 29), ('keren', 28), ('bahagia', 21), ('kasih', 19), ('cinta', 18)]

# %%
topic_dict_16 = {}
topic_names_16 = ["topik 1", "topik 2", "topik 3", "topik 4", "topik 5"]
for i, topic_num in enumerate(top_index_16):
    topic_dict_16[topic_num]=topic_names_16[i]

result_16 = create_topics_dataframe(data_text=df_positif.tweet, mgp=mgp_16, threshold=0.3, topic_dict=topic_dict_16, token_list=datafinal1)
result_16
# Out:
#                                                  tweet    topik  \
# 0                            Dilakukan untuk Baekhyun   topik 4
# 1    Peristiwa selanjutnya kita berkumpul lagi ya g...  topik 3
# 2    semua nya tertawa lihat tingkah nya Sehun tim ...  topik 4
# 3                           dilakukan untuk baekhyun    topik 4
# 4    Saya pikir kami memiliki waktu yg sangat baik ...  topik 5
# ..                                                 ...      ...
# 425   Tapi jujur bridges nya exo tuh bagus bagus ka...  topik 1
# 426  lagi bayangin kalau exo nct svt sama treasure ...  topik 3
# 427  tetap setia sama EXO di era gempuran idol lain...  topik 1
# 428  Gue suka KPop gara gara  BTS and EXO  sejak  2014  topik 5
# 429   Luhan Suho Lay Chanyeol Baekhyun Kyungsoo Seh...  topik 4
#
#                                             token_list
# 0                                     [laku, baekhyun]
# 1                                  [peristiwa, kumpul]
# 2    [tertawa, tingkah, hun, tim, produksi, kyungso...
# 3                                     [laku, baekhyun]
# 4    [pikir, milik, tunggu, sulit, kenang, masamasa...
# ..                                                 ...
# 425  [jujur, bridges, bagus, bagus, lagu, bridges, ...
# 426  [bayangin, nct, svt, treasure, kumpul, rame, m...
# 427                         [setia, era, gempur, idol]
# 428                      [suka, kpop, gara, gara, bts]
# 429  [luhan, suho, lay, chanyeol, baekhyun, kyungso...
#
# [430 rows x 3 columns]

# %%
topics_16 = get_topics_list(mgp_16, top_index_16, 10)
cm_gsdmm_16 = CoherenceModel(topics=topics_16,dictionary=dictionary_pos,corpus=bow_corpus_pos,texts=datafinal1,coherence='c_v')
coherence_gsdmm_16 = cm_gsdmm_16.get_coherence()
print(coherence_gsdmm_16)
# Out:
# 0.3952080294017343

# %% [markdown]
# ##Sentimen Negatif

# %%
#Iterasi ke-1
mgp_17 = MovieGroupProcess(K=3, alpha=0.5, beta=0.5, n_iters=10)
vocab_neg = set(x for i in datafinal2 for x in i)
n_terms_neg = len(vocab_neg)
model_17 = mgp_17.fit(datafinal2, n_terms_neg)
# Out:
# In stage 0: transferred 36 clusters with 3 clusters populated
# In stage 1: transferred 26 clusters with 3 clusters populated
# In stage 2: transferred 19 clusters with 3 clusters populated
# In stage 3: transferred 16 clusters with 3 clusters populated
# In stage 4: transferred 17 clusters with 3 clusters populated
# In stage 5: transferred 23 clusters with 3 clusters populated
# In stage 6: transferred 22 clusters with 3 clusters populated
# In stage 7: transferred 25 clusters with 3 clusters populated
# In stage 8: transferred 24 clusters with 3 clusters populated
# In stage 9: transferred 24 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_17 = numpy.array(mgp_17.cluster_doc_count)
print('Number of documents per cluster :', doc_count_17)

#Topic sorted by the number of document they are allocated to
top_index_17 = doc_count_17.argsort()
print('Most important clusters (by number of docs inside):', top_index_17)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_17.cluster_word_distribution, top_index_17, 10)
# Out:
# Number of documents per cluster : [19 25 26]
# Most important clusters (by number of docs inside): [0 1 2]
#
# Cluster 0 : [('jeda', 4), ('silah', 3), ('grup', 3), ('promosi', 3), ('harap', 3), ('semangat', 3), ('exol', 2), ('idol', 2), ('idola', 2), ('konten', 2)]
#
# Cluster 1 : [('instagram', 5), ('suara', 3), ('dubai', 3), ('hilang', 3), ('kai', 2), ('hun', 2), ('ketua', 2), ('tiktok', 2), ('mulu', 2), ('video', 2)]
#
# Cluster 2 : [('exol', 10), ('idol', 9), ('foto', 8), ('lay', 6), ('lo', 5), ('ungu', 5), ('akun', 5), ('fokus', 4), ('campur', 4), ('chanyeol', 4)]

# %%
topic_dict_17 = {}
topic_names_17 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_17):
    topic_dict_17[topic_num]=topic_names_17[i]

result_17 = create_topics_dataframe(data_text=df_negatif.tweet, mgp=mgp_17, threshold=0.3, topic_dict=topic_dict_17, token_list=datafinal2)
result_17
# Out:
#                                                 tweet    topik  \
# 0   lucu banget liat Kai marah gegara eribong di s...  topik 2
# 1   Tidak sabar menanti Kji3  Tapi tunggu Itu bera...  topik 2
# 2   Beri suara Baekhyun di TTA yuk Eri ayo keluari...  topik 2
# 3   Pesan suara dari  untuk 5 th hari jadi Debut E...  topik 2
# 4   Biasa mendapat tinjauan harian Chanyeol tiap h...  topik 3
# ..                                                ...      ...
# 65  asli deh padahal udah gua nyala semua notif ny...  topik 2
# 66  Tolong EXO segera kembali sebelum aku terjatuh...  topik 2
# 67  Baru sadar selama stan exo aku ga punya momen ...  topik 3
# 68  padahal dulu suka banget nonton video konser s...  topik 3
# 69  Harapan gua terlalu muluk kayak nya kalo liat ...  topik 1
#
#                                            token_list
# 0   [lucu, liat, kai, marah, gegara, eribong, semb...
# 1                  [sabar, kji, tunggu, arti, enlist]
# 2   [suara, baekhyun, tta, eri, ayo, keluarin, mod...
# 3   [pesan, suara, debut, cbx, jepang, cr, chennie...
# 4   [tinjau, chanyeol, muncul, asa, muncul, chanye...
# ..                                                ...
# 65  [asli, nyala, notif, instagram, member, hun, j...
# 66                           [jatuh, brondong, dream]
# 67  [sadar, stan, momen, utama, suka, hun, promosi...
# 68  [suka, nonton, video, konser, suju, shinee, as...
# 69                       [harap, muluk, liat, kangen]
#
# [70 rows x 3 columns]

# %%
dictionary_neg = gensim.corpora.Dictionary(datafinal2)
bow_corpus_neg = [dictionary_neg.doc2bow(doc) for doc in datafinal2]
topics_17 = get_topics_list(mgp_17, top_index_17, 10)
cm_gsdmm_17 = CoherenceModel(topics=topics_17,dictionary=dictionary_neg,corpus=bow_corpus_neg,texts=datafinal2,coherence='c_v')
coherence_gsdmm_17 = cm_gsdmm_17.get_coherence()
print(coherence_gsdmm_17)
# Out:
# 0.4734692671377054

# %%
#Iterasi ke-2
mgp_18 = MovieGroupProcess(K=3, alpha=0.5, beta=0.5, n_iters=30)
model_18 = mgp_18.fit(datafinal2, n_terms_neg)
# Out:
# In stage 0: transferred 43 clusters with 3 clusters populated
# In stage 1: transferred 34 clusters with 3 clusters populated
# In stage 2: transferred 29 clusters with 3 clusters populated
# In stage 3: transferred 17 clusters with 3 clusters populated
# In stage 4: transferred 23 clusters with 3 clusters populated
# In stage 5: transferred 23 clusters with 3 clusters populated
# In stage 6: transferred 21 clusters with 3 clusters populated
# In stage 7: transferred 20 clusters with 3 clusters populated
# In stage 8: transferred 26 clusters with 3 clusters populated
# In stage 9: transferred 32 clusters with 3 clusters populated
# In stage 10: transferred 21 clusters with 3 clusters populated
# In stage 11: transferred 20 clusters with 3 clusters populated
# In stage 12: transferred 15 clusters with 3 clusters populated
# In stage 13: transferred 19 clusters with 3 clusters populated
# In stage 14: transferred 14 clusters with 3 clusters populated
# In stage 15: transferred 24 clusters with 3 clusters populated
# In stage 16: transferred 22 clusters with 3 clusters populated
# In stage 17: transferred 25 clusters with 3 clusters populated
# In stage 18: transferred 27 clusters with 3 clusters populated
# In stage 19: transferred 19 clusters with 3 clusters populated
# In stage 20: transferred 29 clusters with 3 clusters populated
# In stage 21: transferred 21 clusters with 3 clusters populated
# In stage 22: transferred 25 clusters with 3 clusters populated
# In stage 23: transferred 27 clusters with 3 clusters populated
# In stage 24: transferred 17 clusters with 3 clusters populated
# In stage 25: transferred 21 clusters with 3 clusters populated
# In stage 26: transferred 23 clusters with 3 clusters populated
# In stage 27: transferred 17 clusters with 3 clusters populated
# In stage 28: transferred 19 clusters with 3 clusters populated
# In stage 29: transferred 24 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_18 = numpy.array(mgp_18.cluster_doc_count)
print('Number of documents per cluster :', doc_count_18)

#Topic sorted by the number of document they are allocated to
top_index_18 = doc_count_18.argsort()
print('Most important clusters (by number of docs inside):', top_index_18)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_18.cluster_word_distribution, top_index_18, 10)
# Out:
# Number of documents per cluster : [30 16 24]
# Most important clusters (by number of docs inside): [1 2 0]
#
# Cluster 1 : [('instagram', 4), ('hun', 3), ('suara', 3), ('harap', 3), ('kangen', 2), ('tiktok', 2), ('video', 2), ('member', 2), ('liat', 2), ('baekhyun', 2)]
#
# Cluster 2 : [('lay', 7), ('akun', 5), ('exol', 4), ('ungu', 4), ('silah', 4), ('grup', 4), ('jeda', 4), ('henti', 3), ('only', 3), ('kai', 3)]
#
# Cluster 0 : [('idol', 9), ('exol', 8), ('foto', 7), ('fokus', 4), ('campur', 4), ('chanyeol', 4), ('konser', 4), ('susah', 3), ('profil', 3), ('asa', 3)]

# %%
topic_dict_18 = {}
topic_names_18 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_18):
    topic_dict_18[topic_num]=topic_names_18[i]

result_18 = create_topics_dataframe(data_text=df_negatif.tweet, mgp=mgp_18, threshold=0.3, topic_dict=topic_dict_18, token_list=datafinal2)
result_18
# Out:
#                                                 tweet    topik  \
# 0   lucu banget liat Kai marah gegara eribong di s...  topik 1
# 1   Tidak sabar menanti Kji3  Tapi tunggu Itu bera...  topik 2
# 2   Beri suara Baekhyun di TTA yuk Eri ayo keluari...  topik 1
# 3   Pesan suara dari  untuk 5 th hari jadi Debut E...  topik 1
# 4   Biasa mendapat tinjauan harian Chanyeol tiap h...  topik 3
# ..                                                ...      ...
# 65  asli deh padahal udah gua nyala semua notif ny...  topik 1
# 66  Tolong EXO segera kembali sebelum aku terjatuh...  topik 2
# 67  Baru sadar selama stan exo aku ga punya momen ...  topik 2
# 68  padahal dulu suka banget nonton video konser s...  topik 3
# 69  Harapan gua terlalu muluk kayak nya kalo liat ...  topik 1
#
#                                            token_list
# 0   [lucu, liat, kai, marah, gegara, eribong, semb...
# 1                  [sabar, kji, tunggu, arti, enlist]
# 2   [suara, baekhyun, tta, eri, ayo, keluarin, mod...
# 3   [pesan, suara, debut, cbx, jepang, cr, chennie...
# 4   [tinjau, chanyeol, muncul, asa, muncul, chanye...
# ..                                                ...
# 65  [asli, nyala, notif, instagram, member, hun, j...
# 66                           [jatuh, brondong, dream]
# 67  [sadar, stan, momen, utama, suka, hun, promosi...
# 68  [suka, nonton, video, konser, suju, shinee, as...
# 69                       [harap, muluk, liat, kangen]
#
# [70 rows x 3 columns]

# %%
topics_18 = get_topics_list(mgp_18, top_index_18, 10)
cm_gsdmm_18 = CoherenceModel(topics=topics_18,dictionary=dictionary_neg,corpus=bow_corpus_neg,texts=datafinal2,coherence='c_v')
coherence_gsdmm_18 = cm_gsdmm_18.get_coherence()
print(coherence_gsdmm_18)
# Out:
# 0.3985440191109111

# %%
#Iterasi ke-3
mgp_19 = MovieGroupProcess(K=3, alpha=0.5, beta=0.5, n_iters=5)
model_19 = mgp_19.fit(datafinal2, n_terms_neg)
# Out:
# In stage 0: transferred 44 clusters with 3 clusters populated
# In stage 1: transferred 25 clusters with 3 clusters populated
# In stage 2: transferred 23 clusters with 3 clusters populated
# In stage 3: transferred 28 clusters with 3 clusters populated
# In stage 4: transferred 23 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_19 = numpy.array(mgp_19.cluster_doc_count)
print('Number of documents per cluster :', doc_count_19)

#Topic sorted by the number of document they are allocated to
top_index_19 = doc_count_19.argsort()
print('Most important clusters (by number of docs inside):', top_index_19)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_19.cluster_word_distribution, top_index_19, 10)
# Out:
# Number of documents per cluster : [25 25 20]
# Most important clusters (by number of docs inside): [2 0 1]
#
# Cluster 2 : [('exol', 5), ('ungu', 5), ('akun', 5), ('silah', 4), ('grup', 4), ('jeda', 4), ('suara', 4), ('only', 3), ('henti', 3), ('lo', 3)]
#
# Cluster 0 : [('idol', 8), ('exol', 7), ('foto', 7), ('fokus', 5), ('instagram', 5), ('campur', 4), ('chanyeol', 4), ('sedih', 3), ('profil', 3), ('eri', 2)]
#
# Cluster 1 : [('lay', 6), ('promosi', 4), ('kangen', 4), ('sm', 4), ('konser', 4), ('video', 3), ('hun', 3), ('hilang', 3), ('semangat', 3), ('kai', 2)]

# %%
topic_dict_19 = {}
topic_names_19 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_19):
    topic_dict_19[topic_num]=topic_names_19[i]

result_19 = create_topics_dataframe(data_text=df_negatif.tweet, mgp=mgp_19, threshold=0.3, topic_dict=topic_dict_19, token_list=datafinal2)
result_19
# Out:
#                                                 tweet    topik  \
# 0   lucu banget liat Kai marah gegara eribong di s...  topik 3
# 1   Tidak sabar menanti Kji3  Tapi tunggu Itu bera...  topik 3
# 2   Beri suara Baekhyun di TTA yuk Eri ayo keluari...  topik 1
# 3   Pesan suara dari  untuk 5 th hari jadi Debut E...  topik 1
# 4   Biasa mendapat tinjauan harian Chanyeol tiap h...  topik 2
# ..                                                ...      ...
# 65  asli deh padahal udah gua nyala semua notif ny...  topik 2
# 66  Tolong EXO segera kembali sebelum aku terjatuh...  topik 1
# 67  Baru sadar selama stan exo aku ga punya momen ...  topik 3
# 68  padahal dulu suka banget nonton video konser s...  topik 3
# 69  Harapan gua terlalu muluk kayak nya kalo liat ...  topik 3
#
#                                            token_list
# 0   [lucu, liat, kai, marah, gegara, eribong, semb...
# 1                  [sabar, kji, tunggu, arti, enlist]
# 2   [suara, baekhyun, tta, eri, ayo, keluarin, mod...
# 3   [pesan, suara, debut, cbx, jepang, cr, chennie...
# 4   [tinjau, chanyeol, muncul, asa, muncul, chanye...
# ..                                                ...
# 65  [asli, nyala, notif, instagram, member, hun, j...
# 66                           [jatuh, brondong, dream]
# 67  [sadar, stan, momen, utama, suka, hun, promosi...
# 68  [suka, nonton, video, konser, suju, shinee, as...
# 69                       [harap, muluk, liat, kangen]
#
# [70 rows x 3 columns]

# %%
topics_19 = get_topics_list(mgp_19, top_index_19, 10)
cm_gsdmm_19 = CoherenceModel(topics=topics_19,dictionary=dictionary_neg,corpus=bow_corpus_neg,texts=datafinal2,coherence='c_v')
coherence_gsdmm_19 = cm_gsdmm_19.get_coherence()
print(coherence_gsdmm_19)
# Out:
# 0.3953095421816292

# %%
#Iterasi ke-4 (pilih ini)
mgp_20 = MovieGroupProcess(K=3, alpha=0.7, beta=0.5, n_iters=10)
model_20 = mgp_20.fit(datafinal2, n_terms_neg)
# Out:
# In stage 0: transferred 37 clusters with 3 clusters populated
# In stage 1: transferred 26 clusters with 3 clusters populated
# In stage 2: transferred 24 clusters with 3 clusters populated
# In stage 3: transferred 21 clusters with 3 clusters populated
# In stage 4: transferred 20 clusters with 3 clusters populated
# In stage 5: transferred 17 clusters with 3 clusters populated
# In stage 6: transferred 25 clusters with 3 clusters populated
# In stage 7: transferred 26 clusters with 3 clusters populated
# In stage 8: transferred 35 clusters with 3 clusters populated
# In stage 9: transferred 26 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_20 = numpy.array(mgp_20.cluster_doc_count)
print('Number of documents per cluster :', doc_count_20)

#Topic sorted by the number of document they are allocated to
top_index_20 = doc_count_20.argsort()
print('Most important clusters (by number of docs inside):', top_index_20)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_20.cluster_word_distribution, top_index_20, 10)
# Out:
# Number of documents per cluster : [18 23 29]
# Most important clusters (by number of docs inside): [0 1 2]
#
# Cluster 0 : [('exol', 5), ('ungu', 5), ('silah', 5), ('grup', 4), ('jeda', 4), ('henti', 3), ('only', 3), ('moots', 3), ('ku', 3), ('ijo', 2)]
#
# Cluster 1 : [('idol', 8), ('foto', 8), ('exol', 7), ('fokus', 5), ('akun', 5), ('campur', 4), ('promosi', 4), ('eri', 3), ('chanyeol', 3), ('suara', 3)]
#
# Cluster 2 : [('instagram', 5), ('lay', 4), ('sm', 4), ('video', 3), ('konser', 3), ('kangen', 3), ('kai', 3), ('hilang', 3), ('suho', 3), ('hun', 2)]

# %%
topic_dict_20 = {}
topic_names_20 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_20):
    topic_dict_20[topic_num]=topic_names_20[i]

result_20 = create_topics_dataframe(data_text=df_negatif.tweet, mgp=mgp_20, threshold=0.3, topic_dict=topic_dict_20, token_list=datafinal2)
result_20
# Out:
#                                                 tweet    topik  \
# 0   lucu banget liat Kai marah gegara eribong di s...  topik 3
# 1   Tidak sabar menanti Kji3  Tapi tunggu Itu bera...  topik 3
# 2   Beri suara Baekhyun di TTA yuk Eri ayo keluari...  topik 2
# 3   Pesan suara dari  untuk 5 th hari jadi Debut E...  topik 3
# 4   Biasa mendapat tinjauan harian Chanyeol tiap h...  topik 2
# ..                                                ...      ...
# 65  asli deh padahal udah gua nyala semua notif ny...  topik 3
# 66  Tolong EXO segera kembali sebelum aku terjatuh...  topik 3
# 67  Baru sadar selama stan exo aku ga punya momen ...  topik 2
# 68  padahal dulu suka banget nonton video konser s...  topik 3
# 69  Harapan gua terlalu muluk kayak nya kalo liat ...  topik 3
#
#                                            token_list
# 0   [lucu, liat, kai, marah, gegara, eribong, semb...
# 1                  [sabar, kji, tunggu, arti, enlist]
# 2   [suara, baekhyun, tta, eri, ayo, keluarin, mod...
# 3   [pesan, suara, debut, cbx, jepang, cr, chennie...
# 4   [tinjau, chanyeol, muncul, asa, muncul, chanye...
# ..                                                ...
# 65  [asli, nyala, notif, instagram, member, hun, j...
# 66                           [jatuh, brondong, dream]
# 67  [sadar, stan, momen, utama, suka, hun, promosi...
# 68  [suka, nonton, video, konser, suju, shinee, as...
# 69                       [harap, muluk, liat, kangen]
#
# [70 rows x 3 columns]

# %%
topics_20 = get_topics_list(mgp_20, top_index_20, 10)
cm_gsdmm_20 = CoherenceModel(topics=topics_20,dictionary=dictionary_neg,corpus=bow_corpus_neg,texts=datafinal2,coherence='c_v')
coherence_gsdmm_20 = cm_gsdmm_20.get_coherence()
print(coherence_gsdmm_20)
# Out:
# 0.49372155132026446

# %%
#Iterasi ke-5
mgp_21 = MovieGroupProcess(K=3, alpha=0.7, beta=0.35, n_iters=10)
model_21 = mgp_21.fit(datafinal2, n_terms_neg)
# Out:
# In stage 0: transferred 42 clusters with 3 clusters populated
# In stage 1: transferred 22 clusters with 3 clusters populated
# In stage 2: transferred 18 clusters with 3 clusters populated
# In stage 3: transferred 12 clusters with 3 clusters populated
# In stage 4: transferred 18 clusters with 3 clusters populated
# In stage 5: transferred 28 clusters with 3 clusters populated
# In stage 6: transferred 22 clusters with 3 clusters populated
# In stage 7: transferred 24 clusters with 3 clusters populated
# In stage 8: transferred 22 clusters with 3 clusters populated
# In stage 9: transferred 14 clusters with 3 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_21 = numpy.array(mgp_21.cluster_doc_count)
print('Number of documents per cluster :', doc_count_21)

#Topic sorted by the number of document they are allocated to
top_index_21 = doc_count_21.argsort()
print('Most important clusters (by number of docs inside):', top_index_21)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_21.cluster_word_distribution, top_index_21, 10)
# Out:
# Number of documents per cluster : [21 26 23]
# Most important clusters (by number of docs inside): [0 2 1]
#
# Cluster 0 : [('exol', 5), ('ungu', 5), ('akun', 5), ('grup', 4), ('jeda', 4), ('idol', 3), ('silah', 3), ('susah', 3), ('only', 3), ('henti', 3)]
#
# Cluster 2 : [('foto', 8), ('idol', 7), ('exol', 6), ('fokus', 5), ('campur', 4), ('chanyeol', 4), ('eri', 3), ('profil', 3), ('istirahat', 3), ('suara', 3)]
#
# Cluster 1 : [('lay', 7), ('sm', 4), ('kangen', 4), ('video', 3), ('harap', 3), ('instagram', 3), ('hilang', 3), ('promosi', 3), ('semangat', 3), ('suho', 2)]

# %%
topic_dict_21 = {}
topic_names_21 = ["topik 1", "topik 2", "topik 3"]
for i, topic_num in enumerate(top_index_21):
    topic_dict_21[topic_num]=topic_names_21[i]

result_21 = create_topics_dataframe(data_text=df_negatif.tweet, mgp=mgp_21, threshold=0.3, topic_dict=topic_dict_21, token_list=datafinal2)
result_21
# Out:
#                                                 tweet    topik  \
# 0   lucu banget liat Kai marah gegara eribong di s...  topik 1
# 1   Tidak sabar menanti Kji3  Tapi tunggu Itu bera...  topik 2
# 2   Beri suara Baekhyun di TTA yuk Eri ayo keluari...  topik 2
# 3   Pesan suara dari  untuk 5 th hari jadi Debut E...  topik 2
# 4   Biasa mendapat tinjauan harian Chanyeol tiap h...  topik 2
# ..                                                ...      ...
# 65  asli deh padahal udah gua nyala semua notif ny...  topik 2
# 66  Tolong EXO segera kembali sebelum aku terjatuh...  topik 1
# 67  Baru sadar selama stan exo aku ga punya momen ...  topik 2
# 68  padahal dulu suka banget nonton video konser s...  topik 3
# 69  Harapan gua terlalu muluk kayak nya kalo liat ...  topik 3
#
#                                            token_list
# 0   [lucu, liat, kai, marah, gegara, eribong, semb...
# 1                  [sabar, kji, tunggu, arti, enlist]
# 2   [suara, baekhyun, tta, eri, ayo, keluarin, mod...
# 3   [pesan, suara, debut, cbx, jepang, cr, chennie...
# 4   [tinjau, chanyeol, muncul, asa, muncul, chanye...
# ..                                                ...
# 65  [asli, nyala, notif, instagram, member, hun, j...
# 66                           [jatuh, brondong, dream]
# 67  [sadar, stan, momen, utama, suka, hun, promosi...
# 68  [suka, nonton, video, konser, suju, shinee, as...
# 69                       [harap, muluk, liat, kangen]
#
# [70 rows x 3 columns]

# %%
topics_21 = get_topics_list(mgp_21, top_index_21, 10)
cm_gsdmm_21 = CoherenceModel(topics=topics_21,dictionary=dictionary_neg,corpus=bow_corpus_neg,texts=datafinal2,coherence='c_v')
coherence_gsdmm_21 = cm_gsdmm_21.get_coherence()
print(coherence_gsdmm_21)
# Out:
# 0.45454243157827384

# %%
#Iterasi ke-6
mgp_22 = MovieGroupProcess(K=5, alpha=0.7, beta=0.5, n_iters=10)
model_22 = mgp_22.fit(datafinal2, n_terms_neg)
# Out:
# In stage 0: transferred 53 clusters with 5 clusters populated
# In stage 1: transferred 36 clusters with 5 clusters populated
# In stage 2: transferred 27 clusters with 5 clusters populated
# In stage 3: transferred 29 clusters with 5 clusters populated
# In stage 4: transferred 27 clusters with 5 clusters populated
# In stage 5: transferred 28 clusters with 5 clusters populated
# In stage 6: transferred 28 clusters with 5 clusters populated
# In stage 7: transferred 28 clusters with 5 clusters populated
# In stage 8: transferred 37 clusters with 5 clusters populated
# In stage 9: transferred 33 clusters with 5 clusters populated

# %%
import numpy
#print number of documents per cluster
doc_count_22 = numpy.array(mgp_22.cluster_doc_count)
print('Number of documents per cluster :', doc_count_22)

#Topic sorted by the number of document they are allocated to
top_index_22 = doc_count_22.argsort()
print('Most important clusters (by number of docs inside):', top_index_22)

#define function to get top words per topic
def top_words(cluster_word_distribution, top_cluster, values):
    for cluster in top_cluster:
        sort_dicts = sorted(cluster_word_distribution[cluster].items(), key=lambda k: k[1], reverse=True)[:values]
        print("\nCluster %s : %s"%(cluster, sort_dicts))

top_words(mgp_22.cluster_word_distribution, top_index_22, 10)
# Out:
# Number of documents per cluster : [15  8 22 15 10]
# Most important clusters (by number of docs inside): [1 4 0 3 2]
#
# Cluster 1 : [('lay', 6), ('sm', 4), ('konser', 3), ('suho', 2), ('do', 2), ('entertainment', 2), ('panggil', 2), ('terjun', 2), ('kai', 1), ('episode', 1)]
#
# Cluster 4 : [('akun', 5), ('ungu', 4), ('only', 3), ('silah', 3), ('henti', 3), ('suara', 3), ('stan', 3), ('moots', 3), ('exol', 2), ('khusus', 2)]
#
# Cluster 0 : [('instagram', 5), ('jeda', 4), ('member', 3), ('hun', 3), ('kai', 3), ('grup', 3), ('ketua', 2), ('mulu', 2), ('ku', 2), ('lucu', 2)]
#
# Cluster 3 : [('chanyeol', 3), ('muncul', 3), ('asa', 2), ('istirahat', 2), ('dubai', 2), ('kimjunmyeon', 2), ('korea', 2), ('lo', 2), ('harap', 1), ('video', 1)]
#
# Cluster 2 : [('exol', 9), ('idol', 8), ('foto', 7), ('fokus', 5), ('campur', 4), ('profil', 3), ('semangat', 3), ('promosi', 3), ('urus', 2), ('eri', 2)]

# %%
topic_dict_22 = {}
topic_names_22 = ["topik 1", "topik 2", "topik 3", "topik 4", "topik 5"]
for i, topic_num in enumerate(top_index_22):
    topic_dict_22[topic_num]=topic_names_22[i]

result_22 = create_topics_dataframe(data_text=df_negatif.tweet, mgp=mgp_22, threshold=0.3, topic_dict=topic_dict_22, token_list=datafinal2)
result_22
# Out:
#                                                 tweet    topik  \
# 0   lucu banget liat Kai marah gegara eribong di s...  topik 3
# 1   Tidak sabar menanti Kji3  Tapi tunggu Itu bera...  topik 5
# 2   Beri suara Baekhyun di TTA yuk Eri ayo keluari...  topik 2
# 3   Pesan suara dari  untuk 5 th hari jadi Debut E...  topik 4
# 4   Biasa mendapat tinjauan harian Chanyeol tiap h...  topik 4
# ..                                                ...      ...
# 65  asli deh padahal udah gua nyala semua notif ny...  topik 3
# 66  Tolong EXO segera kembali sebelum aku terjatuh...  topik 3
# 67  Baru sadar selama stan exo aku ga punya momen ...  topik 2
# 68  padahal dulu suka banget nonton video konser s...  topik 1
# 69  Harapan gua terlalu muluk kayak nya kalo liat ...  topik 5
#
#                                            token_list
# 0   [lucu, liat, kai, marah, gegara, eribong, semb...
# 1                  [sabar, kji, tunggu, arti, enlist]
# 2   [suara, baekhyun, tta, eri, ayo, keluarin, mod...
# 3   [pesan, suara, debut, cbx, jepang, cr, chennie...
# 4   [tinjau, chanyeol, muncul, asa, muncul, chanye...
# ..                                                ...
# 65  [asli, nyala, notif, instagram, member, hun, j...
# 66                           [jatuh, brondong, dream]
# 67  [sadar, stan, momen, utama, suka, hun, promosi...
# 68  [suka, nonton, video, konser, suju, shinee, as...
# 69                       [harap, muluk, liat, kangen]
#
# [70 rows x 3 columns]

# %%
topics_22 = get_topics_list(mgp_22, top_index_22, 10)
cm_gsdmm_22 = CoherenceModel(topics=topics_22,dictionary=dictionary_neg,corpus=bow_corpus_neg,texts=datafinal2,coherence='c_v')
coherence_gsdmm_22 = cm_gsdmm_22.get_coherence()
print(coherence_gsdmm_22)
# Out:
# 0.3670016233267525
